# %%
get_ipython().system('pip3 install scikit-hts')
# Out:
# Collecting scikit-hts
#   Downloading https://files.pythonhosted.org/packages/5a/83/9f0865ad11ababc00f909cb29e64ad3030ff8ded701a0c36b2ecce8c94b0/scikit_hts-0.5.2-py2.py3-none-any.whl
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.6/dist-packages (from scikit-hts) (1.0.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.6/dist-packages (from scikit-hts) (1.4.1)
# Requirement already satisfied: statsmodels==0.10.2 in /usr/local/lib/python3.6/dist-packages (from scikit-hts) (0.10.2)
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.6/dist-packages (from scikit-hts) (1.18.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.6/dist-packages (from scikit-hts) (0.22.2.post1)
# Collecting tqdm==4.43
#   Downloading https://files.pythonhosted.org/packages/47/55/fd9170ba08a1a64a18a7f8a18f088037316f2a41be04d2fe6ece5a653e8f/tqdm-4.43.0-py2.py3-none-any.whl (59kB)
#      |████████████████████████████████| 61kB 2.9MB/s
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.25.3->scikit-hts) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.25.3->scikit-hts) (2018.9)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from statsmodels==0.10.2->scikit-hts) (0.5.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.21.3->scikit-hts) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.25.3->scikit-hts) (1.15.0)
# Installing collected packages: tqdm, scikit-hts
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# Successfully installed scikit-hts-0.5.2 tqdm-4.43.0

# %%
get_ipython().system('pip3 install pmdarima')
# Out:
# Collecting pmdarima
#   Downloading https://files.pythonhosted.org/packages/4b/15/0dfc38deb2f5582b79baff6523b245d6a3dbe877e3fb96a1ee39ec63b626/pmdarima-1.6.1-cp36-cp36m-manylinux1_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 2.8MB/s
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.0.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (0.16.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.18.5)
# Collecting statsmodels>=0.11
#   Downloading https://files.pythonhosted.org/packages/cb/83/540fd83238a18abe6c2d280fa8e489ac5fcefa1f370f0ca1acd16ae1b860/statsmodels-0.11.1-cp36-cp36m-manylinux1_x86_64.whl (8.7MB)
#      |████████████████████████████████| 8.6MB 27kB/s eta 0:00:01     |████████████████████████████████| 8.7MB 27kB/s
# Collecting Cython<0.29.18,>=0.29
#   Downloading https://files.pythonhosted.org/packages/e7/d7/510ddef0248f3e1e91f9cc7e31c0f35f8954d0af92c5c3fd4c853e859ebe/Cython-0.29.17-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 49.2MB/s eta 0:00:01
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (0.22.2.post1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.6/dist-packages (from statsmodels>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.19->pmdarima) (1.15.0)
# ERROR: scikit-hts 0.5.2 has requirement statsmodels==0.10.2, but you'll have statsmodels 0.11.1 which is incompatible.
# Installing collected packages: statsmodels, Cython, pmdarima
#   Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
#   Found existing installation: Cython 0.29.21
#     Uninstalling Cython-0.29.21:
#       Successfully uninstalled Cython-0.29.21
# Successfully installed Cython-0.29.17 pmdarima-1.6.1 statsmodels-0.11.1

# %%
import numpy as np
import pandas as pd
from fbprophet import Prophet
import os
import json

# %%
import inspect
def get_default_args(func):
    signature = inspect.signature(func)
    return{
        k: v.default
        for k, v in signature.parameters.items()
        if v.default is not inspect.Parameter.empty 
    }

prophet_defaults = get_default_args(Prophet)

# %%
'''
#df = pd.read_csv("/kaggle/input/sales-df/df.csv")
df = pd.read_csv("data/df.csv")
#with open("/kaggle/input/hier-json/hierarchy.json", "r") as f:
with open("data/hierarchy.json", "r") as f:
    hierarchy = json.load(f)  
if "Date" in df.columns.tolist():
    df.index = pd.to_datetime(df["Date"])
    del df["Date"]
df = df.asfreq("D")
'''

# %%
#with open("/kaggle/input/hier-json/hierarchy.json", "r") as f:
with open("data/hierarchy.json", "r") as f:
    hierarchy = json.load(f)
#df_path = "/kaggle/input/df-add-lookup/df_add_lookup.csv"
df_path = "data/df_add_lookup.csv"
df = pd.read_csv(df_path)
shift_cols = list(filter(lambda x: x.startswith("Customers") or x.startswith("Sales"),df.columns.tolist()))
for col in shift_cols:
    df[col] = df[col].shift(1)
#df = df.dropna()
df = df.fillna(0)
if "Date" in df.columns.tolist():
    df.index = pd.to_datetime(df["Date"])
    del df["Date"]
df = df.asfreq("D")

# %%
#df.head()
# Out:
#                    aa         ac  ...  14_mean_total  14_max_total
# Date                              ...
# 2013-01-02  2380995.0  1539391.0  ...       0.112222           1.0
# 2013-01-03  2138492.0  1389535.0  ...       0.111968           1.0
# 2013-01-04  2190919.0  1419296.0  ...       0.111968           1.0
# 2013-01-05  1734213.0  1230374.0  ...       0.112054           1.0
# 2013-01-06  2764731.5  1764528.5  ...       0.112054           1.0
#
# [5 rows x 1575 columns]

# %%
#first_df, second_df = pd.read_csv("data/df.csv"), pd.read_csv("df_add_lookup.csv")

# %%
#first_df.shape, second_df.shape

# %%
#(first_df.iloc[:, 1:] - second_df[first_df.iloc[:, 1:].columns.tolist()]).applymap(np.abs).mean()

# %%
#df.shape

# %%
#from hts.hierarchy import HierarchyTree
#ht = HierarchyTree.from_nodes(nodes = hierarchy, df = df)

# %%
#type(ht.children[0]), type(ht)
#ht.key, ht.children[0].key
#ht.item

# %%
#list(hierarchy.keys()) + list(hierarchy.values())[0]

# %%
head_set = set(filter(lambda x: "_" in x ,map(lambda col: col[:col.rfind("_")] ,df.columns.tolist())))
cate_set = set(filter(lambda x: "_" not in x ,map(lambda col: col[col.rfind("_") + 1:] ,df.columns.tolist())))

# %%
#head_set

# %%
#"Promo2SinceWeek_mean_total" in df.columns.tolist()

# %%
from hts.model import FBProphetModel
from hts.model.p import *
class FBProphetModel_Add_Version(FBProphetModel):
    def create_model(self, *args, **kwargs):
        self.lookup_df = None
        has_children = bool(self.node.children)
        is_children = not has_children
        print("will create {} model {}".format("leaf" if is_children else "branch", self.node) + "-" * 10)
        if "ext_args" not in kwargs:
            return super(FBProphetModel_Add_Version, self).create_model(*args, **kwargs)
        base_kwargs = dict()
        for k, v in kwargs.items():
            if k not in ["ext_args", "add_reg"]:
                base_kwargs[k] = v
        base_model = super(FBProphetModel_Add_Version, self).create_model(*args, **base_kwargs)
        #base_model = super().create_model(*args, **kwargs)
        ext_args_dict = kwargs["ext_args"]
        if "seasonality" in ext_args_dict:
            assert type(ext_args_dict["seasonality"]) == type([])
            for seasonality_dict in ext_args_dict["seasonality"]:
                name, period, fourier_order, prior_scale = seasonality_dict["name"], seasonality_dict["period"], seasonality_dict["fourier_order"], seasonality_dict["prior_scale"]
                base_model.add_seasonality(name = name, period = period, fourier_order = fourier_order, prior_scale =prior_scale)
                print("seasonality {} {} {} {} added".format(name, period, fourier_order, prior_scale))
        if "add_reg" in kwargs and "data" in kwargs["add_reg"] and kwargs["add_reg"]["data"] is not None:
            assert "reg" in ext_args_dict
            print("reg")
            reg_prior_dict = ext_args_dict["reg"]
            self.lookup_df = kwargs["add_reg"]["data"]
            cate = self.node.key
            assert cate in cate_set
            for col in map(lambda x: "{}_{}".format(x, cate), head_set):
                if "_mean_" in col:
                    prior_scale = reg_prior_dict["{}_prior".format(col)]
                    base_model.add_regressor(col, prior_scale = prior_scale)
                    #print("reg {} added".format(col))
        return base_model
    def fit(self, **fit_args) -> 'TimeSeriesModel':
        df = self._reformat(self.node.item)

        if self.lookup_df is not None:
            lookup_df = self.lookup_df
            before_shape = df.shape
            if "Date" not in lookup_df.columns.tolist():
                lookup_df = lookup_df.reset_index()
            ds_col = list(map(lambda tt2: tt2[0] ,filter(lambda t2: t2[-1] ,lookup_df.dtypes.map(str).map(lambda x: x == "datetime64[ns]").to_dict().items())))[0]
            lookup_df = lookup_df.rename(columns = {ds_col: "ds"})
            df = pd.merge(df, lookup_df, on = "ds", how = "inner")
            print("fit merge shape {} before shape {}".format(df.shape, before_shape))
            
        with suppress_stdout_stderr():
            self.model = self.model.fit(df)
            self.model.stan_backend = None
        return self

    def predict(self,
                node: HierarchyTree,
                freq: str = 'D',
                steps_ahead: int = 1):

        df = self._reformat(node.item)
        future = self.model.make_future_dataframe(periods=steps_ahead,
                                                  freq=freq,
                                                  include_history=True)
        if self.cap:
            future['cap'] = self.cap
        if self.floor:
            future['floor'] = self.floor
        
        if self.lookup_df is not None:
            lookup_df = self.lookup_df
            before_shape = future.shape
            if "Date" not in lookup_df.columns.tolist():
                lookup_df = lookup_df.reset_index()
            ds_col = list(map(lambda tt2: tt2[0] ,filter(lambda t2: t2[-1] ,lookup_df.dtypes.map(str).map(lambda x: x == "datetime64[ns]").to_dict().items())))[0]
            lookup_df = lookup_df.rename(columns = {ds_col: "ds"})
            future = pd.merge(future, lookup_df, on = "ds", how = "inner")
            print("pred merge shape {} before shape {}".format(future.shape, before_shape))
        
        self.forecast = self.model.predict(future)
        merged = pandas.merge(df, self.forecast, on='ds')
        self.residual = (merged['yhat'] - merged['y']).values
        self.mse = numpy.mean(numpy.array(self.residual) ** 2)
        if self.cap is not None:
            self.forecast.yhat = numpy.exp(self.forecast.yhat)
        if self.transform:
            self.forecast.yhat = self.transformer.inverse_transform(self.forecast.yhat)
            self.forecast.trend = self.transformer.inverse_transform(self.forecast.trend)
            for component in ["seasonal", "daily", "weekly", "yearly", "holidays"]:
                if component in self.forecast.columns.tolist():
                    inv_transf = self.transformer.inverse_transform(getattr(self.forecast, component))
                    setattr(self.forecast, component, inv_transf)
        return self

# %%
from hts.revision import *
class RevisionMethod_BU(RevisionMethod):
    def _y_hat_matrix(self, forecasts):
        print("forecasts first key: {}".format(list(forecasts.keys())[0]))
        n_cols = len(list(forecasts.keys())) + 1
        keys = range(n_cols - self.sum_mat.shape[1] - 1, n_cols - 1)
        #named_keys = list(map(lambda k_idx: list(forecasts.keys())[k_idx], keys))
        named_keys = list(set(forecasts.keys()).difference(set(["total"])))
        return y_hat_matrix(forecasts, keys=named_keys)

# %%
from hts.core.regressor import *
class HTSRegressor_Add_Verison(HTSRegressor):
    def _init_revision(self):
        self.revision_method = RevisionMethod_BU(sum_mat=self.sum_mat, transformer=self.transform, name=self.method)
    def _set_model_instance(self):
        from hts import model as hts_models
        from copy import deepcopy
        model_mapping = deepcopy(hts_models.MODEL_MAPPING)
        model_mapping["prophet"] = FBProphetModel_Add_Version
        try:
            self.model_instance = model_mapping[self.model]
        except KeyError:
            raise InvalidArgumentException(f'Model {self.model} not valid. Pick one of: {" ".join(Model.names())}')
            
    def _revise(self, steps_ahead=1):
        logger.info(f'Reconciling forecasts using {self.revision_method}')
        revised = self.revision_method.revise(
            forecasts=self.hts_result.forecasts,
            mse=self.hts_result.errors,
            nodes=self.nodes
        )

        revised_columns = list(make_iterable(self.nodes))
        revised_index = self._get_predict_index(steps_ahead=steps_ahead)
        return pandas.DataFrame(revised,
                                index=revised_index,
                                columns=revised_columns)

# %%
def object_func(kw):
    from copy import deepcopy
    from time import time
    from fbprophet.diagnostics import generate_cutoffs, performance_metrics
    start_time = time()
    assert type(kw) == type(dict())
    
    n_changepoints = int(kw["n_changepoints"])
    changepoint_range = kw["changepoint_range"]
    seasonality_prior_scale = kw["seasonality_prior_scale"]
    holidays_prior_scale = kw["holidays_prior_scale"]
    changepoint_prior_scale = kw["changepoint_prior_scale"]
    
    yearly_fourier_order = int(kw["yearly_fourier_order"])
    weekly_fourier_order = int(kw["weekly_fourier_order"])
    monthly_fourier_order = int(kw["monthly_fourier_order"])

    yearly_prior = kw["yearly_prior"]
    weekly_prior = kw["weekly_prior"]
    monthly_prior = kw["monthly_prior"]

    kwargs = dict()
    kwargs["yearly_seasonality"] = False
    kwargs["daily_seasonality"] = False
    kwargs["weekly_seasonality"] = False
    kwargs["ext_args"] = {
    "seasonality": [],
    "reg": {}
}

    kwargs["ext_args"]["seasonality"].append(
    {
        "name": "yearly",
        "period": 365.25,
        "fourier_order": yearly_fourier_order,
        "prior_scale": yearly_prior
    }
)
    kwargs["ext_args"]["seasonality"].append(
    {
        "name": "weekly",
        "period": 7,
        "fourier_order": weekly_fourier_order,
        "prior_scale": weekly_prior
    }
)
    kwargs["ext_args"]["seasonality"].append(
    {
        "name": "monthly",
        "period": 30.5,
        "fourier_order": monthly_fourier_order,
        "prior_scale": monthly_prior
    }
)
    
    kwargs["n_changepoints"] = n_changepoints
    kwargs["seasonality_prior_scale"] = seasonality_prior_scale
    kwargs["holidays_prior_scale"] = holidays_prior_scale
    kwargs["changepoint_prior_scale"] = changepoint_prior_scale
    
    kwargs["changepoint_range"] = changepoint_range
    kwargs["add_reg"] = {
        "data": None, 
    }
    
    horizon = "7 days"
    period = "7 days"
    initial = "870 days"
    
    horizon, period, initial = map(pd.Timedelta, [horizon, period, initial])
    #df = pd.read_csv("/kaggle/input/sales-df/df.csv")
    #df = pd.read_csv("data/df.csv")
    df = pd.read_csv(df_path)
    shift_cols = list(filter(lambda x: x.startswith("Customers") or x.startswith("Sales"),df.columns.tolist()))
    #shift_cols = []
    for col in shift_cols:
        df[col] = df[col].shift(1).copy()
    #df = df.dropna()
    df = df.fillna(0)
    df["Date"] = pd.to_datetime(df["Date"])
    
    kwargs["add_reg"]["data"] = df
    
    other_cols = list(filter(lambda col: col not in ["Date"] + list(hierarchy.keys()) + list(hierarchy.values())[0] ,df.columns.tolist()))
    for col in other_cols:
        #exec("reg_{}_prior=kw['{}_prior']".format(col, col))
        #kwargs["reg"]["{}_prior".format(col)] = kw["{}_prior".format(col)]
        kwargs["ext_args"]["reg"]["{}_prior".format(col)] = kw["{}_prior".format(col)]
    #df = df[["Date"] + list(hierarchy.keys()) + list(hierarchy.values())[0]].copy()

    cutoffs = generate_cutoffs(df = df.reset_index().rename(columns ={"Date": "ds", "total": "y"})[["ds", "y"]],horizon=horizon, period=period, initial=initial)

    cutoffs_list = list(cutoffs)

    def cutoff_forecast_gen(input_df, cutoffs_list):
        if "Date" not in input_df.columns.tolist() and "ds" not in input_df.columns.tolist():
            input_df = input_df.reset_index() 
            ds_col = "Date"
        else:
            ds_col = "Date" if "Date" in input_df.columns.tolist() else "ds"
        assert ds_col in input_df.columns.tolist()
        input_df[ds_col] = pd.to_datetime(input_df[ds_col])
        for i in range(len(sorted(cutoffs_list)[:-1])):
            time = sorted(cutoffs_list)[i]
            df_for_fit = input_df[input_df[ds_col] <= time].copy()
            pred_length = (sorted(cutoffs_list)[i + 1] - time).days
            df_for_fit.index = df_for_fit[ds_col]
            del df_for_fit[ds_col]
            yield (df_for_fit, pred_length)

    cutoffs_gen = cutoff_forecast_gen(df, cutoffs_list=cutoffs_list)

    cutoffs_gen_list = list(cutoffs_gen)

    def single_fit_predict(total_df ,clf_for_cp, df_for_fit, hierarchy, pred_length, measure_cols = "total", return_errors = True):
        assert type(measure_cols) in [type([]), type("")]
        measure_cols_list = measure_cols if type(measure_cols) == type([]) else [measure_cols]
        from copy import deepcopy
        clf = deepcopy(clf_for_cp)
        df_for_fit = df_for_fit.asfreq("D")
        model = clf.fit(df_for_fit, hierarchy)
        preds = model.predict(steps_ahead=pred_length)
        if "Date" not in total_df.columns.tolist():
            total_df = total_df.reset_index()
        if "Date" not in preds.columns.tolist():
            preds = preds.reset_index()
        
        total_ds_col = list(map(lambda tt2: tt2[0] ,filter(lambda t2: t2[-1] ,total_df.dtypes.map(str).map(lambda x: x == "datetime64[ns]").to_dict().items())))[0]
        preds_ds_col = list(map(lambda tt2: tt2[0] ,filter(lambda t2: t2[-1] ,preds.dtypes.map(str).map(lambda x: x == "datetime64[ns]").to_dict().items())))[0]
        preds_lookup_part = preds.sort_values(by = preds_ds_col, ascending = True).tail(pred_length).copy()
        total_lookup_part = total_df[total_df[total_ds_col].isin(preds_lookup_part[preds_ds_col])]
        print("total_part {} preds_part {}".format(total_lookup_part.shape, preds_lookup_part.shape))
        assert len(set(measure_cols_list).intersection(set(total_lookup_part.columns.tolist()))) == len(measure_cols_list)
        assert len(set(measure_cols_list).intersection(set(preds_lookup_part.columns.tolist()))) == len(measure_cols_list)
        preds_lookup_part = preds_lookup_part[preds_lookup_part[preds_ds_col].isin(total_lookup_part[total_ds_col])]
        total_lookup_part = total_lookup_part.sort_values(by = total_ds_col, ascending = True)
        preds_lookup_part = preds_lookup_part.sort_values(by = preds_ds_col, ascending = True)
        if not return_errors:
            return (total_lookup_part[measure_cols_list], preds_lookup_part[measure_cols_list])
        
        measure_cols_errors = (total_lookup_part[measure_cols_list] - preds_lookup_part[measure_cols_list]).applymap(abs).mean(axis = 0)
        mean_errors = measure_cols_errors.mean()
        return (measure_cols_errors, mean_errors)
    
    clf = HTSRegressor_Add_Verison(model='prophet', revision_method='BU', n_jobs=4, low_memory=False, **kwargs)
    
    def construct_df_cv_format(ori_df, pred_df, max_date, add_one = True):
        assert ori_df.columns.tolist() == pred_df.columns.tolist() and ori_df.shape == pred_df.shape
        ori_series_list = []
        pred_series_list = []
        cols = ori_df.columns.tolist()
        for col in cols:
            ori_series_list.append(ori_df[col])
            pred_series_list.append(pred_df[col])
        
        def bind_single_series(ori_s, pred_s):
            bind_df = pd.concat(list(map(pd.Series,[ori_s.values.tolist(), pred_s.values.tolist()])), axis = 1)
            assert bind_df.shape[0] == len(ori_s)
            bind_df.columns = ["y", "yhat"]
            if add_one:
                bind_df["y"] += 1
                bind_df["yhat"] += 1
            bind_df["ds"] = pd.date_range(max_date - pd.Timedelta("{}d".format(len(ori_s) - 1)), max_date)
            bind_df["cutoff"] = max_date - pd.Timedelta("{}d".format(len(ori_s)))
            return bind_df

        before_performance_list = list(map(lambda idx: ( ori_series_list[idx].name,bind_single_series(ori_series_list[idx], pred_series_list[idx])), range(len(ori_series_list))))
        different_part_dict = dict(map(lambda t2: (t2[0] ,performance_metrics(t2[-1], ["mape"])), before_performance_list))
        return dict(map(lambda t2: (t2[0], t2[1]["mape"].mean()) ,different_part_dict.items()))

    use_mape = True
    if use_mape:
        cutoffs_run_conclusions = list(map(lambda df_and_step:  (pd.Series(df_and_step[0].index.tolist()).max() ,single_fit_predict(df[["Date"] + list(hierarchy.keys()) + list(hierarchy.values())[0]] ,clf, df_and_step[0], hierarchy, df_and_step[1], ["total"], return_errors = False)), cutoffs_gen_list))
        dict_list = list(map(lambda t2: construct_df_cv_format(t2[-1][0], t2[-1][1], t2[0]), cutoffs_run_conclusions))
        from collections import defaultdict
        req = defaultdict(list)
        for dict_ in dict_list:
            for k, v in dict_.items():
                req[k].append(v)
        req_cp = dict()
        for k, v in req.items():
            req_cp[k] = pd.Series(v).mean()
        score = pd.Series(list(req_cp.values())).mean()
        #return score
    else:
        cutoffs_run_conclusions = list(map(lambda df_and_step:  (pd.Series(df_and_step[0].index.tolist()).max() ,single_fit_predict(df ,clf, df_and_step[0], hierarchy, df_and_step[1], ["total"], return_errors = True)), cutoffs_gen_list))
            
        cutoffs_run_conclusions_df = pd.DataFrame(cutoffs_run_conclusions)
        cutoffs_run_conclusions_df.columns = ["Date", "error"]
        data_unzipped = pd.concat(list(map(pd.Series ,cutoffs_run_conclusions_df["error"].map(lambda x: dict(x[0])).values.tolist())), axis = 1).T
        cutoffs_run_conclusions_df[data_unzipped.columns.tolist()] = data_unzipped
        cutoffs_run_conclusions_df = cutoffs_run_conclusions_df[["Date"] + data_unzipped.columns.tolist()]
        score = cutoffs_run_conclusions_df["total"].mean()
    
    '''
    import pickle as pkl
    import os
    retain_size = 100
    serlize_path = "/kaggle/working/serlize_m_dict.pkl"
    if os.path.exists(serlize_path):
        with open(serlize_path, "rb") as f:
            ori_serlize_m_dict = pkl.load(f)
        if len(ori_serlize_m_dict) > retain_size:
            ori_serlize_m_dict = dict(list(sorted(ori_serlize_m_dict.items(), key = lambda t2: t2[0]))[:retain_size])
    else:
        ori_serlize_m_dict = {}
    ori_serlize_m_dict = dict([(score, (kw, ))] + list(ori_serlize_m_dict.items()))
    
    ori_serlize_m_dict = dict(list(sorted(ori_serlize_m_dict.items(), key = lambda t2: t2[0]))[:retain_size])
    print("list length : {}".format(len(ori_serlize_m_dict)))
    
    with open(serlize_path, "wb") as f:
        pkl.dump(ori_serlize_m_dict, f)
    '''
    print("time consum : {}".format(time() - start_time))
    
    return score

# %%
req_keys = [
         'n_changepoints',
     'changepoint_range',
     'seasonality_prior_scale',
     'holidays_prior_scale',
     'changepoint_prior_scale',
        "yearly_fourier_order",
        "weekly_fourier_order",
        "monthly_fourier_order",

    "yearly_prior",
    "weekly_prior",
    "monthly_prior",
]


have_kv_dict = {
    "yearly_fourier_order": 1,
    "monthly_fourier_order": 2,

    "yearly_prior": 10,
    "monthly_prior": 10,
    "yearly_on_season_prior": 10, 

    "weekly_fourier_order": 5,
    "weekly_prior": 18,
    
}

other_cols = list(filter(lambda col: col not in ["Date"] + list(hierarchy.keys()) + list(hierarchy.values())[0] ,df.columns.tolist()))
req_keys.extend(list(map(lambda col: "{}_prior".format(col) ,other_cols)))

for col in other_cols:
    have_kv_dict["{}_prior".format(col)] = 10

from hyperopt import hp
from hyperopt import fmin, tpe


tiny_space = {
'n_changepoints': hp.choice("n_changepoints", list(range(5, 45))),
 'changepoint_range': hp.uniform("changepoint_range", 0.5, 1.0),
 'seasonality_prior_scale': hp.uniform("seasonality_prior_scale", 5.0, 50.0),
 'holidays_prior_scale': hp.uniform("holidays_prior_scale", 5.0, 60.0),
 'changepoint_prior_scale': hp.uniform("changepoint_prior_scale", 0.0001, 0.1),
 'yearly_fourier_order': hp.choice("yearly_fourier_order", list(range(1, 70))),
 'monthly_fourier_order': hp.choice("monthly_fourier_order", list(range(1, 35))),
    
  "yearly_prior": hp.choice("yearly_prior", np.logspace(1, 100, num = 100, base = 100 ** (1 / 100))),
    "monthly_prior":hp.choice("monthly_prior", np.logspace(1, 100, num = 100, base = 100 ** (1 / 100))),

"weekly_prior":hp.choice("weekly_prior", np.logspace(1, 100, num = 100, base = 100 ** (1 / 100))),
'weekly_fourier_order': hp.choice("weekly_fourier_order", list(range(1, 35))),
    
}

for col in other_cols:
    tiny_space["{}_prior".format(col)] = hp.choice("{}_prior".format(col), np.logspace(1, 100, num = 100, base = 100 ** (1 / 100)))

# %%
set_default_dict = dict(map(lambda k:(k, have_kv_dict[k]) if k in have_kv_dict else (k, prophet_defaults[k]), req_keys))

# %%
set_default_dict
# Out:
# {'n_changepoints': 25,
#  'changepoint_range': 0.8,
#  'seasonality_prior_scale': 10.0,
#  'holidays_prior_scale': 10.0,
#  'changepoint_prior_scale': 0.05,
#  'yearly_fourier_order': 1,
#  'weekly_fourier_order': 5,
#  'monthly_fourier_order': 2,
#  'yearly_prior': 10,
#  'weekly_prior': 18,
#  'monthly_prior': 10,
#  '25_max_da_prior': 10,
#  'CompetitionOpenSinceMonth_max_da_prior': 10,
#  'CompetitionDistance_max_da_prior': 10,
#  '9_max_da_prior': 10,
#  '12_max_da_prior': 10,
#  'SchoolHoliday_max_da_prior': 10,
#  'Promo2_max_da_prior': 10,
#  'PromoInterval_Mar_max_da_prior': 10,
#  'Promo2SinceYear_max_da_prior': 10,
#  '2_max_da_prior': 10,
#  '6_max_da_prior': 10,
#  '13_max_da_prior': 10,
#  '21_max_da_prior': 10,
#  '0_max_da_prior': 10,
#  '16_max_da_prior': 10,
#  '18_max_da_prior': 10,
#  'PromoInterval_Oct_max_da_prior': 10,
#  'Day_max_da_prior': 10,
#  '4_max_da_prior': 10,
#  '26_max_da_prior': 10,
#  '1_max_da_prior': 10,
#  'Sales_max_da_prior': 10,
#  '15_max_da_prior': 10,
#  'PromoInterval_Aug_max_da_prior': 10,
#  '7_max_da_prior': 10,
#  'PromoInterval_Apr_max_da_prior': 10,
#  'PromoInterval_Jul_max_da_prior': 10,
#  '5_max_da_prior': 10,
#  'PromoInterval_Nov_max_da_prior': 10,
#  'WeekOfYear_max_da_prior': 10,
#  '3_max_da_prior': 10,
#  'SalesPerCustomer_max_da_prior': 10,
#  '22_max_da_prior': 10,
#  '24_max_da_prior': 10,
#  'Month_max_da_prior': 10,
#  'PromoInterval_Feb_max_da_prior': 10,
#  'Promo2SinceWeek_max_da_prior': 10,
#  '11_max_da_prior': 10,
#  '20_max_da_prior': 10,
#  '10_max_da_prior': 10,
#  'PromoInterval_Dec_max_da_prior': 10,
#  'PromoInterval_Jan_max_da_prior': 10,
#  'Promo_max_da_prior': 10,
#  'PromoInterval_Sept_max_da_prior': 10,
#  'Customers_max_da_prior': 10,
#  'CompetitionOpenSinceYear_max_da_prior': 10,
#  'Date_max_da_prior': 10,
#  '8_max_da_prior': 10,
#  '17_max_da_prior': 10,
#  '23_max_da_prior': 10,
#  'PromoInterval_May_max_da_prior': 10,
#  '19_max_da_prior': 10,
#  'DayOfWeek_max_da_prior': 10,
#  'Year_max_da_prior': 10,
#  'PromoInterval_Jun_max_da_prior': 10,
#  '14_max_da_prior': 10,
#  '25_min_da_prior': 10,
#  'CompetitionOpenSinceMonth_min_da_prior': 10,
#  'CompetitionDistance_min_da_prior': 10,
#  '9_min_da_prior': 10,
#  '12_min_da_prior': 10,
#  'SchoolHoliday_min_da_prior': 10,
#  'Promo2_min_da_prior': 10,
#  'PromoInterval_Mar_min_da_prior': 10,
#  'Promo2SinceYear_min_da_prior': 10,
#  '2_min_da_prior': 10,
#  '6_min_da_prior': 10,
#  '13_min_da_prior': 10,
#  '21_min_da_prior': 10,
#  '0_min_da_prior': 10,
#  '16_min_da_prior': 10,
#  '18_min_da_prior': 10,
#  'PromoInterval_Oct_min_da_prior': 10,
#  'Day_min_da_prior': 10,
#  '4_min_da_prior': 10,
#  '26_min_da_prior': 10,
#  '1_min_da_prior': 10,
#  'Sales_min_da_prior': 10,
#  '15_min_da_prior': 10,
#  'PromoInterval_Aug_min_da_prior': 10,
#  '7_min_da_prior': 10,
#  'PromoInterval_Apr_min_da_prior': 10,
#  'PromoInterval_Jul_min_da_prior': 10,
#  '5_min_da_prior': 10,
#  'PromoInterval_Nov_min_da_prior': 10,
#  'WeekOfYear_min_da_prior': 10,
#  '3_min_da_prior': 10,
#  'SalesPerCustomer_min_da_prior': 10,
#  '22_min_da_prior': 10,
#  '24_min_da_prior': 10,
#  'Month_min_da_prior': 10,
#  'PromoInterval_Feb_min_da_prior': 10,
#  'Promo2SinceWeek_min_da_prior': 10,
#  '11_min_da_prior': 10,
#  '20_min_da_prior': 10,
#  '10_min_da_prior': 10,
#  'PromoInterval_Dec_min_da_prior': 10,
#  'PromoInterval_Jan_min_da_prior': 10,
#  'Promo_min_da_prior': 10,
#  'PromoInterval_Sept_min_da_prior': 10,
#  'Customers_min_da_prior': 10,
#  'CompetitionOpenSinceYear_min_da_prior': 10,
#  'Date_min_da_prior': 10,
#  '8_min_da_prior': 10,
#  '17_min_da_prior': 10,
#  '23_min_da_prior': 10,
#  'PromoInterval_May_min_da_prior': 10,
#  '19_min_da_prior': 10,
#  'DayOfWeek_min_da_prior': 10,
#  'Year_min_da_prior': 10,
#  'PromoInterval_Jun_min_da_prior': 10,
#  '14_min_da_prior': 10,
#  '25_count_da_prior': 10,
#  'CompetitionOpenSinceMonth_count_da_prior': 10,
#  'CompetitionDistance_count_da_prior': 10,
#  '9_count_da_prior': 10,
#  '12_count_da_prior': 10,
#  'SchoolHoliday_count_da_prior': 10,
#  'Promo2_count_da_prior': 10,
#  'PromoInterval_Mar_count_da_prior': 10,
#  'Promo2SinceYear_count_da_prior': 10,
#  '2_count_da_prior': 10,
#  '6_count_da_prior': 10,
#  '13_count_da_prior': 10,
#  '21_count_da_prior': 10,
#  '0_count_da_prior': 10,
#  '16_count_da_prior': 10,
#  '18_count_da_prior': 10,
#  'PromoInterval_Oct_count_da_prior': 10,
#  'Day_count_da_prior': 10,
#  '4_count_da_prior': 10,
#  '26_count_da_prior': 10,
#  '1_count_da_prior': 10,
#  'Sales_count_da_prior': 10,
#  '15_count_da_prior': 10,
#  'PromoInterval_Aug_count_da_prior': 10,
#  '7_count_da_prior': 10,
#  'PromoInterval_Apr_count_da_prior': 10,
#  'PromoInterval_Jul_count_da_prior': 10,
#  '5_count_da_prior': 10,
#  'PromoInterval_Nov_count_da_prior': 10,
#  'WeekOfYear_count_da_prior': 10,
#  '3_count_da_prior': 10,
#  'SalesPerCustomer_count_da_prior': 10,
#  '22_count_da_prior': 10,
#  '24_count_da_prior': 10,
#  'Month_count_da_prior': 10,
#  'PromoInterval_Feb_count_da_prior': 10,
#  'Promo2SinceWeek_count_da_prior': 10,
#  '11_count_da_prior': 10,
#  '20_count_da_prior': 10,
#  '10_count_da_prior': 10,
#  'PromoInterval_Dec_count_da_prior': 10,
#  'PromoInterval_Jan_count_da_prior': 10,
#  'Promo_count_da_prior': 10,
#  'PromoInterval_Sept_count_da_prior': 10,
#  'Customers_count_da_prior': 10,
#  'CompetitionOpenSinceYear_count_da_prior': 10,
#  'Date_count_da_prior': 10,
#  '8_count_da_prior': 10,
#  '17_count_da_prior': 10,
#  '23_count_da_prior': 10,
#  'PromoInterval_May_count_da_prior': 10,
#  '19_count_da_prior': 10,
#  'DayOfWeek_count_da_prior': 10,
#  'Year_count_da_prior': 10,
#  'PromoInterval_Jun_count_da_prior': 10,
#  '14_count_da_prior': 10,
#  '25_mean_da_prior': 10,
#  'CompetitionOpenSinceMonth_mean_da_prior': 10,
#  'CompetitionDistance_mean_da_prior': 10,
#  '9_mean_da_prior': 10,
#  '12_mean_da_prior': 10,
#  'SchoolHoliday_mean_da_prior': 10,
#  'Promo2_mean_da_prior': 10,
#  'PromoInterval_Mar_mean_da_prior': 10,
#  'Promo2SinceYear_mean_da_prior': 10,
#  '2_mean_da_prior': 10,
#  '6_mean_da_prior': 10,
#  '13_mean_da_prior': 10,
#  '21_mean_da_prior': 10,
#  '0_mean_da_prior': 10,
#  '16_mean_da_prior': 10,
#  '18_mean_da_prior': 10,
#  'PromoInterval_Oct_mean_da_prior': 10,
#  'Day_mean_da_prior': 10,
#  '4_mean_da_prior': 10,
#  '26_mean_da_prior': 10,
#  '1_mean_da_prior': 10,
#  'Sales_mean_da_prior': 10,
#  '15_mean_da_prior': 10,
#  'PromoInterval_Aug_mean_da_prior': 10,
#  '7_mean_da_prior': 10,
#  'PromoInterval_Apr_mean_da_prior': 10,
#  'PromoInterval_Jul_mean_da_prior': 10,
#  '5_mean_da_prior': 10,
#  'PromoInterval_Nov_mean_da_prior': 10,
#  'WeekOfYear_mean_da_prior': 10,
#  '3_mean_da_prior': 10,
#  'SalesPerCustomer_mean_da_prior': 10,
#  '22_mean_da_prior': 10,
#  '24_mean_da_prior': 10,
#  'Month_mean_da_prior': 10,
#  'PromoInterval_Feb_mean_da_prior': 10,
#  'Promo2SinceWeek_mean_da_prior': 10,
#  '11_mean_da_prior': 10,
#  '20_mean_da_prior': 10,
#  '10_mean_da_prior': 10,
#  'PromoInterval_Dec_mean_da_prior': 10,
#  'PromoInterval_Jan_mean_da_prior': 10,
#  'Promo_mean_da_prior': 10,
#  'PromoInterval_Sept_mean_da_prior': 10,
#  'Customers_mean_da_prior': 10,
#  'CompetitionOpenSinceYear_mean_da_prior': 10,
#  'Date_mean_da_prior': 10,
#  '8_mean_da_prior': 10,
#  '17_mean_da_prior': 10,
#  '23_mean_da_prior': 10,
#  'PromoInterval_May_mean_da_prior': 10,
#  '19_mean_da_prior': 10,
#  'DayOfWeek_mean_da_prior': 10,
#  'Year_mean_da_prior': 10,
#  'PromoInterval_Jun_mean_da_prior': 10,
#  '14_mean_da_prior': 10,
#  '25_max_cc_prior': 10,
#  'CompetitionOpenSinceMonth_max_cc_prior': 10,
#  'CompetitionDistance_max_cc_prior': 10,
#  '9_max_cc_prior': 10,
#  '12_max_cc_prior': 10,
#  'SchoolHoliday_max_cc_prior': 10,
#  'Promo2_max_cc_prior': 10,
#  'PromoInterval_Mar_max_cc_prior': 10,
#  'Promo2SinceYear_max_cc_prior': 10,
#  '2_max_cc_prior': 10,
#  '6_max_cc_prior': 10,
#  '13_max_cc_prior': 10,
#  '21_max_cc_prior': 10,
#  '0_max_cc_prior': 10,
#  '16_max_cc_prior': 10,
#  '18_max_cc_prior': 10,
#  'PromoInterval_Oct_max_cc_prior': 10,
#  'Day_max_cc_prior': 10,
#  '4_max_cc_prior': 10,
#  '26_max_cc_prior': 10,
#  '1_max_cc_prior': 10,
#  'Sales_max_cc_prior': 10,
#  '15_max_cc_prior': 10,
#  'PromoInterval_Aug_max_cc_prior': 10,
#  '7_max_cc_prior': 10,
#  'PromoInterval_Apr_max_cc_prior': 10,
#  'PromoInterval_Jul_max_cc_prior': 10,
#  '5_max_cc_prior': 10,
#  'PromoInterval_Nov_max_cc_prior': 10,
#  'WeekOfYear_max_cc_prior': 10,
#  '3_max_cc_prior': 10,
#  'SalesPerCustomer_max_cc_prior': 10,
#  '22_max_cc_prior': 10,
#  '24_max_cc_prior': 10,
#  'Month_max_cc_prior': 10,
#  'PromoInterval_Feb_max_cc_prior': 10,
#  'Promo2SinceWeek_max_cc_prior': 10,
#  '11_max_cc_prior': 10,
#  '20_max_cc_prior': 10,
#  '10_max_cc_prior': 10,
#  'PromoInterval_Dec_max_cc_prior': 10,
#  'PromoInterval_Jan_max_cc_prior': 10,
#  'Promo_max_cc_prior': 10,
#  'PromoInterval_Sept_max_cc_prior': 10,
#  'Customers_max_cc_prior': 10,
#  'CompetitionOpenSinceYear_max_cc_prior': 10,
#  'Date_max_cc_prior': 10,
#  '8_max_cc_prior': 10,
#  '17_max_cc_prior': 10,
#  '23_max_cc_prior': 10,
#  'PromoInterval_May_max_cc_prior': 10,
#  '19_max_cc_prior': 10,
#  'DayOfWeek_max_cc_prior': 10,
#  'Year_max_cc_prior': 10,
#  'PromoInterval_Jun_max_cc_prior': 10,
#  '14_max_cc_prior': 10,
#  '25_min_cc_prior': 10,
#  'CompetitionOpenSinceMonth_min_cc_prior': 10,
#  'CompetitionDistance_min_cc_prior': 10,
#  '9_min_cc_prior': 10,
#  '12_min_cc_prior': 10,
#  'SchoolHoliday_min_cc_prior': 10,
#  'Promo2_min_cc_prior': 10,
#  'PromoInterval_Mar_min_cc_prior': 10,
#  'Promo2SinceYear_min_cc_prior': 10,
#  '2_min_cc_prior': 10,
#  '6_min_cc_prior': 10,
#  '13_min_cc_prior': 10,
#  '21_min_cc_prior': 10,
#  '0_min_cc_prior': 10,
#  '16_min_cc_prior': 10,
#  '18_min_cc_prior': 10,
#  'PromoInterval_Oct_min_cc_prior': 10,
#  'Day_min_cc_prior': 10,
#  '4_min_cc_prior': 10,
#  '26_min_cc_prior': 10,
#  '1_min_cc_prior': 10,
#  'Sales_min_cc_prior': 10,
#  '15_min_cc_prior': 10,
#  'PromoInterval_Aug_min_cc_prior': 10,
#  '7_min_cc_prior': 10,
#  'PromoInterval_Apr_min_cc_prior': 10,
#  'PromoInterval_Jul_min_cc_prior': 10,
#  '5_min_cc_prior': 10,
#  'PromoInterval_Nov_min_cc_prior': 10,
#  'WeekOfYear_min_cc_prior': 10,
#  '3_min_cc_prior': 10,
#  'SalesPerCustomer_min_cc_prior': 10,
#  '22_min_cc_prior': 10,
#  '24_min_cc_prior': 10,
#  'Month_min_cc_prior': 10,
#  'PromoInterval_Feb_min_cc_prior': 10,
#  'Promo2SinceWeek_min_cc_prior': 10,
#  '11_min_cc_prior': 10,
#  '20_min_cc_prior': 10,
#  '10_min_cc_prior': 10,
#  'PromoInterval_Dec_min_cc_prior': 10,
#  'PromoInterval_Jan_min_cc_prior': 10,
#  'Promo_min_cc_prior': 10,
#  'PromoInterval_Sept_min_cc_prior': 10,
#  'Customers_min_cc_prior': 10,
#  'CompetitionOpenSinceYear_min_cc_prior': 10,
#  'Date_min_cc_prior': 10,
#  '8_min_cc_prior': 10,
#  '17_min_cc_prior': 10,
#  '23_min_cc_prior': 10,
#  'PromoInterval_May_min_cc_prior': 10,
#  '19_min_cc_prior': 10,
#  'DayOfWeek_min_cc_prior': 10,
#  'Year_min_cc_prior': 10,
#  'PromoInterval_Jun_min_cc_prior': 10,
#  '14_min_cc_prior': 10,
#  '25_count_cc_prior': 10,
#  'CompetitionOpenSinceMonth_count_cc_prior': 10,
#  'CompetitionDistance_count_cc_prior': 10,
#  '9_count_cc_prior': 10,
#  '12_count_cc_prior': 10,
#  'SchoolHoliday_count_cc_prior': 10,
#  'Promo2_count_cc_prior': 10,
#  'PromoInterval_Mar_count_cc_prior': 10,
#  'Promo2SinceYear_count_cc_prior': 10,
#  '2_count_cc_prior': 10,
#  '6_count_cc_prior': 10,
#  '13_count_cc_prior': 10,
#  '21_count_cc_prior': 10,
#  '0_count_cc_prior': 10,
#  '16_count_cc_prior': 10,
#  '18_count_cc_prior': 10,
#  'PromoInterval_Oct_count_cc_prior': 10,
#  'Day_count_cc_prior': 10,
#  '4_count_cc_prior': 10,
#  '26_count_cc_prior': 10,
#  '1_count_cc_prior': 10,
#  'Sales_count_cc_prior': 10,
#  '15_count_cc_prior': 10,
#  'PromoInterval_Aug_count_cc_prior': 10,
#  '7_count_cc_prior': 10,
#  'PromoInterval_Apr_count_cc_prior': 10,
#  'PromoInterval_Jul_count_cc_prior': 10,
#  '5_count_cc_prior': 10,
#  'PromoInterval_Nov_count_cc_prior': 10,
#  'WeekOfYear_count_cc_prior': 10,
#  '3_count_cc_prior': 10,
#  'SalesPerCustomer_count_cc_prior': 10,
#  '22_count_cc_prior': 10,
#  '24_count_cc_prior': 10,
#  'Month_count_cc_prior': 10,
#  'PromoInterval_Feb_count_cc_prior': 10,
#  'Promo2SinceWeek_count_cc_prior': 10,
#  '11_count_cc_prior': 10,
#  '20_count_cc_prior': 10,
#  '10_count_cc_prior': 10,
#  'PromoInterval_Dec_count_cc_prior': 10,
#  'PromoInterval_Jan_count_cc_prior': 10,
#  'Promo_count_cc_prior': 10,
#  'PromoInterval_Sept_count_cc_prior': 10,
#  'Customers_count_cc_prior': 10,
#  'CompetitionOpenSinceYear_count_cc_prior': 10,
#  'Date_count_cc_prior': 10,
#  '8_count_cc_prior': 10,
#  '17_count_cc_prior': 10,
#  '23_count_cc_prior': 10,
#  'PromoInterval_May_count_cc_prior': 10,
#  '19_count_cc_prior': 10,
#  'DayOfWeek_count_cc_prior': 10,
#  'Year_count_cc_prior': 10,
#  'PromoInterval_Jun_count_cc_prior': 10,
#  '14_count_cc_prior': 10,
#  '25_mean_cc_prior': 10,
#  'CompetitionOpenSinceMonth_mean_cc_prior': 10,
#  'CompetitionDistance_mean_cc_prior': 10,
#  '9_mean_cc_prior': 10,
#  '12_mean_cc_prior': 10,
#  'SchoolHoliday_mean_cc_prior': 10,
#  'Promo2_mean_cc_prior': 10,
#  'PromoInterval_Mar_mean_cc_prior': 10,
#  'Promo2SinceYear_mean_cc_prior': 10,
#  '2_mean_cc_prior': 10,
#  '6_mean_cc_prior': 10,
#  '13_mean_cc_prior': 10,
#  '21_mean_cc_prior': 10,
#  '0_mean_cc_prior': 10,
#  '16_mean_cc_prior': 10,
#  '18_mean_cc_prior': 10,
#  'PromoInterval_Oct_mean_cc_prior': 10,
#  'Day_mean_cc_prior': 10,
#  '4_mean_cc_prior': 10,
#  '26_mean_cc_prior': 10,
#  '1_mean_cc_prior': 10,
#  'Sales_mean_cc_prior': 10,
#  '15_mean_cc_prior': 10,
#  'PromoInterval_Aug_mean_cc_prior': 10,
#  '7_mean_cc_prior': 10,
#  'PromoInterval_Apr_mean_cc_prior': 10,
#  'PromoInterval_Jul_mean_cc_prior': 10,
#  '5_mean_cc_prior': 10,
#  'PromoInterval_Nov_mean_cc_prior': 10,
#  'WeekOfYear_mean_cc_prior': 10,
#  '3_mean_cc_prior': 10,
#  'SalesPerCustomer_mean_cc_prior': 10,
#  '22_mean_cc_prior': 10,
#  '24_mean_cc_prior': 10,
#  'Month_mean_cc_prior': 10,
#  'PromoInterval_Feb_mean_cc_prior': 10,
#  'Promo2SinceWeek_mean_cc_prior': 10,
#  '11_mean_cc_prior': 10,
#  '20_mean_cc_prior': 10,
#  '10_mean_cc_prior': 10,
#  'PromoInterval_Dec_mean_cc_prior': 10,
#  'PromoInterval_Jan_mean_cc_prior': 10,
#  'Promo_mean_cc_prior': 10,
#  'PromoInterval_Sept_mean_cc_prior': 10,
#  'Customers_mean_cc_prior': 10,
#  'CompetitionOpenSinceYear_mean_cc_prior': 10,
#  'Date_mean_cc_prior': 10,
#  '8_mean_cc_prior': 10,
#  '17_mean_cc_prior': 10,
#  '23_mean_cc_prior': 10,
#  'PromoInterval_May_mean_cc_prior': 10,
#  '19_mean_cc_prior': 10,
#  'DayOfWeek_mean_cc_prior': 10,
#  'Year_mean_cc_prior': 10,
#  'PromoInterval_Jun_mean_cc_prior': 10,
#  '14_mean_cc_prior': 10,
#  '25_max_aa_prior': 10,
#  'CompetitionOpenSinceMonth_max_aa_prior': 10,
#  'CompetitionDistance_max_aa_prior': 10,
#  '9_max_aa_prior': 10,
#  '12_max_aa_prior': 10,
#  'SchoolHoliday_max_aa_prior': 10,
#  'Promo2_max_aa_prior': 10,
#  'PromoInterval_Mar_max_aa_prior': 10,
#  'Promo2SinceYear_max_aa_prior': 10,
#  '2_max_aa_prior': 10,
#  '6_max_aa_prior': 10,
#  '13_max_aa_prior': 10,
#  '21_max_aa_prior': 10,
#  '0_max_aa_prior': 10,
#  '16_max_aa_prior': 10,
#  '18_max_aa_prior': 10,
#  'PromoInterval_Oct_max_aa_prior': 10,
#  'Day_max_aa_prior': 10,
#  '4_max_aa_prior': 10,
#  '26_max_aa_prior': 10,
#  '1_max_aa_prior': 10,
#  'Sales_max_aa_prior': 10,
#  '15_max_aa_prior': 10,
#  'PromoInterval_Aug_max_aa_prior': 10,
#  '7_max_aa_prior': 10,
#  'PromoInterval_Apr_max_aa_prior': 10,
#  'PromoInterval_Jul_max_aa_prior': 10,
#  '5_max_aa_prior': 10,
#  'PromoInterval_Nov_max_aa_prior': 10,
#  'WeekOfYear_max_aa_prior': 10,
#  '3_max_aa_prior': 10,
#  'SalesPerCustomer_max_aa_prior': 10,
#  '22_max_aa_prior': 10,
#  '24_max_aa_prior': 10,
#  'Month_max_aa_prior': 10,
#  'PromoInterval_Feb_max_aa_prior': 10,
#  'Promo2SinceWeek_max_aa_prior': 10,
#  '11_max_aa_prior': 10,
#  '20_max_aa_prior': 10,
#  '10_max_aa_prior': 10,
#  'PromoInterval_Dec_max_aa_prior': 10,
#  'PromoInterval_Jan_max_aa_prior': 10,
#  'Promo_max_aa_prior': 10,
#  'PromoInterval_Sept_max_aa_prior': 10,
#  'Customers_max_aa_prior': 10,
#  'CompetitionOpenSinceYear_max_aa_prior': 10,
#  'Date_max_aa_prior': 10,
#  '8_max_aa_prior': 10,
#  '17_max_aa_prior': 10,
#  '23_max_aa_prior': 10,
#  'PromoInterval_May_max_aa_prior': 10,
#  '19_max_aa_prior': 10,
#  'DayOfWeek_max_aa_prior': 10,
#  'Year_max_aa_prior': 10,
#  'PromoInterval_Jun_max_aa_prior': 10,
#  '14_max_aa_prior': 10,
#  '25_min_aa_prior': 10,
#  'CompetitionOpenSinceMonth_min_aa_prior': 10,
#  'CompetitionDistance_min_aa_prior': 10,
#  '9_min_aa_prior': 10,
#  '12_min_aa_prior': 10,
#  'SchoolHoliday_min_aa_prior': 10,
#  'Promo2_min_aa_prior': 10,
#  'PromoInterval_Mar_min_aa_prior': 10,
#  'Promo2SinceYear_min_aa_prior': 10,
#  '2_min_aa_prior': 10,
#  '6_min_aa_prior': 10,
#  '13_min_aa_prior': 10,
#  '21_min_aa_prior': 10,
#  '0_min_aa_prior': 10,
#  '16_min_aa_prior': 10,
#  '18_min_aa_prior': 10,
#  'PromoInterval_Oct_min_aa_prior': 10,
#  'Day_min_aa_prior': 10,
#  '4_min_aa_prior': 10,
#  '26_min_aa_prior': 10,
#  '1_min_aa_prior': 10,
#  'Sales_min_aa_prior': 10,
#  '15_min_aa_prior': 10,
#  'PromoInterval_Aug_min_aa_prior': 10,
#  '7_min_aa_prior': 10,
#  'PromoInterval_Apr_min_aa_prior': 10,
#  'PromoInterval_Jul_min_aa_prior': 10,
#  '5_min_aa_prior': 10,
#  'PromoInterval_Nov_min_aa_prior': 10,
#  'WeekOfYear_min_aa_prior': 10,
#  '3_min_aa_prior': 10,
#  'SalesPerCustomer_min_aa_prior': 10,
#  '22_min_aa_prior': 10,
#  '24_min_aa_prior': 10,
#  'Month_min_aa_prior': 10,
#  'PromoInterval_Feb_min_aa_prior': 10,
#  'Promo2SinceWeek_min_aa_prior': 10,
#  '11_min_aa_prior': 10,
#  '20_min_aa_prior': 10,
#  '10_min_aa_prior': 10,
#  'PromoInterval_Dec_min_aa_prior': 10,
#  'PromoInterval_Jan_min_aa_prior': 10,
#  'Promo_min_aa_prior': 10,
#  'PromoInterval_Sept_min_aa_prior': 10,
#  'Customers_min_aa_prior': 10,
#  'CompetitionOpenSinceYear_min_aa_prior': 10,
#  'Date_min_aa_prior': 10,
#  '8_min_aa_prior': 10,
#  '17_min_aa_prior': 10,
#  '23_min_aa_prior': 10,
#  'PromoInterval_May_min_aa_prior': 10,
#  '19_min_aa_prior': 10,
#  'DayOfWeek_min_aa_prior': 10,
#  'Year_min_aa_prior': 10,
#  'PromoInterval_Jun_min_aa_prior': 10,
#  '14_min_aa_prior': 10,
#  '25_count_aa_prior': 10,
#  'CompetitionOpenSinceMonth_count_aa_prior': 10,
#  'CompetitionDistance_count_aa_prior': 10,
#  '9_count_aa_prior': 10,
#  '12_count_aa_prior': 10,
#  'SchoolHoliday_count_aa_prior': 10,
#  'Promo2_count_aa_prior': 10,
#  'PromoInterval_Mar_count_aa_prior': 10,
#  'Promo2SinceYear_count_aa_prior': 10,
#  '2_count_aa_prior': 10,
#  '6_count_aa_prior': 10,
#  '13_count_aa_prior': 10,
#  '21_count_aa_prior': 10,
#  '0_count_aa_prior': 10,
#  '16_count_aa_prior': 10,
#  '18_count_aa_prior': 10,
#  'PromoInterval_Oct_count_aa_prior': 10,
#  'Day_count_aa_prior': 10,
#  '4_count_aa_prior': 10,
#  '26_count_aa_prior': 10,
#  '1_count_aa_prior': 10,
#  'Sales_count_aa_prior': 10,
#  '15_count_aa_prior': 10,
#  'PromoInterval_Aug_count_aa_prior': 10,
#  '7_count_aa_prior': 10,
#  'PromoInterval_Apr_count_aa_prior': 10,
#  'PromoInterval_Jul_count_aa_prior': 10,
#  '5_count_aa_prior': 10,
#  'PromoInterval_Nov_count_aa_prior': 10,
#  'WeekOfYear_count_aa_prior': 10,
#  '3_count_aa_prior': 10,
#  'SalesPerCustomer_count_aa_prior': 10,
#  '22_count_aa_prior': 10,
#  '24_count_aa_prior': 10,
#  'Month_count_aa_prior': 10,
#  'PromoInterval_Feb_count_aa_prior': 10,
#  'Promo2SinceWeek_count_aa_prior': 10,
#  '11_count_aa_prior': 10,
#  '20_count_aa_prior': 10,
#  '10_count_aa_prior': 10,
#  'PromoInterval_Dec_count_aa_prior': 10,
#  'PromoInterval_Jan_count_aa_prior': 10,
#  'Promo_count_aa_prior': 10,
#  'PromoInterval_Sept_count_aa_prior': 10,
#  'Customers_count_aa_prior': 10,
#  'CompetitionOpenSinceYear_count_aa_prior': 10,
#  'Date_count_aa_prior': 10,
#  '8_count_aa_prior': 10,
#  '17_count_aa_prior': 10,
#  '23_count_aa_prior': 10,
#  'PromoInterval_May_count_aa_prior': 10,
#  '19_count_aa_prior': 10,
#  'DayOfWeek_count_aa_prior': 10,
#  'Year_count_aa_prior': 10,
#  'PromoInterval_Jun_count_aa_prior': 10,
#  '14_count_aa_prior': 10,
#  '25_mean_aa_prior': 10,
#  'CompetitionOpenSinceMonth_mean_aa_prior': 10,
#  'CompetitionDistance_mean_aa_prior': 10,
#  '9_mean_aa_prior': 10,
#  '12_mean_aa_prior': 10,
#  'SchoolHoliday_mean_aa_prior': 10,
#  'Promo2_mean_aa_prior': 10,
#  'PromoInterval_Mar_mean_aa_prior': 10,
#  'Promo2SinceYear_mean_aa_prior': 10,
#  '2_mean_aa_prior': 10,
#  '6_mean_aa_prior': 10,
#  '13_mean_aa_prior': 10,
#  '21_mean_aa_prior': 10,
#  '0_mean_aa_prior': 10,
#  '16_mean_aa_prior': 10,
#  '18_mean_aa_prior': 10,
#  'PromoInterval_Oct_mean_aa_prior': 10,
#  'Day_mean_aa_prior': 10,
#  '4_mean_aa_prior': 10,
#  '26_mean_aa_prior': 10,
#  '1_mean_aa_prior': 10,
#  'Sales_mean_aa_prior': 10,
#  '15_mean_aa_prior': 10,
#  'PromoInterval_Aug_mean_aa_prior': 10,
#  '7_mean_aa_prior': 10,
#  'PromoInterval_Apr_mean_aa_prior': 10,
#  'PromoInterval_Jul_mean_aa_prior': 10,
#  '5_mean_aa_prior': 10,
#  'PromoInterval_Nov_mean_aa_prior': 10,
#  'WeekOfYear_mean_aa_prior': 10,
#  '3_mean_aa_prior': 10,
#  'SalesPerCustomer_mean_aa_prior': 10,
#  '22_mean_aa_prior': 10,
#  '24_mean_aa_prior': 10,
#  'Month_mean_aa_prior': 10,
#  'PromoInterval_Feb_mean_aa_prior': 10,
#  'Promo2SinceWeek_mean_aa_prior': 10,
#  '11_mean_aa_prior': 10,
#  '20_mean_aa_prior': 10,
#  '10_mean_aa_prior': 10,
#  'PromoInterval_Dec_mean_aa_prior': 10,
#  'PromoInterval_Jan_mean_aa_prior': 10,
#  'Promo_mean_aa_prior': 10,
#  'PromoInterval_Sept_mean_aa_prior': 10,
#  'Customers_mean_aa_prior': 10,
#  'CompetitionOpenSinceYear_mean_aa_prior': 10,
#  'Date_mean_aa_prior': 10,
#  '8_mean_aa_prior': 10,
#  '17_mean_aa_prior': 10,
#  '23_mean_aa_prior': 10,
#  'PromoInterval_May_mean_aa_prior': 10,
#  '19_mean_aa_prior': 10,
#  'DayOfWeek_mean_aa_prior': 10,
#  'Year_mean_aa_prior': 10,
#  'PromoInterval_Jun_mean_aa_prior': 10,
#  '14_mean_aa_prior': 10,
#  '25_max_ac_prior': 10,
#  'CompetitionOpenSinceMonth_max_ac_prior': 10,
#  'CompetitionDistance_max_ac_prior': 10,
#  '9_max_ac_prior': 10,
#  '12_max_ac_prior': 10,
#  'SchoolHoliday_max_ac_prior': 10,
#  'Promo2_max_ac_prior': 10,
#  'PromoInterval_Mar_max_ac_prior': 10,
#  'Promo2SinceYear_max_ac_prior': 10,
#  '2_max_ac_prior': 10,
#  '6_max_ac_prior': 10,
#  '13_max_ac_prior': 10,
#  '21_max_ac_prior': 10,
#  '0_max_ac_prior': 10,
#  '16_max_ac_prior': 10,
#  '18_max_ac_prior': 10,
#  'PromoInterval_Oct_max_ac_prior': 10,
#  'Day_max_ac_prior': 10,
#  '4_max_ac_prior': 10,
#  '26_max_ac_prior': 10,
#  '1_max_ac_prior': 10,
#  'Sales_max_ac_prior': 10,
#  '15_max_ac_prior': 10,
#  'PromoInterval_Aug_max_ac_prior': 10,
#  '7_max_ac_prior': 10,
#  'PromoInterval_Apr_max_ac_prior': 10,
#  'PromoInterval_Jul_max_ac_prior': 10,
#  '5_max_ac_prior': 10,
#  'PromoInterval_Nov_max_ac_prior': 10,
#  'WeekOfYear_max_ac_prior': 10,
#  '3_max_ac_prior': 10,
#  'SalesPerCustomer_max_ac_prior': 10,
#  '22_max_ac_prior': 10,
#  '24_max_ac_prior': 10,
#  'Month_max_ac_prior': 10,
#  'PromoInterval_Feb_max_ac_prior': 10,
#  'Promo2SinceWeek_max_ac_prior': 10,
#  '11_max_ac_prior': 10,
#  '20_max_ac_prior': 10,
#  '10_max_ac_prior': 10,
#  'PromoInterval_Dec_max_ac_prior': 10,
#  'PromoInterval_Jan_max_ac_prior': 10,
#  'Promo_max_ac_prior': 10,
#  'PromoInterval_Sept_max_ac_prior': 10,
#  'Customers_max_ac_prior': 10,
#  'CompetitionOpenSinceYear_max_ac_prior': 10,
#  'Date_max_ac_prior': 10,
#  '8_max_ac_prior': 10,
#  '17_max_ac_prior': 10,
#  '23_max_ac_prior': 10,
#  'PromoInterval_May_max_ac_prior': 10,
#  '19_max_ac_prior': 10,
#  'DayOfWeek_max_ac_prior': 10,
#  'Year_max_ac_prior': 10,
#  'PromoInterval_Jun_max_ac_prior': 10,
#  '14_max_ac_prior': 10,
#  '25_min_ac_prior': 10,
#  'CompetitionOpenSinceMonth_min_ac_prior': 10,
#  'CompetitionDistance_min_ac_prior': 10,
#  '9_min_ac_prior': 10,
#  '12_min_ac_prior': 10,
#  'SchoolHoliday_min_ac_prior': 10,
#  'Promo2_min_ac_prior': 10,
#  'PromoInterval_Mar_min_ac_prior': 10,
#  'Promo2SinceYear_min_ac_prior': 10,
#  '2_min_ac_prior': 10,
#  '6_min_ac_prior': 10,
#  '13_min_ac_prior': 10,
#  '21_min_ac_prior': 10,
#  '0_min_ac_prior': 10,
#  '16_min_ac_prior': 10,
#  '18_min_ac_prior': 10,
#  'PromoInterval_Oct_min_ac_prior': 10,
#  'Day_min_ac_prior': 10,
#  '4_min_ac_prior': 10,
#  '26_min_ac_prior': 10,
#  '1_min_ac_prior': 10,
#  'Sales_min_ac_prior': 10,
#  '15_min_ac_prior': 10,
#  'PromoInterval_Aug_min_ac_prior': 10,
#  '7_min_ac_prior': 10,
#  'PromoInterval_Apr_min_ac_prior': 10,
#  'PromoInterval_Jul_min_ac_prior': 10,
#  '5_min_ac_prior': 10,
#  'PromoInterval_Nov_min_ac_prior': 10,
#  'WeekOfYear_min_ac_prior': 10,
#  '3_min_ac_prior': 10,
#  'SalesPerCustomer_min_ac_prior': 10,
#  '22_min_ac_prior': 10,
#  '24_min_ac_prior': 10,
#  'Month_min_ac_prior': 10,
#  'PromoInterval_Feb_min_ac_prior': 10,
#  'Promo2SinceWeek_min_ac_prior': 10,
#  '11_min_ac_prior': 10,
#  '20_min_ac_prior': 10,
#  '10_min_ac_prior': 10,
#  'PromoInterval_Dec_min_ac_prior': 10,
#  'PromoInterval_Jan_min_ac_prior': 10,
#  'Promo_min_ac_prior': 10,
#  'PromoInterval_Sept_min_ac_prior': 10,
#  'Customers_min_ac_prior': 10,
#  'CompetitionOpenSinceYear_min_ac_prior': 10,
#  'Date_min_ac_prior': 10,
#  '8_min_ac_prior': 10,
#  '17_min_ac_prior': 10,
#  '23_min_ac_prior': 10,
#  'PromoInterval_May_min_ac_prior': 10,
#  '19_min_ac_prior': 10,
#  'DayOfWeek_min_ac_prior': 10,
#  'Year_min_ac_prior': 10,
#  'PromoInterval_Jun_min_ac_prior': 10,
#  '14_min_ac_prior': 10,
#  '25_count_ac_prior': 10,
#  'CompetitionOpenSinceMonth_count_ac_prior': 10,
#  'CompetitionDistance_count_ac_prior': 10,
#  '9_count_ac_prior': 10,
#  '12_count_ac_prior': 10,
#  'SchoolHoliday_count_ac_prior': 10,
#  'Promo2_count_ac_prior': 10,
#  'PromoInterval_Mar_count_ac_prior': 10,
#  'Promo2SinceYear_count_ac_prior': 10,
#  '2_count_ac_prior': 10,
#  '6_count_ac_prior': 10,
#  '13_count_ac_prior': 10,
#  '21_count_ac_prior': 10,
#  '0_count_ac_prior': 10,
#  '16_count_ac_prior': 10,
#  '18_count_ac_prior': 10,
#  'PromoInterval_Oct_count_ac_prior': 10,
#  'Day_count_ac_prior': 10,
#  '4_count_ac_prior': 10,
#  '26_count_ac_prior': 10,
#  '1_count_ac_prior': 10,
#  'Sales_count_ac_prior': 10,
#  '15_count_ac_prior': 10,
#  'PromoInterval_Aug_count_ac_prior': 10,
#  '7_count_ac_prior': 10,
#  'PromoInterval_Apr_count_ac_prior': 10,
#  'PromoInterval_Jul_count_ac_prior': 10,
#  '5_count_ac_prior': 10,
#  'PromoInterval_Nov_count_ac_prior': 10,
#  'WeekOfYear_count_ac_prior': 10,
#  '3_count_ac_prior': 10,
#  'SalesPerCustomer_count_ac_prior': 10,
#  '22_count_ac_prior': 10,
#  '24_count_ac_prior': 10,
#  'Month_count_ac_prior': 10,
#  'PromoInterval_Feb_count_ac_prior': 10,
#  'Promo2SinceWeek_count_ac_prior': 10,
#  '11_count_ac_prior': 10,
#  '20_count_ac_prior': 10,
#  '10_count_ac_prior': 10,
#  'PromoInterval_Dec_count_ac_prior': 10,
#  'PromoInterval_Jan_count_ac_prior': 10,
#  'Promo_count_ac_prior': 10,
#  'PromoInterval_Sept_count_ac_prior': 10,
#  'Customers_count_ac_prior': 10,
#  'CompetitionOpenSinceYear_count_ac_prior': 10,
#  'Date_count_ac_prior': 10,
#  '8_count_ac_prior': 10,
#  '17_count_ac_prior': 10,
#  '23_count_ac_prior': 10,
#  'PromoInterval_May_count_ac_prior': 10,
#  '19_count_ac_prior': 10,
#  'DayOfWeek_count_ac_prior': 10,
#  'Year_count_ac_prior': 10,
#  'PromoInterval_Jun_count_ac_prior': 10,
#  '14_count_ac_prior': 10,
#  '25_mean_ac_prior': 10,
#  'CompetitionOpenSinceMonth_mean_ac_prior': 10,
#  'CompetitionDistance_mean_ac_prior': 10,
#  '9_mean_ac_prior': 10,
#  '12_mean_ac_prior': 10,
#  'SchoolHoliday_mean_ac_prior': 10,
#  'Promo2_mean_ac_prior': 10,
#  'PromoInterval_Mar_mean_ac_prior': 10,
#  'Promo2SinceYear_mean_ac_prior': 10,
#  '2_mean_ac_prior': 10,
#  '6_mean_ac_prior': 10,
#  '13_mean_ac_prior': 10,
#  '21_mean_ac_prior': 10,
#  '0_mean_ac_prior': 10,
#  '16_mean_ac_prior': 10,
#  '18_mean_ac_prior': 10,
#  'PromoInterval_Oct_mean_ac_prior': 10,
#  'Day_mean_ac_prior': 10,
#  '4_mean_ac_prior': 10,
#  '26_mean_ac_prior': 10,
#  '1_mean_ac_prior': 10,
#  'Sales_mean_ac_prior': 10,
#  '15_mean_ac_prior': 10,
#  'PromoInterval_Aug_mean_ac_prior': 10,
#  '7_mean_ac_prior': 10,
#  'PromoInterval_Apr_mean_ac_prior': 10,
#  'PromoInterval_Jul_mean_ac_prior': 10,
#  '5_mean_ac_prior': 10,
#  'PromoInterval_Nov_mean_ac_prior': 10,
#  'WeekOfYear_mean_ac_prior': 10,
#  '3_mean_ac_prior': 10,
#  'SalesPerCustomer_mean_ac_prior': 10,
#  '22_mean_ac_prior': 10,
#  '24_mean_ac_prior': 10,
#  'Month_mean_ac_prior': 10,
#  'PromoInterval_Feb_mean_ac_prior': 10,
#  'Promo2SinceWeek_mean_ac_prior': 10,
#  '11_mean_ac_prior': 10,
#  '20_mean_ac_prior': 10,
#  '10_mean_ac_prior': 10,
#  'PromoInterval_Dec_mean_ac_prior': 10,
#  'PromoInterval_Jan_mean_ac_prior': 10,
#  'Promo_mean_ac_prior': 10,
#  'PromoInterval_Sept_mean_ac_prior': 10,
#  'Customers_mean_ac_prior': 10,
#  'CompetitionOpenSinceYear_mean_ac_prior': 10,
#  'Date_mean_ac_prior': 10,
#  '8_mean_ac_prior': 10,
#  '17_mean_ac_prior': 10,
#  '23_mean_ac_prior': 10,
#  'PromoInterval_May_mean_ac_prior': 10,
#  '19_mean_ac_prior': 10,
#  'DayOfWeek_mean_ac_prior': 10,
#  'Year_mean_ac_prior': 10,
#  'PromoInterval_Jun_mean_ac_prior': 10,
#  '14_mean_ac_prior': 10,
#  '25_max_ca_prior': 10,
#  'CompetitionOpenSinceMonth_max_ca_prior': 10,
#  'CompetitionDistance_max_ca_prior': 10,
#  '9_max_ca_prior': 10,
#  '12_max_ca_prior': 10,
#  'SchoolHoliday_max_ca_prior': 10,
#  'Promo2_max_ca_prior': 10,
#  'PromoInterval_Mar_max_ca_prior': 10,
#  'Promo2SinceYear_max_ca_prior': 10,
#  '2_max_ca_prior': 10,
#  '6_max_ca_prior': 10,
#  '13_max_ca_prior': 10,
#  '21_max_ca_prior': 10,
#  '0_max_ca_prior': 10,
#  '16_max_ca_prior': 10,
#  '18_max_ca_prior': 10,
#  'PromoInterval_Oct_max_ca_prior': 10,
#  'Day_max_ca_prior': 10,
#  '4_max_ca_prior': 10,
#  '26_max_ca_prior': 10,
#  '1_max_ca_prior': 10,
#  'Sales_max_ca_prior': 10,
#  '15_max_ca_prior': 10,
#  'PromoInterval_Aug_max_ca_prior': 10,
#  '7_max_ca_prior': 10,
#  'PromoInterval_Apr_max_ca_prior': 10,
#  'PromoInterval_Jul_max_ca_prior': 10,
#  '5_max_ca_prior': 10,
#  'PromoInterval_Nov_max_ca_prior': 10,
#  'WeekOfYear_max_ca_prior': 10,
#  '3_max_ca_prior': 10,
#  'SalesPerCustomer_max_ca_prior': 10,
#  '22_max_ca_prior': 10,
#  '24_max_ca_prior': 10,
#  'Month_max_ca_prior': 10,
#  'PromoInterval_Feb_max_ca_prior': 10,
#  'Promo2SinceWeek_max_ca_prior': 10,
#  '11_max_ca_prior': 10,
#  '20_max_ca_prior': 10,
#  '10_max_ca_prior': 10,
#  'PromoInterval_Dec_max_ca_prior': 10,
#  'PromoInterval_Jan_max_ca_prior': 10,
#  'Promo_max_ca_prior': 10,
#  'PromoInterval_Sept_max_ca_prior': 10,
#  'Customers_max_ca_prior': 10,
#  'CompetitionOpenSinceYear_max_ca_prior': 10,
#  'Date_max_ca_prior': 10,
#  '8_max_ca_prior': 10,
#  '17_max_ca_prior': 10,
#  '23_max_ca_prior': 10,
#  'PromoInterval_May_max_ca_prior': 10,
#  '19_max_ca_prior': 10,
#  'DayOfWeek_max_ca_prior': 10,
#  'Year_max_ca_prior': 10,
#  'PromoInterval_Jun_max_ca_prior': 10,
#  '14_max_ca_prior': 10,
#  '25_min_ca_prior': 10,
#  'CompetitionOpenSinceMonth_min_ca_prior': 10,
#  'CompetitionDistance_min_ca_prior': 10,
#  '9_min_ca_prior': 10,
#  '12_min_ca_prior': 10,
#  'SchoolHoliday_min_ca_prior': 10,
#  'Promo2_min_ca_prior': 10,
#  'PromoInterval_Mar_min_ca_prior': 10,
#  'Promo2SinceYear_min_ca_prior': 10,
#  '2_min_ca_prior': 10,
#  '6_min_ca_prior': 10,
#  '13_min_ca_prior': 10,
#  '21_min_ca_prior': 10,
#  '0_min_ca_prior': 10,
#  '16_min_ca_prior': 10,
#  '18_min_ca_prior': 10,
#  'PromoInterval_Oct_min_ca_prior': 10,
#  'Day_min_ca_prior': 10,
#  '4_min_ca_prior': 10,
#  '26_min_ca_prior': 10,
#  '1_min_ca_prior': 10,
#  'Sales_min_ca_prior': 10,
#  '15_min_ca_prior': 10,
#  'PromoInterval_Aug_min_ca_prior': 10,
#  '7_min_ca_prior': 10,
#  'PromoInterval_Apr_min_ca_prior': 10,
#  'PromoInterval_Jul_min_ca_prior': 10,
#  '5_min_ca_prior': 10,
#  'PromoInterval_Nov_min_ca_prior': 10,
#  'WeekOfYear_min_ca_prior': 10,
#  '3_min_ca_prior': 10,
#  'SalesPerCustomer_min_ca_prior': 10,
#  '22_min_ca_prior': 10,
#  '24_min_ca_prior': 10,
#  'Month_min_ca_prior': 10,
#  'PromoInterval_Feb_min_ca_prior': 10,
#  'Promo2SinceWeek_min_ca_prior': 10,
#  ...}

# %%
#score = object_func(set_default_dict)

# %%
#score
#### with reg score 0.08

# %%
#score
#### without reg score 0.15

# %%
from multiprocessing import Process, Pipe
import sys
import time

import hyperopt
import numpy as np

PY2 = sys.version_info[0] == 2
int_types = (int, long) if PY2 else (int,)


def is_integer(obj):
    return isinstance(obj, int_types + (np.integer,))


def is_number(obj, check_complex=False):
    types = ((float, complex, np.number) if check_complex else
             (float, np.floating))
    return is_integer(obj) or isinstance(obj, types)

def get_vals(trial):
    """Determine hyperparameter values given a ``Trial`` object"""
    # based on hyperopt/base.py:Trials:argmin
    return dict((k, v[0]) for k, v in trial['misc']['vals'].items() if v)


def wrap_cost(cost_fn, timeout=None, iters=1, verbose=0):
    """Wrap cost function to execute trials safely on a separate process.

    Parameters
    ----------
    cost_fn : callable
        The cost function (aka. objective function) to wrap. It follows the
        same specifications as normal Hyperopt cost functions.
    timeout : int
        Time to wait for process to complete, in seconds. If this time is
        reached, the process is re-tried if there are remaining iterations,
        otherwise marked as a failure. If ``None``, wait indefinitely.
    iters : int
        Number of times to allow the trial to timeout before marking it as
        a failure due to timeout.
    verbose : int
        How verbose this function should be. 0 is not verbose, 1 is verbose.

    Example
    -------
    def objective(args):
        case, val = args
        return val**2 if case else val

    space = [hp.choice('case', [False, True]), hp.uniform('val', -1, 1)]
    safe_objective = wrap_cost(objective, timeout=2, iters=2, verbose=1)
    best = hyperopt.fmin(safe_objective, space, max_evals=100)

    Notes
    -----
    Based on code from https://github.com/hyperopt/hyperopt-sklearn
    """
    def _cost_fn(*args, **kwargs):
        _conn = kwargs.pop('_conn')
        try:
            t_start = time.time()
            rval = cost_fn(*args, **kwargs)
            t_done = time.time()

            if not isinstance(rval, dict):
                rval = dict(loss=rval)
            assert 'loss' in rval, "Returned dictionary must include loss"
            loss = rval['loss']
            assert is_number(loss), "Returned loss must be a number type"
            rval.setdefault('status', hyperopt.STATUS_OK if np.isfinite(loss)
                            else hyperopt.STATUS_FAIL)
            rval.setdefault('duration', t_done - t_start)
            rtype = 'return'

        except Exception as exc:
            rval = exc
            rtype = 'raise'

        # -- return the result to calling process
        _conn.send((rtype, rval))

    def wrapper(*args, **kwargs):
        for k in range(iters):
            conn1, conn2 = Pipe()
            kwargs['_conn'] = conn2
            th = Process(target=_cost_fn, args=args, kwargs=kwargs)
            th.start()
            if conn1.poll(timeout):
                fn_rval = conn1.recv()
                th.join()
            else:
                if verbose >= 1:
                    print("TRIAL TIMED OUT (%d/%d)" % (k+1, iters))
                th.terminate()
                th.join()
                continue

            assert fn_rval[0] in ('raise', 'return')
            if fn_rval[0] == 'raise':
                raise fn_rval[1]
            else:
                return fn_rval[1]

        return {'status': hyperopt.STATUS_FAIL,
                'failure': 'timeout'}

    return wrapper

#### try two times
safe_objective = wrap_cost(object_func, timeout=500, iters=1, verbose=1)

# %%
from hyperopt import Trials
trials = Trials()

#### with calculate
def run_trials():
    import pickle
    trials_step = 1  # how many additional trials to do after loading saved trials. 1 = save after iteration
    max_trials = 1  # initial max_trials. put something small to not have to wait
    trials_path = "/kaggle/working/trials_mean_1_peak_100_prior.pkl"
    try:  # try to load an already saved trials object, and increase the max
        #trials = pickle.load(open("my_model.hyperopt", "rb"))x
        trials = pickle.load(open(trials_path, "rb"))
        print("Found saved Trials! Loading...")
        max_trials = len(trials.trials) + trials_step
        print("Rerunning from {} trials to {} (+{}) trials".format(len(trials.trials), max_trials, trials_step))
    except:  # create a new trials object and start searching
        trials = Trials()

    #best = fmin(fn=mymodel, space=model_space, algo=tpe.suggest, max_evals=max_trials, trials=trials)
    try:
        best_without_init = fmin(safe_objective, tiny_space, algo = tpe.suggest, max_evals = max_trials,  points_to_evaluate=[set_default_dict], 
                         trials = trials)
    except:
        print("Time Out !!!!")
        return
    print("Best:", best_without_init)
    
    # save the trials object
    with open(trials_path, "wb") as f:
        pickle.dump(trials, f)
        
    print("length : {}".format(len(trials)) + "!" * 100)

# loop indefinitely and stop whenever you like
'''
times = 0
while True:
    run_trials()
    times += 1 
    if times >= 3:
        break
'''
# Out:
# '\ntimes = 0\nwhile True:\n    run_trials()\n    times += 1 \n    if times >= 3:\n        break\n'

# %%
import pickle as pkl
with open("data/serlize_m_dict_bu_reg.pkl", "rb") as f:
    serlize_m_dict = pkl.load(f)

# %%
len(serlize_m_dict)
# Out:
# 97

# %%
import seaborn as sns
sns.distplot(list(serlize_m_dict.keys()))

# %%
best_key = min(serlize_m_dict.keys())

# %%
best_kw = serlize_m_dict[best_key][-1]

# %%
best_key
# Out:
# 0.06500640424790124

# %%
best_kw
# Out:
# {'0_count_aa_prior': 13.182567385564125,
#  '0_count_ac_prior': 50.11872336272754,
#  '0_count_ca_prior': 2.884031503126611,
#  '0_count_cc_prior': 1.096478196143185,
#  '0_count_da_prior': 95.4992586021443,
#  '0_count_dc_prior': 52.48074602497759,
#  '0_count_total_prior': 33.11311214825929,
#  '0_max_aa_prior': 9.549925860214394,
#  '0_max_ac_prior': 7.585775750291862,
#  '0_max_ca_prior': 1.0471285480508996,
#  '0_max_cc_prior': 1.3182567385564077,
#  '0_max_da_prior': 1.5848931924611147,
#  '0_max_dc_prior': 10.471285480509035,
#  '0_max_total_prior': 83.17637711026768,
#  '0_mean_aa_prior': 5.7543993733715855,
#  '0_mean_ac_prior': 3.981071705534981,
#  '0_mean_ca_prior': 7.244359600749924,
#  '0_mean_cc_prior': 31.622776601683967,
#  '0_mean_da_prior': 2.2908676527677763,
#  '0_mean_dc_prior': 43.65158322401686,
#  '0_mean_total_prior': 28.840315031266215,
#  '0_min_aa_prior': 1.2589254117941677,
#  '0_min_ac_prior': 5.49540873857626,
#  '0_min_ca_prior': 95.4992586021443,
#  '0_min_cc_prior': 20.892961308540496,
#  '0_min_da_prior': 9.549925860214394,
#  '0_min_dc_prior': 72.4435960074995,
#  '0_min_total_prior': 4.7863009232263956,
#  '10_count_aa_prior': 41.68693834703379,
#  '10_count_ac_prior': 14.454397707459336,
#  '10_count_ca_prior': 50.11872336272754,
#  '10_count_cc_prior': 5.24807460249774,
#  '10_count_da_prior': 8.709635899560837,
#  '10_count_dc_prior': 39.81071705534996,
#  '10_count_total_prior': 19.95262314968889,
#  '10_max_aa_prior': 1.3182567385564077,
#  '10_max_ac_prior': 57.543993733716064,
#  '10_max_ca_prior': 2.884031503126611,
#  '10_max_cc_prior': 2.089296130854042,
#  '10_max_da_prior': 1.148153621496883,
#  '10_max_dc_prior': 50.11872336272754,
#  '10_max_total_prior': 4.570881896148761,
#  '10_mean_aa_prior': 57.543993733716064,
#  '10_mean_ac_prior': 5.7543993733715855,
#  '10_mean_ca_prior': 45.70881896148778,
#  '10_mean_cc_prior': 1.659586907437562,
#  '10_mean_da_prior': 2.7542287033381707,
#  '10_mean_dc_prior': 36.30780547701034,
#  '10_mean_total_prior': 6.60693448007598,
#  '10_min_aa_prior': 6.60693448007598,
#  '10_min_ac_prior': 50.11872336272754,
#  '10_min_ca_prior': 39.81071705534996,
#  '10_min_cc_prior': 1.148153621496883,
#  '10_min_da_prior': 9.12010839355913,
#  '10_min_dc_prior': 14.454397707459336,
#  '10_min_total_prior': 7.585775750291862,
#  '11_count_aa_prior': 4.36515832240167,
#  '11_count_ac_prior': 72.4435960074995,
#  '11_count_ca_prior': 1.9952623149688817,
#  '11_count_cc_prior': 12.022644346174177,
#  '11_count_da_prior': 5.7543993733715855,
#  '11_count_dc_prior': 95.4992586021443,
#  '11_count_total_prior': 100.00000000000074,
#  '11_max_aa_prior': 5.49540873857626,
#  '11_max_ac_prior': 1.096478196143185,
#  '11_max_ca_prior': 2.884031503126611,
#  '11_max_cc_prior': 3.1622776601683853,
#  '11_max_da_prior': 69.18309709189411,
#  '11_max_dc_prior': 5.49540873857626,
#  '11_max_total_prior': 72.4435960074995,
#  '11_mean_aa_prior': 9.12010839355913,
#  '11_mean_ac_prior': 3.981071705534981,
#  '11_mean_ca_prior': 1.2589254117941677,
#  '11_mean_cc_prior': 2.884031503126611,
#  '11_mean_da_prior': 9.549925860214394,
#  '11_mean_dc_prior': 5.49540873857626,
#  '11_mean_total_prior': 1.3803842646028854,
#  '11_min_aa_prior': 95.4992586021443,
#  '11_min_ac_prior': 100.00000000000074,
#  '11_min_ca_prior': 1.4454397707459283,
#  '11_min_cc_prior': 2.187761623949555,
#  '11_min_da_prior': 95.4992586021443,
#  '11_min_dc_prior': 17.378008287493834,
#  '11_min_total_prior': 63.09573444801974,
#  '12_count_aa_prior': 66.06934480076004,
#  '12_count_ac_prior': 87.09635899560868,
#  '12_count_ca_prior': 5.7543993733715855,
#  '12_count_cc_prior': 17.378008287493834,
#  '12_count_da_prior': 47.863009232264126,
#  '12_count_dc_prior': 1.9054607179632492,
#  '12_count_total_prior': 11.481536214968871,
#  '12_max_aa_prior': 20.892961308540496,
#  '12_max_ac_prior': 45.70881896148778,
#  '12_max_ca_prior': 12.589254117941723,
#  '12_max_cc_prior': 5.24807460249774,
#  '12_max_da_prior': 9.12010839355913,
#  '12_max_dc_prior': 4.570881896148761,
#  '12_max_total_prior': 9.12010839355913,
#  '12_mean_aa_prior': 3.4673685045253233,
#  '12_mean_ac_prior': 1.096478196143185,
#  '12_mean_ca_prior': 12.022644346174177,
#  '12_mean_cc_prior': 1.9952623149688817,
#  '12_mean_da_prior': 23.988329190195024,
#  '12_mean_dc_prior': 5.24807460249774,
#  '12_mean_total_prior': 1.2022644346174132,
#  '12_min_aa_prior': 5.7543993733715855,
#  '12_min_ac_prior': 1.9054607179632492,
#  '12_min_ca_prior': 1.513561248436209,
#  '12_min_cc_prior': 50.11872336272754,
#  '12_min_da_prior': 2.5118864315095837,
#  '12_min_dc_prior': 5.24807460249774,
#  '12_min_total_prior': 19.95262314968889,
#  '13_count_aa_prior': 33.11311214825929,
#  '13_count_ac_prior': 36.30780547701034,
#  '13_count_ca_prior': 100.00000000000074,
#  '13_count_cc_prior': 21.877616239495634,
#  '13_count_da_prior': 2.089296130854042,
#  '13_count_dc_prior': 8.709635899560837,
#  '13_count_total_prior': 13.182567385564125,
#  '13_max_aa_prior': 2.089296130854042,
#  '13_max_ac_prior': 8.317637711026737,
#  '13_max_ca_prior': 34.67368504525336,
#  '13_max_cc_prior': 1.0471285480508996,
#  '13_max_da_prior': 3.4673685045253233,
#  '13_max_dc_prior': 2.5118864315095837,
#  '13_max_total_prior': 4.7863009232263956,
#  '13_mean_aa_prior': 6.025595860743595,
#  '13_mean_ac_prior': 27.54228703338181,
#  '13_mean_ca_prior': 4.1686938347033635,
#  '13_mean_cc_prior': 11.481536214968871,
#  '13_mean_da_prior': 5.7543993733715855,
#  '13_mean_dc_prior': 20.892961308540496,
#  '13_mean_total_prior': 2.2908676527677763,
#  '13_min_aa_prior': 4.7863009232263956,
#  '13_min_ac_prior': 50.11872336272754,
#  '13_min_ca_prior': 15.848931924611204,
#  '13_min_cc_prior': 75.8577575029189,
#  '13_min_da_prior': 12.589254117941723,
#  '13_min_dc_prior': 9.12010839355913,
#  '13_min_total_prior': 3.0199517204020214,
#  '14_count_aa_prior': 8.709635899560837,
#  '14_count_ac_prior': 1.148153621496883,
#  '14_count_ca_prior': 1.659586907437562,
#  '14_count_cc_prior': 6.60693448007598,
#  '14_count_da_prior': 3.3113112148259174,
#  '14_count_dc_prior': 87.09635899560868,
#  '14_count_total_prior': 3.4673685045253233,
#  '14_max_aa_prior': 22.908676527677844,
#  '14_max_ac_prior': 60.25595860743617,
#  '14_max_ca_prior': 1.0471285480508996,
#  '14_max_cc_prior': 3.4673685045253233,
#  '14_max_da_prior': 1.148153621496883,
#  '14_max_dc_prior': 66.06934480076004,
#  '14_max_total_prior': 63.09573444801974,
#  '14_mean_aa_prior': 3.6307805477010207,
#  '14_mean_ac_prior': 16.59586907437568,
#  '14_mean_ca_prior': 54.954087385762804,
#  '14_mean_cc_prior': 16.59586907437568,
#  '14_mean_da_prior': 95.4992586021443,
#  '14_mean_dc_prior': 34.67368504525336,
#  '14_mean_total_prior': 21.877616239495634,
#  '14_min_aa_prior': 26.302679918953956,
#  '14_min_ac_prior': 1.4454397707459283,
#  '14_min_ca_prior': 19.95262314968889,
#  '14_min_cc_prior': 14.454397707459336,
#  '14_min_da_prior': 3.6307805477010207,
#  '14_min_dc_prior': 50.11872336272754,
#  '14_min_total_prior': 9.12010839355913,
#  '15_count_aa_prior': 13.803842646028906,
#  '15_count_ac_prior': 10.964781961431893,
#  '15_count_ca_prior': 4.36515832240167,
#  '15_count_cc_prior': 1.4454397707459283,
#  '15_count_da_prior': 41.68693834703379,
#  '15_count_dc_prior': 13.803842646028906,
#  '15_count_total_prior': 1.2022644346174132,
#  '15_max_aa_prior': 75.8577575029189,
#  '15_max_ac_prior': 57.543993733716064,
#  '15_max_ca_prior': 3.3113112148259174,
#  '15_max_cc_prior': 57.543993733716064,
#  '15_max_da_prior': 47.863009232264126,
#  '15_max_dc_prior': 25.11886431509593,
#  '15_max_total_prior': 12.589254117941723,
#  '15_mean_aa_prior': 23.988329190195024,
#  '15_mean_ac_prior': 7.9432823472428415,
#  '15_mean_ca_prior': 3.3113112148259174,
#  '15_mean_cc_prior': 4.7863009232263956,
#  '15_mean_da_prior': 30.199517204020324,
#  '15_mean_dc_prior': 25.11886431509593,
#  '15_mean_total_prior': 20.892961308540496,
#  '15_min_aa_prior': 12.589254117941723,
#  '15_min_ac_prior': 1.148153621496883,
#  '15_min_ca_prior': 1.2589254117941677,
#  '15_min_cc_prior': 7.9432823472428415,
#  '15_min_da_prior': 6.309573444801951,
#  '15_min_dc_prior': 43.65158322401686,
#  '15_min_total_prior': 1.4454397707459283,
#  '16_count_aa_prior': 33.11311214825929,
#  '16_count_ac_prior': 7.9432823472428415,
#  '16_count_ca_prior': 1.3803842646028854,
#  '16_count_cc_prior': 6.309573444801951,
#  '16_count_da_prior': 19.054607179632562,
#  '16_count_dc_prior': 5.49540873857626,
#  '16_count_total_prior': 30.199517204020324,
#  '16_max_aa_prior': 72.4435960074995,
#  '16_max_ac_prior': 45.70881896148778,
#  '16_max_ca_prior': 3.1622776601683853,
#  '16_max_cc_prior': 54.954087385762804,
#  '16_max_da_prior': 12.589254117941723,
#  '16_max_dc_prior': 13.803842646028906,
#  '16_max_total_prior': 10.964781961431893,
#  '16_mean_aa_prior': 9.12010839355913,
#  '16_mean_ac_prior': 3.4673685045253233,
#  '16_mean_ca_prior': 30.199517204020324,
#  '16_mean_cc_prior': 91.20108393559163,
#  '16_mean_da_prior': 63.09573444801974,
#  '16_mean_dc_prior': 26.302679918953956,
#  '16_mean_total_prior': 12.589254117941723,
#  '16_min_aa_prior': 15.848931924611204,
#  '16_min_ac_prior': 1.2589254117941677,
#  '16_min_ca_prior': 3.981071705534981,
#  '16_min_cc_prior': 8.709635899560837,
#  '16_min_da_prior': 25.11886431509593,
#  '16_min_dc_prior': 17.378008287493834,
#  '16_min_total_prior': 3.4673685045253233,
#  '17_count_aa_prior': 91.20108393559163,
#  '17_count_ac_prior': 10.000000000000037,
#  '17_count_ca_prior': 1.2589254117941677,
#  '17_count_cc_prior': 15.848931924611204,
#  '17_count_da_prior': 3.981071705534981,
#  '17_count_dc_prior': 100.00000000000074,
#  '17_count_total_prior': 10.964781961431893,
#  '17_max_aa_prior': 4.570881896148761,
#  '17_max_ac_prior': 6.60693448007598,
#  '17_max_ca_prior': 95.4992586021443,
#  '17_max_cc_prior': 1.3803842646028854,
#  '17_max_da_prior': 7.244359600749924,
#  '17_max_dc_prior': 31.622776601683967,
#  '17_max_total_prior': 2.2908676527677763,
#  '17_mean_aa_prior': 1.9952623149688817,
#  '17_mean_ac_prior': 83.17637711026768,
#  '17_mean_ca_prior': 2.630267991895386,
#  '17_mean_cc_prior': 2.187761623949555,
#  '17_mean_da_prior': 63.09573444801974,
#  '17_mean_dc_prior': 43.65158322401686,
#  '17_mean_total_prior': 9.12010839355913,
#  '17_min_aa_prior': 54.954087385762804,
#  '17_min_ac_prior': 1.513561248436209,
#  '17_min_ca_prior': 15.848931924611204,
#  '17_min_cc_prior': 41.68693834703379,
#  '17_min_da_prior': 3.3113112148259174,
#  '17_min_dc_prior': 1.2589254117941677,
#  '17_min_total_prior': 4.36515832240167,
#  '18_count_aa_prior': 3.981071705534981,
#  '18_count_ac_prior': 15.135612484362147,
#  '18_count_ca_prior': 36.30780547701034,
#  '18_count_cc_prior': 16.59586907437568,
#  '18_count_da_prior': 21.877616239495634,
#  '18_count_dc_prior': 69.18309709189411,
#  '18_count_total_prior': 1.2022644346174132,
#  '18_max_aa_prior': 75.8577575029189,
#  '18_max_ac_prior': 6.60693448007598,
#  '18_max_ca_prior': 15.848931924611204,
#  '18_max_cc_prior': 13.803842646028906,
#  '18_max_da_prior': 34.67368504525336,
#  '18_max_dc_prior': 23.988329190195024,
#  '18_max_total_prior': 75.8577575029189,
#  '18_mean_aa_prior': 34.67368504525336,
#  '18_mean_ac_prior': 4.1686938347033635,
#  '18_mean_ca_prior': 9.549925860214394,
#  '18_mean_cc_prior': 1.2589254117941677,
#  '18_mean_da_prior': 10.471285480509035,
#  '18_mean_dc_prior': 14.454397707459336,
#  '18_mean_total_prior': 26.302679918953956,
#  '18_min_aa_prior': 6.309573444801951,
#  '18_min_ac_prior': 75.8577575029189,
#  '18_min_ca_prior': 95.4992586021443,
#  '18_min_cc_prior': 7.244359600749924,
#  '18_min_da_prior': 75.8577575029189,
#  '18_min_dc_prior': 4.1686938347033635,
#  '18_min_total_prior': 2.187761623949555,
#  '19_count_aa_prior': 2.2908676527677763,
#  '19_count_ac_prior': 5.7543993733715855,
#  '19_count_ca_prior': 60.25595860743617,
#  '19_count_cc_prior': 5.49540873857626,
#  '19_count_da_prior': 69.18309709189411,
#  '19_count_dc_prior': 1.3803842646028854,
#  '19_count_total_prior': 15.135612484362147,
#  '19_max_aa_prior': 6.60693448007598,
#  '19_max_ac_prior': 9.12010839355913,
#  '19_max_ca_prior': 3.4673685045253233,
#  '19_max_cc_prior': 1.3182567385564077,
#  '19_max_da_prior': 34.67368504525336,
#  '19_max_dc_prior': 1.3182567385564077,
#  '19_max_total_prior': 12.589254117941723,
#  '19_mean_aa_prior': 6.309573444801951,
#  '19_mean_ac_prior': 57.543993733716064,
#  '19_mean_ca_prior': 25.11886431509593,
#  '19_mean_cc_prior': 87.09635899560868,
#  '19_mean_da_prior': 60.25595860743617,
#  '19_mean_dc_prior': 1.8197008586099852,
#  '19_mean_total_prior': 12.589254117941723,
#  '19_min_aa_prior': 75.8577575029189,
#  '19_min_ac_prior': 2.398832919019494,
#  '19_min_ca_prior': 47.863009232264126,
#  '19_min_cc_prior': 52.48074602497759,
#  '19_min_da_prior': 5.24807460249774,
#  '19_min_dc_prior': 2.884031503126611,
#  '19_min_total_prior': 9.12010839355913,
#  '1_count_aa_prior': 7.9432823472428415,
#  '1_count_ac_prior': 45.70881896148778,
#  '1_count_ca_prior': 1.0471285480508996,
#  '1_count_cc_prior': 45.70881896148778,
#  '1_count_da_prior': 47.863009232264126,
#  '1_count_dc_prior': 1.2022644346174132,
#  '1_count_total_prior': 21.877616239495634,
#  '1_max_aa_prior': 20.892961308540496,
#  '1_max_ac_prior': 3.1622776601683853,
#  '1_max_ca_prior': 100.00000000000074,
#  '1_max_cc_prior': 66.06934480076004,
#  '1_max_da_prior': 1.5848931924611147,
#  '1_max_dc_prior': 91.20108393559163,
#  '1_max_total_prior': 69.18309709189411,
#  '1_mean_aa_prior': 3.1622776601683853,
#  '1_mean_ac_prior': 4.7863009232263956,
#  '1_mean_ca_prior': 15.135612484362147,
#  '1_mean_cc_prior': 30.199517204020324,
#  '1_mean_da_prior': 1.8197008586099852,
#  '1_mean_dc_prior': 6.60693448007598,
#  '1_mean_total_prior': 23.988329190195024,
#  '1_min_aa_prior': 1.9054607179632492,
#  '1_min_ac_prior': 18.19700858609992,
#  '1_min_ca_prior': 1.2589254117941677,
#  '1_min_cc_prior': 45.70881896148778,
#  '1_min_da_prior': 25.11886431509593,
#  '1_min_dc_prior': 10.964781961431893,
#  '1_min_total_prior': 83.17637711026768,
#  '20_count_aa_prior': 72.4435960074995,
#  '20_count_ac_prior': 17.378008287493834,
#  '20_count_ca_prior': 4.1686938347033635,
#  '20_count_cc_prior': 23.988329190195024,
#  '20_count_da_prior': 95.4992586021443,
#  '20_count_dc_prior': 63.09573444801974,
#  '20_count_total_prior': 21.877616239495634,
#  '20_max_aa_prior': 60.25595860743617,
#  '20_max_ac_prior': 7.9432823472428415,
#  '20_max_ca_prior': 36.30780547701034,
#  '20_max_cc_prior': 18.19700858609992,
#  '20_max_da_prior': 7.244359600749924,
#  '20_max_dc_prior': 1.3803842646028854,
#  '20_max_total_prior': 6.918309709189386,
#  '20_mean_aa_prior': 5.49540873857626,
#  '20_mean_ac_prior': 1.9952623149688817,
#  '20_mean_ca_prior': 6.918309709189386,
#  '20_mean_cc_prior': 10.964781961431893,
#  '20_mean_da_prior': 15.135612484362147,
#  '20_mean_dc_prior': 6.60693448007598,
#  '20_mean_total_prior': 63.09573444801974,
#  '20_min_aa_prior': 63.09573444801974,
#  '20_min_ac_prior': 3.3113112148259174,
#  '20_min_ca_prior': 2.7542287033381707,
#  '20_min_cc_prior': 1.737800828749377,
#  '20_min_da_prior': 1.5848931924611147,
#  '20_min_dc_prior': 47.863009232264126,
#  '20_min_total_prior': 83.17637711026768,
#  '21_count_aa_prior': 34.67368504525336,
#  '21_count_ac_prior': 41.68693834703379,
#  '21_count_ca_prior': 3.80189396320562,
#  '21_count_cc_prior': 1.096478196143185,
#  '21_count_da_prior': 57.543993733716064,
#  '21_count_dc_prior': 13.182567385564125,
#  '21_count_total_prior': 3.6307805477010207,
#  '21_max_aa_prior': 6.60693448007598,
#  '21_max_ac_prior': 6.025595860743595,
#  '21_max_ca_prior': 69.18309709189411,
#  '21_max_cc_prior': 1.9054607179632492,
#  '21_max_da_prior': 14.454397707459336,
#  '21_max_dc_prior': 2.884031503126611,
#  '21_max_total_prior': 83.17637711026768,
#  '21_mean_aa_prior': 75.8577575029189,
#  '21_mean_ac_prior': 10.000000000000037,
#  '21_mean_ca_prior': 2.5118864315095837,
#  '21_mean_cc_prior': 1.659586907437562,
#  '21_mean_da_prior': 3.981071705534981,
#  '21_mean_dc_prior': 45.70881896148778,
#  '21_mean_total_prior': 54.954087385762804,
#  '21_min_aa_prior': 31.622776601683967,
#  '21_min_ac_prior': 18.19700858609992,
#  '21_min_ca_prior': 45.70881896148778,
#  '21_min_cc_prior': 26.302679918953956,
#  '21_min_da_prior': 6.918309709189386,
#  '21_min_dc_prior': 7.585775750291862,
#  '21_min_total_prior': 87.09635899560868,
#  '22_count_aa_prior': 2.398832919019494,
#  '22_count_ac_prior': 91.20108393559163,
#  '22_count_ca_prior': 60.25595860743617,
#  '22_count_cc_prior': 10.471285480509035,
#  '22_count_da_prior': 3.0199517204020214,
#  '22_count_dc_prior': 6.025595860743595,
#  '22_count_total_prior': 79.43282347242871,
#  '22_max_aa_prior': 5.011872336272735,
#  '22_max_ac_prior': 3.6307805477010207,
#  '22_max_ca_prior': 47.863009232264126,
#  '22_max_cc_prior': 1.0471285480508996,
#  '22_max_da_prior': 14.454397707459336,
#  '22_max_dc_prior': 23.988329190195024,
#  '22_max_total_prior': 27.54228703338181,
#  '22_mean_aa_prior': 2.398832919019494,
#  '22_mean_ac_prior': 100.00000000000074,
#  '22_mean_ca_prior': 3.80189396320562,
#  '22_mean_cc_prior': 4.7863009232263956,
#  '22_mean_da_prior': 41.68693834703379,
#  '22_mean_dc_prior': 13.803842646028906,
#  '22_mean_total_prior': 52.48074602497759,
#  '22_min_aa_prior': 30.199517204020324,
#  '22_min_ac_prior': 9.12010839355913,
#  '22_min_ca_prior': 41.68693834703379,
#  '22_min_cc_prior': 1.8197008586099852,
#  '22_min_da_prior': 9.549925860214394,
#  '22_min_dc_prior': 1.5848931924611147,
#  '22_min_total_prior': 6.60693448007598,
#  '23_count_aa_prior': 3.0199517204020214,
#  '23_count_ac_prior': 4.36515832240167,
#  '23_count_ca_prior': 5.011872336272735,
#  '23_count_cc_prior': 1.9054607179632492,
#  '23_count_da_prior': 22.908676527677844,
#  '23_count_dc_prior': 63.09573444801974,
#  '23_count_total_prior': 1.5848931924611147,
#  '23_max_aa_prior': 41.68693834703379,
#  '23_max_ac_prior': 66.06934480076004,
#  '23_max_ca_prior': 2.398832919019494,
#  '23_max_cc_prior': 12.022644346174177,
#  '23_max_da_prior': 5.24807460249774,
#  '23_max_dc_prior': 50.11872336272754,
#  '23_max_total_prior': 79.43282347242871,
#  '23_mean_aa_prior': 100.00000000000074,
#  '23_mean_ac_prior': 12.022644346174177,
#  '23_mean_ca_prior': 7.244359600749924,
#  '23_mean_cc_prior': 3.981071705534981,
#  '23_mean_da_prior': 21.877616239495634,
#  '23_mean_dc_prior': 3.80189396320562,
#  '23_mean_total_prior': 27.54228703338181,
#  '23_min_aa_prior': 36.30780547701034,
#  '23_min_ac_prior': 1.9952623149688817,
#  '23_min_ca_prior': 4.7863009232263956,
#  '23_min_cc_prior': 1.2022644346174132,
#  '23_min_da_prior': 3.3113112148259174,
#  '23_min_dc_prior': 20.892961308540496,
#  '23_min_total_prior': 5.011872336272735,
#  '24_count_aa_prior': 22.908676527677844,
#  '24_count_ac_prior': 4.7863009232263956,
#  '24_count_ca_prior': 75.8577575029189,
#  '24_count_cc_prior': 13.182567385564125,
#  '24_count_da_prior': 1.096478196143185,
#  '24_count_dc_prior': 1.9952623149688817,
#  '24_count_total_prior': 12.022644346174177,
#  '24_max_aa_prior': 83.17637711026768,
#  '24_max_ac_prior': 21.877616239495634,
#  '24_max_ca_prior': 1.2022644346174132,
#  '24_max_cc_prior': 3.981071705534981,
#  '24_max_da_prior': 1.659586907437562,
#  '24_max_dc_prior': 1.2022644346174132,
#  '24_max_total_prior': 16.59586907437568,
#  '24_mean_aa_prior': 5.7543993733715855,
#  '24_mean_ac_prior': 4.570881896148761,
#  '24_mean_ca_prior': 7.9432823472428415,
#  '24_mean_cc_prior': 15.848931924611204,
#  '24_mean_da_prior': 2.7542287033381707,
#  '24_mean_dc_prior': 6.025595860743595,
#  '24_mean_total_prior': 14.454397707459336,
#  '24_min_aa_prior': 15.848931924611204,
#  '24_min_ac_prior': 11.481536214968871,
#  '24_min_ca_prior': 1.096478196143185,
#  '24_min_cc_prior': 1.2022644346174132,
#  '24_min_da_prior': 10.964781961431893,
#  '24_min_dc_prior': 2.7542287033381707,
#  '24_min_total_prior': 87.09635899560868,
#  '25_count_aa_prior': 75.8577575029189,
#  '25_count_ac_prior': 10.471285480509035,
#  '25_count_ca_prior': 1.659586907437562,
#  '25_count_cc_prior': 3.1622776601683853,
#  '25_count_da_prior': 100.00000000000074,
#  '25_count_dc_prior': 27.54228703338181,
#  '25_count_total_prior': 91.20108393559163,
#  '25_max_aa_prior': 60.25595860743617,
#  '25_max_ac_prior': 4.1686938347033635,
#  '25_max_ca_prior': 95.4992586021443,
#  '25_max_cc_prior': 1.0471285480508996,
#  '25_max_da_prior': 2.5118864315095837,
#  '25_max_dc_prior': 2.2908676527677763,
#  '25_max_total_prior': 87.09635899560868,
#  '25_mean_aa_prior': 1.659586907437562,
#  '25_mean_ac_prior': 4.1686938347033635,
#  '25_mean_ca_prior': 9.12010839355913,
#  '25_mean_cc_prior': 8.709635899560837,
#  '25_mean_da_prior': 2.630267991895386,
#  '25_mean_dc_prior': 43.65158322401686,
#  '25_mean_total_prior': 3.4673685045253233,
#  '25_min_aa_prior': 2.884031503126611,
#  '25_min_ac_prior': 3.1622776601683853,
#  '25_min_ca_prior': 20.892961308540496,
#  '25_min_cc_prior': 69.18309709189411,
#  '25_min_da_prior': 6.309573444801951,
#  '25_min_dc_prior': 79.43282347242871,
#  '25_min_total_prior': 2.7542287033381707,
#  '26_count_aa_prior': 75.8577575029189,
#  '26_count_ac_prior': 100.00000000000074,
#  '26_count_ca_prior': 13.803842646028906,
#  '26_count_cc_prior': 7.9432823472428415,
#  '26_count_da_prior': 47.863009232264126,
#  '26_count_dc_prior': 2.7542287033381707,
#  '26_count_total_prior': 72.4435960074995,
#  '26_max_aa_prior': 39.81071705534996,
#  '26_max_ac_prior': 28.840315031266215,
#  '26_max_ca_prior': 45.70881896148778,
#  '26_max_cc_prior': 1.3182567385564077,
#  '26_max_da_prior': 1.2589254117941677,
#  '26_max_dc_prior': 23.988329190195024,
#  '26_max_total_prior': 52.48074602497759,
#  '26_mean_aa_prior': 36.30780547701034,
#  '26_mean_ac_prior': 5.24807460249774,
#  '26_mean_ca_prior': 16.59586907437568,
#  '26_mean_cc_prior': 9.549925860214394,
#  '26_mean_da_prior': 95.4992586021443,
#  '26_mean_dc_prior': 1.9952623149688817,
#  '26_mean_total_prior': 1.2589254117941677,
#  '26_min_aa_prior': 14.454397707459336,
#  '26_min_ac_prior': 69.18309709189411,
#  '26_min_ca_prior': 2.187761623949555,
#  '26_min_cc_prior': 5.49540873857626,
#  '26_min_da_prior': 5.7543993733715855,
#  '26_min_dc_prior': 15.135612484362147,
#  '26_min_total_prior': 1.9054607179632492,
#  '2_count_aa_prior': 57.543993733716064,
#  '2_count_ac_prior': 19.054607179632562,
#  '2_count_ca_prior': 2.187761623949555,
#  '2_count_cc_prior': 63.09573444801974,
#  '2_count_da_prior': 72.4435960074995,
#  '2_count_dc_prior': 5.011872336272735,
#  '2_count_total_prior': 21.877616239495634,
#  '2_max_aa_prior': 57.543993733716064,
#  '2_max_ac_prior': 18.19700858609992,
#  '2_max_ca_prior': 2.089296130854042,
#  '2_max_cc_prior': 9.549925860214394,
#  '2_max_da_prior': 60.25595860743617,
#  '2_max_dc_prior': 3.4673685045253233,
#  '2_max_total_prior': 4.570881896148761,
#  '2_mean_aa_prior': 5.49540873857626,
#  '2_mean_ac_prior': 7.9432823472428415,
#  '2_mean_ca_prior': 3.981071705534981,
#  '2_mean_cc_prior': 3.4673685045253233,
#  '2_mean_da_prior': 43.65158322401686,
#  '2_mean_dc_prior': 2.398832919019494,
#  '2_mean_total_prior': 1.4454397707459283,
#  '2_min_aa_prior': 14.454397707459336,
#  '2_min_ac_prior': 34.67368504525336,
#  '2_min_ca_prior': 52.48074602497759,
#  '2_min_cc_prior': 2.7542287033381707,
#  '2_min_da_prior': 1.3803842646028854,
#  '2_min_dc_prior': 9.549925860214394,
#  '2_min_total_prior': 1.2022644346174132,
#  '3_count_aa_prior': 100.00000000000074,
#  '3_count_ac_prior': 63.09573444801974,
#  '3_count_ca_prior': 28.840315031266215,
#  '3_count_cc_prior': 1.513561248436209,
#  '3_count_da_prior': 47.863009232264126,
#  '3_count_dc_prior': 1.737800828749377,
#  '3_count_total_prior': 20.892961308540496,
#  '3_max_aa_prior': 1.4454397707459283,
#  '3_max_ac_prior': 47.863009232264126,
#  '3_max_ca_prior': 4.570881896148761,
#  '3_max_cc_prior': 54.954087385762804,
#  '3_max_da_prior': 38.01893963205634,
#  '3_max_dc_prior': 34.67368504525336,
#  '3_max_total_prior': 10.471285480509035,
#  '3_mean_aa_prior': 1.148153621496883,
#  '3_mean_ac_prior': 66.06934480076004,
#  '3_mean_ca_prior': 1.4454397707459283,
#  '3_mean_cc_prior': 4.570881896148761,
#  '3_mean_da_prior': 22.908676527677844,
#  '3_mean_dc_prior': 31.622776601683967,
#  '3_mean_total_prior': 2.630267991895386,
#  '3_min_aa_prior': 1.0471285480508996,
#  '3_min_ac_prior': 1.659586907437562,
#  '3_min_ca_prior': 7.244359600749924,
#  '3_min_cc_prior': 30.199517204020324,
#  '3_min_da_prior': 19.054607179632562,
#  '3_min_dc_prior': 30.199517204020324,
#  '3_min_total_prior': 10.964781961431893,
#  '4_count_aa_prior': 3.3113112148259174,
#  '4_count_ac_prior': 1.9054607179632492,
#  '4_count_ca_prior': 2.2908676527677763,
#  '4_count_cc_prior': 10.471285480509035,
#  '4_count_da_prior': 21.877616239495634,
#  '4_count_dc_prior': 1.148153621496883,
#  '4_count_total_prior': 16.59586907437568,
#  '4_max_aa_prior': 2.630267991895386,
#  '4_max_ac_prior': 9.549925860214394,
#  '4_max_ca_prior': 12.022644346174177,
#  '4_max_cc_prior': 11.481536214968871,
#  '4_max_da_prior': 1.0471285480508996,
#  '4_max_dc_prior': 1.513561248436209,
#  '4_max_total_prior': 2.187761623949555,
#  '4_mean_aa_prior': 2.089296130854042,
#  '4_mean_ac_prior': 83.17637711026768,
#  '4_mean_ca_prior': 2.884031503126611,
#  '4_mean_cc_prior': 6.60693448007598,
#  '4_mean_da_prior': 34.67368504525336,
#  '4_mean_dc_prior': 2.2908676527677763,
#  '4_mean_total_prior': 10.471285480509035,
#  '4_min_aa_prior': 8.317637711026737,
#  '4_min_ac_prior': 72.4435960074995,
#  '4_min_ca_prior': 18.19700858609992,
#  '4_min_cc_prior': 2.5118864315095837,
#  '4_min_da_prior': 43.65158322401686,
#  '4_min_dc_prior': 1.2589254117941677,
#  '4_min_total_prior': 22.908676527677844,
#  '5_count_aa_prior': 2.398832919019494,
#  '5_count_ac_prior': 52.48074602497759,
#  '5_count_ca_prior': 83.17637711026768,
#  '5_count_cc_prior': 45.70881896148778,
#  '5_count_da_prior': 1.2022644346174132,
#  '5_count_dc_prior': 10.471285480509035,
#  '5_count_total_prior': 63.09573444801974,
#  '5_max_aa_prior': 27.54228703338181,
#  '5_max_ac_prior': 100.00000000000074,
#  '5_max_ca_prior': 75.8577575029189,
#  '5_max_cc_prior': 1.2589254117941677,
#  '5_max_da_prior': 52.48074602497759,
#  '5_max_dc_prior': 95.4992586021443,
#  '5_max_total_prior': 4.1686938347033635,
#  '5_mean_aa_prior': 2.398832919019494,
#  '5_mean_ac_prior': 1.4454397707459283,
#  '5_mean_ca_prior': 2.5118864315095837,
#  '5_mean_cc_prior': 2.7542287033381707,
#  '5_mean_da_prior': 9.549925860214394,
#  '5_mean_dc_prior': 33.11311214825929,
#  '5_mean_total_prior': 69.18309709189411,
#  '5_min_aa_prior': 10.000000000000037,
#  '5_min_ac_prior': 1.2589254117941677,
#  '5_min_ca_prior': 4.1686938347033635,
#  '5_min_cc_prior': 1.096478196143185,
#  '5_min_da_prior': 18.19700858609992,
#  '5_min_dc_prior': 39.81071705534996,
#  '5_min_total_prior': 23.988329190195024,
#  '6_count_aa_prior': 12.022644346174177,
#  '6_count_ac_prior': 26.302679918953956,
#  '6_count_ca_prior': 15.848931924611204,
#  '6_count_cc_prior': 1.0471285480508996,
#  '6_count_da_prior': 10.471285480509035,
#  '6_count_dc_prior': 66.06934480076004,
#  '6_count_total_prior': 14.454397707459336,
#  '6_max_aa_prior': 3.1622776601683853,
#  '6_max_ac_prior': 47.863009232264126,
#  '6_max_ca_prior': 28.840315031266215,
#  '6_max_cc_prior': 19.95262314968889,
#  '6_max_da_prior': 54.954087385762804,
#  '6_max_dc_prior': 17.378008287493834,
#  '6_max_total_prior': 3.6307805477010207,
#  '6_mean_aa_prior': 83.17637711026768,
#  '6_mean_ac_prior': 28.840315031266215,
#  '6_mean_ca_prior': 57.543993733716064,
#  '6_mean_cc_prior': 13.803842646028906,
#  '6_mean_da_prior': 31.622776601683967,
#  '6_mean_dc_prior': 1.2589254117941677,
#  '6_mean_total_prior': 1.2022644346174132,
#  '6_min_aa_prior': 8.709635899560837,
#  '6_min_ac_prior': 13.182567385564125,
#  '6_min_ca_prior': 63.09573444801974,
#  '6_min_cc_prior': 5.24807460249774,
#  '6_min_da_prior': 19.054607179632562,
#  '6_min_dc_prior': 1.9952623149688817,
#  '6_min_total_prior': 19.054607179632562,
#  '7_count_aa_prior': 2.5118864315095837,
#  '7_count_ac_prior': 12.589254117941723,
#  '7_count_ca_prior': 7.244359600749924,
#  '7_count_cc_prior': 2.5118864315095837,
#  '7_count_da_prior': 33.11311214825929,
#  '7_count_dc_prior': 2.7542287033381707,
#  '7_count_total_prior': 79.43282347242871,
#  '7_max_aa_prior': 4.1686938347033635,
#  '7_max_ac_prior': 87.09635899560868,
#  '7_max_ca_prior': 72.4435960074995,
#  '7_max_cc_prior': 3.981071705534981,
#  '7_max_da_prior': 11.481536214968871,
#  '7_max_dc_prior': 3.80189396320562,
#  '7_max_total_prior': 19.054607179632562,
#  '7_mean_aa_prior': 11.481536214968871,
#  '7_mean_ac_prior': 1.4454397707459283,
#  '7_mean_ca_prior': 5.49540873857626,
#  '7_mean_cc_prior': 6.918309709189386,
#  '7_mean_da_prior': 15.848931924611204,
#  '7_mean_dc_prior': 2.089296130854042,
#  '7_mean_total_prior': 7.9432823472428415,
#  '7_min_aa_prior': 6.918309709189386,
#  '7_min_ac_prior': 1.737800828749377,
#  '7_min_ca_prior': 1.4454397707459283,
#  '7_min_cc_prior': 1.2589254117941677,
#  '7_min_da_prior': 5.011872336272735,
#  '7_min_dc_prior': 33.11311214825929,
#  '7_min_total_prior': 20.892961308540496,
#  '8_count_aa_prior': 1.148153621496883,
#  '8_count_ac_prior': 50.11872336272754,
#  '8_count_ca_prior': 75.8577575029189,
#  '8_count_cc_prior': 2.187761623949555,
#  '8_count_da_prior': 2.187761623949555,
#  '8_count_dc_prior': 7.585775750291862,
#  '8_count_total_prior': 43.65158322401686,
#  '8_max_aa_prior': 6.309573444801951,
#  '8_max_ac_prior': 5.011872336272735,
#  '8_max_ca_prior': 100.00000000000074,
#  '8_max_cc_prior': 43.65158322401686,
#  '8_max_da_prior': 16.59586907437568,
#  '8_max_dc_prior': 2.187761623949555,
#  '8_max_total_prior': 2.7542287033381707,
#  '8_mean_aa_prior': 16.59586907437568,
#  '8_mean_ac_prior': 95.4992586021443,
#  '8_mean_ca_prior': 11.481536214968871,
#  '8_mean_cc_prior': 9.12010839355913,
#  '8_mean_da_prior': 9.549925860214394,
#  '8_mean_dc_prior': 23.988329190195024,
#  '8_mean_total_prior': 22.908676527677844,
#  '8_min_aa_prior': 9.549925860214394,
#  '8_min_ac_prior': 4.1686938347033635,
#  '8_min_ca_prior': 2.884031503126611,
#  '8_min_cc_prior': 2.187761623949555,
#  '8_min_da_prior': 3.4673685045253233,
#  '8_min_dc_prior': 7.9432823472428415,
#  '8_min_total_prior': 7.244359600749924,
#  '9_count_aa_prior': 34.67368504525336,
#  '9_count_ac_prior': 60.25595860743617,
#  '9_count_ca_prior': 8.317637711026737,
#  '9_count_cc_prior': 19.95262314968889,
#  '9_count_da_prior': 54.954087385762804,
#  '9_count_dc_prior': 1.9054607179632492,
#  '9_count_total_prior': 2.630267991895386,
#  '9_max_aa_prior': 2.089296130854042,
#  '9_max_ac_prior': 72.4435960074995,
#  '9_max_ca_prior': 12.022644346174177,
#  '9_max_cc_prior': 2.7542287033381707,
#  '9_max_da_prior': 13.182567385564125,
#  '9_max_dc_prior': 38.01893963205634,
#  '9_max_total_prior': 13.803842646028906,
#  '9_mean_aa_prior': 13.803842646028906,
#  '9_mean_ac_prior': 1.5848931924611147,
#  '9_mean_ca_prior': 5.24807460249774,
#  '9_mean_cc_prior': 2.630267991895386,
#  '9_mean_da_prior': 43.65158322401686,
#  '9_mean_dc_prior': 1.5848931924611147,
#  '9_mean_total_prior': 34.67368504525336,
#  '9_min_aa_prior': 12.022644346174177,
#  '9_min_ac_prior': 2.187761623949555,
#  '9_min_ca_prior': 72.4435960074995,
#  '9_min_cc_prior': 5.24807460249774,
#  '9_min_da_prior': 5.24807460249774,
#  '9_min_dc_prior': 21.877616239495634,
#  '9_min_total_prior': 34.67368504525336,
#  'CompetitionDistance_count_aa_prior': 17.378008287493834,
#  'CompetitionDistance_count_ac_prior': 57.543993733716064,
#  'CompetitionDistance_count_ca_prior': 19.054607179632562,
#  'CompetitionDistance_count_cc_prior': 57.543993733716064,
#  'CompetitionDistance_count_da_prior': 79.43282347242871,
#  'CompetitionDistance_count_dc_prior': 3.981071705534981,
#  'CompetitionDistance_count_total_prior': 72.4435960074995,
#  'CompetitionDistance_max_aa_prior': 30.199517204020324,
#  'CompetitionDistance_max_ac_prior': 34.67368504525336,
#  'CompetitionDistance_max_ca_prior': 9.12010839355913,
#  'CompetitionDistance_max_cc_prior': 2.398832919019494,
#  'CompetitionDistance_max_da_prior': 1.3803842646028854,
#  'CompetitionDistance_max_dc_prior': 16.59586907437568,
#  'CompetitionDistance_max_total_prior': 12.589254117941723,
#  'CompetitionDistance_mean_aa_prior': 31.622776601683967,
#  'CompetitionDistance_mean_ac_prior': 63.09573444801974,
#  'CompetitionDistance_mean_ca_prior': 3.6307805477010207,
#  'CompetitionDistance_mean_cc_prior': 1.9054607179632492,
#  'CompetitionDistance_mean_da_prior': 4.36515832240167,
#  'CompetitionDistance_mean_dc_prior': 57.543993733716064,
#  'CompetitionDistance_mean_total_prior': 13.803842646028906,
#  'CompetitionDistance_min_aa_prior': 2.7542287033381707,
#  'CompetitionDistance_min_ac_prior': 79.43282347242871,
#  'CompetitionDistance_min_ca_prior': 45.70881896148778,
#  'CompetitionDistance_min_cc_prior': 6.60693448007598,
#  'CompetitionDistance_min_da_prior': 31.622776601683967,
#  'CompetitionDistance_min_dc_prior': 17.378008287493834,
#  'CompetitionDistance_min_total_prior': 13.803842646028906,
#  'CompetitionOpenSinceMonth_count_aa_prior': 1.9952623149688817,
#  'CompetitionOpenSinceMonth_count_ac_prior': 2.187761623949555,
#  'CompetitionOpenSinceMonth_count_ca_prior': 52.48074602497759,
#  'CompetitionOpenSinceMonth_count_cc_prior': 9.549925860214394,
#  'CompetitionOpenSinceMonth_count_da_prior': 2.089296130854042,
#  'CompetitionOpenSinceMonth_count_dc_prior': 19.95262314968889,
#  'CompetitionOpenSinceMonth_count_total_prior': 41.68693834703379,
#  'CompetitionOpenSinceMonth_max_aa_prior': 26.302679918953956,
#  'CompetitionOpenSinceMonth_max_ac_prior': 1.9952623149688817,
#  'CompetitionOpenSinceMonth_max_ca_prior': 57.543993733716064,
#  'CompetitionOpenSinceMonth_max_cc_prior': 4.1686938347033635,
#  'CompetitionOpenSinceMonth_max_da_prior': 1.0471285480508996,
#  'CompetitionOpenSinceMonth_max_dc_prior': 18.19700858609992,
#  'CompetitionOpenSinceMonth_max_total_prior': 5.7543993733715855,
#  'CompetitionOpenSinceMonth_mean_aa_prior': 3.3113112148259174,
#  'CompetitionOpenSinceMonth_mean_ac_prior': 2.7542287033381707,
#  'CompetitionOpenSinceMonth_mean_ca_prior': 1.3803842646028854,
#  'CompetitionOpenSinceMonth_mean_cc_prior': 95.4992586021443,
#  'CompetitionOpenSinceMonth_mean_da_prior': 2.630267991895386,
#  'CompetitionOpenSinceMonth_mean_dc_prior': 4.36515832240167,
#  'CompetitionOpenSinceMonth_mean_total_prior': 1.8197008586099852,
#  'CompetitionOpenSinceMonth_min_aa_prior': 18.19700858609992,
#  'CompetitionOpenSinceMonth_min_ac_prior': 52.48074602497759,
#  'CompetitionOpenSinceMonth_min_ca_prior': 1.9054607179632492,
#  'CompetitionOpenSinceMonth_min_cc_prior': 41.68693834703379,
#  'CompetitionOpenSinceMonth_min_da_prior': 1.0471285480508996,
#  'CompetitionOpenSinceMonth_min_dc_prior': 79.43282347242871,
#  'CompetitionOpenSinceMonth_min_total_prior': 63.09573444801974,
#  'CompetitionOpenSinceYear_count_aa_prior': 83.17637711026768,
#  'CompetitionOpenSinceYear_count_ac_prior': 11.481536214968871,
#  'CompetitionOpenSinceYear_count_ca_prior': 25.11886431509593,
#  'CompetitionOpenSinceYear_count_cc_prior': 95.4992586021443,
#  'CompetitionOpenSinceYear_count_da_prior': 10.964781961431893,
#  'CompetitionOpenSinceYear_count_dc_prior': 9.549925860214394,
#  'CompetitionOpenSinceYear_count_total_prior': 28.840315031266215,
#  'CompetitionOpenSinceYear_max_aa_prior': 15.848931924611204,
#  'CompetitionOpenSinceYear_max_ac_prior': 30.199517204020324,
#  'CompetitionOpenSinceYear_max_ca_prior': 19.054607179632562,
#  'CompetitionOpenSinceYear_max_cc_prior': 31.622776601683967,
#  'CompetitionOpenSinceYear_max_da_prior': 15.135612484362147,
#  'CompetitionOpenSinceYear_max_dc_prior': 22.908676527677844,
#  'CompetitionOpenSinceYear_max_total_prior': 6.918309709189386,
#  'CompetitionOpenSinceYear_mean_aa_prior': 17.378008287493834,
#  'CompetitionOpenSinceYear_mean_ac_prior': 7.585775750291862,
#  'CompetitionOpenSinceYear_mean_ca_prior': 6.918309709189386,
#  'CompetitionOpenSinceYear_mean_cc_prior': 12.589254117941723,
#  'CompetitionOpenSinceYear_mean_da_prior': 3.6307805477010207,
#  'CompetitionOpenSinceYear_mean_dc_prior': 3.0199517204020214,
#  'CompetitionOpenSinceYear_mean_total_prior': 75.8577575029189,
#  'CompetitionOpenSinceYear_min_aa_prior': 2.2908676527677763,
#  'CompetitionOpenSinceYear_min_ac_prior': 3.1622776601683853,
#  'CompetitionOpenSinceYear_min_ca_prior': 12.022644346174177,
#  'CompetitionOpenSinceYear_min_cc_prior': 30.199517204020324,
#  'CompetitionOpenSinceYear_min_da_prior': 33.11311214825929,
#  'CompetitionOpenSinceYear_min_dc_prior': 19.054607179632562,
#  'CompetitionOpenSinceYear_min_total_prior': 2.089296130854042,
#  'Customers_count_aa_prior': 25.11886431509593,
#  'Customers_count_ac_prior': 19.95262314968889,
#  'Customers_count_ca_prior': 12.022644346174177,
#  'Customers_count_cc_prior': 66.06934480076004,
#  'Customers_count_da_prior': 4.7863009232263956,
#  'Customers_count_dc_prior': 1.148153621496883,
#  'Customers_count_total_prior': 3.3113112148259174,
#  'Customers_max_aa_prior': 12.022644346174177,
#  'Customers_max_ac_prior': 13.182567385564125,
#  'Customers_max_ca_prior': 57.543993733716064,
#  'Customers_max_cc_prior': 6.60693448007598,
#  'Customers_max_da_prior': 4.36515832240167,
#  'Customers_max_dc_prior': 1.8197008586099852,
#  'Customers_max_total_prior': 1.0471285480508996,
#  'Customers_mean_aa_prior': 1.9054607179632492,
#  'Customers_mean_ac_prior': 1.2589254117941677,
#  'Customers_mean_ca_prior': 1.9952623149688817,
#  'Customers_mean_cc_prior': 18.19700858609992,
#  'Customers_mean_da_prior': 2.5118864315095837,
#  'Customers_mean_dc_prior': 7.244359600749924,
#  'Customers_mean_total_prior': 3.4673685045253233,
#  'Customers_min_aa_prior': 72.4435960074995,
#  'Customers_min_ac_prior': 3.80189396320562,
#  'Customers_min_ca_prior': 12.022644346174177,
#  'Customers_min_cc_prior': 10.000000000000037,
#  'Customers_min_da_prior': 8.317637711026737,
#  'Customers_min_dc_prior': 79.43282347242871,
#  'Customers_min_total_prior': 1.513561248436209,
#  'Date_count_aa_prior': 57.543993733716064,
#  'Date_count_ac_prior': 50.11872336272754,
#  'Date_count_ca_prior': 1.659586907437562,
#  'Date_count_cc_prior': 22.908676527677844,
#  'Date_count_da_prior': 10.471285480509035,
#  'Date_count_dc_prior': 26.302679918953956,
#  'Date_count_total_prior': 8.317637711026737,
#  'Date_max_aa_prior': 3.1622776601683853,
#  'Date_max_ac_prior': 5.7543993733715855,
#  'Date_max_ca_prior': 7.585775750291862,
#  'Date_max_cc_prior': 10.964781961431893,
#  'Date_max_da_prior': 2.398832919019494,
#  'Date_max_dc_prior': 2.630267991895386,
#  'Date_max_total_prior': 16.59586907437568,
#  'Date_mean_aa_prior': 52.48074602497759,
#  'Date_mean_ac_prior': 2.187761623949555,
#  'Date_mean_ca_prior': 17.378008287493834,
#  'Date_mean_cc_prior': 79.43282347242871,
#  'Date_mean_da_prior': 19.95262314968889,
#  'Date_mean_dc_prior': 18.19700858609992,
#  'Date_mean_total_prior': 1.3182567385564077,
#  'Date_min_aa_prior': 75.8577575029189,
#  'Date_min_ac_prior': 10.000000000000037,
#  'Date_min_ca_prior': 4.36515832240167,
#  'Date_min_cc_prior': 87.09635899560868,
#  'Date_min_da_prior': 2.884031503126611,
#  'Date_min_dc_prior': 6.025595860743595,
#  'Date_min_total_prior': 12.589254117941723,
#  'DayOfWeek_count_aa_prior': 2.7542287033381707,
#  'DayOfWeek_count_ac_prior': 39.81071705534996,
#  'DayOfWeek_count_ca_prior': 45.70881896148778,
#  'DayOfWeek_count_cc_prior': 2.398832919019494,
#  'DayOfWeek_count_da_prior': 3.0199517204020214,
#  'DayOfWeek_count_dc_prior': 6.309573444801951,
#  'DayOfWeek_count_total_prior': 41.68693834703379,
#  'DayOfWeek_max_aa_prior': 1.148153621496883,
#  'DayOfWeek_max_ac_prior': 6.309573444801951,
#  'DayOfWeek_max_ca_prior': 69.18309709189411,
#  'DayOfWeek_max_cc_prior': 12.022644346174177,
#  'DayOfWeek_max_da_prior': 57.543993733716064,
#  'DayOfWeek_max_dc_prior': 100.00000000000074,
#  'DayOfWeek_max_total_prior': 47.863009232264126,
#  'DayOfWeek_mean_aa_prior': 6.309573444801951,
#  'DayOfWeek_mean_ac_prior': 1.659586907437562,
#  'DayOfWeek_mean_ca_prior': 79.43282347242871,
#  'DayOfWeek_mean_cc_prior': 43.65158322401686,
#  'DayOfWeek_mean_da_prior': 10.964781961431893,
#  'DayOfWeek_mean_dc_prior': 2.089296130854042,
#  'DayOfWeek_mean_total_prior': 1.513561248436209,
#  'DayOfWeek_min_aa_prior': 5.7543993733715855,
#  'DayOfWeek_min_ac_prior': 1.148153621496883,
#  'DayOfWeek_min_ca_prior': 2.089296130854042,
#  'DayOfWeek_min_cc_prior': 25.11886431509593,
#  'DayOfWeek_min_da_prior': 33.11311214825929,
#  'DayOfWeek_min_dc_prior': 2.2908676527677763,
#  'DayOfWeek_min_total_prior': 5.24807460249774,
#  'Day_count_aa_prior': 57.543993733716064,
#  'Day_count_ac_prior': 8.317637711026737,
#  'Day_count_ca_prior': 4.1686938347033635,
#  'Day_count_cc_prior': 28.840315031266215,
#  'Day_count_da_prior': 83.17637711026768,
#  'Day_count_dc_prior': 1.8197008586099852,
#  'Day_count_total_prior': 1.659586907437562,
#  'Day_max_aa_prior': 95.4992586021443,
#  'Day_max_ac_prior': 2.089296130854042,
#  'Day_max_ca_prior': 50.11872336272754,
#  'Day_max_cc_prior': 60.25595860743617,
#  'Day_max_da_prior': 5.24807460249774,
#  'Day_max_dc_prior': 20.892961308540496,
#  'Day_max_total_prior': 45.70881896148778,
#  'Day_mean_aa_prior': 15.135612484362147,
#  'Day_mean_ac_prior': 38.01893963205634,
#  'Day_mean_ca_prior': 15.848931924611204,
#  'Day_mean_cc_prior': 9.549925860214394,
#  'Day_mean_da_prior': 2.187761623949555,
#  'Day_mean_dc_prior': 16.59586907437568,
#  'Day_mean_total_prior': 4.36515832240167,
#  'Day_min_aa_prior': 3.1622776601683853,
#  'Day_min_ac_prior': 2.5118864315095837,
#  'Day_min_ca_prior': 1.9054607179632492,
#  'Day_min_cc_prior': 91.20108393559163,
#  'Day_min_da_prior': 2.5118864315095837,
#  'Day_min_dc_prior': 3.3113112148259174,
#  'Day_min_total_prior': 31.622776601683967,
#  'Month_count_aa_prior': 5.24807460249774,
#  'Month_count_ac_prior': 1.096478196143185,
#  'Month_count_ca_prior': 1.513561248436209,
#  'Month_count_cc_prior': 1.0471285480508996,
#  'Month_count_da_prior': 2.089296130854042,
#  'Month_count_dc_prior': 19.054607179632562,
#  'Month_count_total_prior': 2.7542287033381707,
#  'Month_max_aa_prior': 7.244359600749924,
#  'Month_max_ac_prior': 3.4673685045253233,
#  'Month_max_ca_prior': 2.398832919019494,
#  'Month_max_cc_prior': 57.543993733716064,
#  'Month_max_da_prior': 5.7543993733715855,
#  'Month_max_dc_prior': 83.17637711026768,
#  'Month_max_total_prior': 36.30780547701034,
#  'Month_mean_aa_prior': 2.089296130854042,
#  'Month_mean_ac_prior': 60.25595860743617,
#  'Month_mean_ca_prior': 41.68693834703379,
#  'Month_mean_cc_prior': 1.659586907437562,
#  'Month_mean_da_prior': 3.4673685045253233,
#  'Month_mean_dc_prior': 66.06934480076004,
#  'Month_mean_total_prior': 12.022644346174177,
#  'Month_min_aa_prior': 83.17637711026768,
#  'Month_min_ac_prior': 95.4992586021443,
#  'Month_min_ca_prior': 2.5118864315095837,
#  'Month_min_cc_prior': 1.737800828749377,
#  'Month_min_da_prior': 2.2908676527677763,
#  'Month_min_dc_prior': 34.67368504525336,
#  'Month_min_total_prior': 1.513561248436209,
#  'Promo2SinceWeek_count_aa_prior': 54.954087385762804,
#  'Promo2SinceWeek_count_ac_prior': 79.43282347242871,
#  'Promo2SinceWeek_count_ca_prior': 4.36515832240167,
#  'Promo2SinceWeek_count_cc_prior': 9.549925860214394,
#  'Promo2SinceWeek_count_da_prior': 3.4673685045253233,
#  'Promo2SinceWeek_count_dc_prior': 100.00000000000074,
#  'Promo2SinceWeek_count_total_prior': 69.18309709189411,
#  'Promo2SinceWeek_max_aa_prior': 41.68693834703379,
#  'Promo2SinceWeek_max_ac_prior': 1.3803842646028854,
#  'Promo2SinceWeek_max_ca_prior': 1.8197008586099852,
#  'Promo2SinceWeek_max_cc_prior': 16.59586907437568,
#  'Promo2SinceWeek_max_da_prior': 2.5118864315095837,
#  'Promo2SinceWeek_max_dc_prior': 95.4992586021443,
#  'Promo2SinceWeek_max_total_prior': 100.00000000000074,
#  'Promo2SinceWeek_mean_aa_prior': 21.877616239495634,
#  'Promo2SinceWeek_mean_ac_prior': 2.630267991895386,
#  'Promo2SinceWeek_mean_ca_prior': 2.398832919019494,
#  'Promo2SinceWeek_mean_cc_prior': 3.6307805477010207,
#  'Promo2SinceWeek_mean_da_prior': 3.0199517204020214,
#  'Promo2SinceWeek_mean_dc_prior': 7.9432823472428415,
#  ...}

# %%
def retrieve_clf(kw):
    from copy import deepcopy
    from time import time
    from fbprophet.diagnostics import generate_cutoffs, performance_metrics
    start_time = time()
    assert type(kw) == type(dict())
    
    n_changepoints = int(kw["n_changepoints"])
    changepoint_range = kw["changepoint_range"]
    seasonality_prior_scale = kw["seasonality_prior_scale"]
    holidays_prior_scale = kw["holidays_prior_scale"]
    changepoint_prior_scale = kw["changepoint_prior_scale"]
    
    yearly_fourier_order = int(kw["yearly_fourier_order"])
    weekly_fourier_order = int(kw["weekly_fourier_order"])
    monthly_fourier_order = int(kw["monthly_fourier_order"])

    yearly_prior = kw["yearly_prior"]
    weekly_prior = kw["weekly_prior"]
    monthly_prior = kw["monthly_prior"]

    kwargs = dict()
    kwargs["yearly_seasonality"] = False
    kwargs["daily_seasonality"] = False
    kwargs["weekly_seasonality"] = False
    kwargs["ext_args"] = {
    "seasonality": [],
    "reg": {}
}

    kwargs["ext_args"]["seasonality"].append(
    {
        "name": "yearly",
        "period": 365.25,
        "fourier_order": yearly_fourier_order,
        "prior_scale": yearly_prior
    }
)
    kwargs["ext_args"]["seasonality"].append(
    {
        "name": "weekly",
        "period": 7,
        "fourier_order": weekly_fourier_order,
        "prior_scale": weekly_prior
    }
)
    kwargs["ext_args"]["seasonality"].append(
    {
        "name": "monthly",
        "period": 30.5,
        "fourier_order": monthly_fourier_order,
        "prior_scale": monthly_prior
    }
)
    
    kwargs["n_changepoints"] = n_changepoints
    kwargs["seasonality_prior_scale"] = seasonality_prior_scale
    kwargs["holidays_prior_scale"] = holidays_prior_scale
    kwargs["changepoint_prior_scale"] = changepoint_prior_scale
    
    kwargs["changepoint_range"] = changepoint_range
    kwargs["add_reg"] = {
        "data": None, 
    }
    
    horizon = "7 days"
    period = "7 days"
    initial = "870 days"
    
    horizon, period, initial = map(pd.Timedelta, [horizon, period, initial])
    #df = pd.read_csv("/kaggle/input/sales-df/df.csv")
    #df = pd.read_csv("data/df.csv")
    df = pd.read_csv(df_path)
    shift_cols = list(filter(lambda x: x.startswith("Customers") or x.startswith("Sales"),df.columns.tolist()))
    #shift_cols = []
    for col in shift_cols:
        df[col] = df[col].shift(1).copy()
    #df = df.dropna()
    df = df.fillna(0)
    df["Date"] = pd.to_datetime(df["Date"])
    
    kwargs["add_reg"]["data"] = df
    
    other_cols = list(filter(lambda col: col not in ["Date"] + list(hierarchy.keys()) + list(hierarchy.values())[0] ,df.columns.tolist()))
    for col in other_cols:
        #exec("reg_{}_prior=kw['{}_prior']".format(col, col))
        #kwargs["reg"]["{}_prior".format(col)] = kw["{}_prior".format(col)]
        kwargs["ext_args"]["reg"]["{}_prior".format(col)] = kw["{}_prior".format(col)]
    #df = df[["Date"] + list(hierarchy.keys()) + list(hierarchy.values())[0]].copy()

    cutoffs = generate_cutoffs(df = df.reset_index().rename(columns ={"Date": "ds", "total": "y"})[["ds", "y"]],horizon=horizon, period=period, initial=initial)

    cutoffs_list = list(cutoffs)

    def cutoff_forecast_gen(input_df, cutoffs_list):
        if "Date" not in input_df.columns.tolist() and "ds" not in input_df.columns.tolist():
            input_df = input_df.reset_index() 
            ds_col = "Date"
        else:
            ds_col = "Date" if "Date" in input_df.columns.tolist() else "ds"
        assert ds_col in input_df.columns.tolist()
        input_df[ds_col] = pd.to_datetime(input_df[ds_col])
        for i in range(len(sorted(cutoffs_list)[:-1])):
            time = sorted(cutoffs_list)[i]
            df_for_fit = input_df[input_df[ds_col] <= time].copy()
            pred_length = (sorted(cutoffs_list)[i + 1] - time).days
            df_for_fit.index = df_for_fit[ds_col]
            del df_for_fit[ds_col]
            yield (df_for_fit, pred_length)

    cutoffs_gen = cutoff_forecast_gen(df, cutoffs_list=cutoffs_list)

    cutoffs_gen_list = list(cutoffs_gen)

    def single_fit_predict(total_df ,clf_for_cp, df_for_fit, hierarchy, pred_length, measure_cols = "total", return_errors = True):
        assert type(measure_cols) in [type([]), type("")]
        measure_cols_list = measure_cols if type(measure_cols) == type([]) else [measure_cols]
        from copy import deepcopy
        clf = deepcopy(clf_for_cp)
        df_for_fit = df_for_fit.asfreq("D")
        model = clf.fit(df_for_fit, hierarchy)
        preds = model.predict(steps_ahead=pred_length)
        if "Date" not in total_df.columns.tolist():
            total_df = total_df.reset_index()
        if "Date" not in preds.columns.tolist():
            preds = preds.reset_index()
        
        total_ds_col = list(map(lambda tt2: tt2[0] ,filter(lambda t2: t2[-1] ,total_df.dtypes.map(str).map(lambda x: x == "datetime64[ns]").to_dict().items())))[0]
        preds_ds_col = list(map(lambda tt2: tt2[0] ,filter(lambda t2: t2[-1] ,preds.dtypes.map(str).map(lambda x: x == "datetime64[ns]").to_dict().items())))[0]
        preds_lookup_part = preds.sort_values(by = preds_ds_col, ascending = True).tail(pred_length).copy()
        total_lookup_part = total_df[total_df[total_ds_col].isin(preds_lookup_part[preds_ds_col])]
        print("total_part {} preds_part {}".format(total_lookup_part.shape, preds_lookup_part.shape))
        assert len(set(measure_cols_list).intersection(set(total_lookup_part.columns.tolist()))) == len(measure_cols_list)
        assert len(set(measure_cols_list).intersection(set(preds_lookup_part.columns.tolist()))) == len(measure_cols_list)
        preds_lookup_part = preds_lookup_part[preds_lookup_part[preds_ds_col].isin(total_lookup_part[total_ds_col])]
        total_lookup_part = total_lookup_part.sort_values(by = total_ds_col, ascending = True)
        preds_lookup_part = preds_lookup_part.sort_values(by = preds_ds_col, ascending = True)
        if not return_errors:
            return (total_lookup_part[measure_cols_list], preds_lookup_part[measure_cols_list])
        
        measure_cols_errors = (total_lookup_part[measure_cols_list] - preds_lookup_part[measure_cols_list]).applymap(abs).mean(axis = 0)
        mean_errors = measure_cols_errors.mean()
        return (measure_cols_errors, mean_errors)
    
    clf = HTSRegressor_Add_Verison(model='prophet', revision_method='BU', n_jobs=4, low_memory=False, **kwargs)
    return clf
    
    '''
    def construct_df_cv_format(ori_df, pred_df, max_date, add_one = True):
        assert ori_df.columns.tolist() == pred_df.columns.tolist() and ori_df.shape == pred_df.shape
        ori_series_list = []
        pred_series_list = []
        cols = ori_df.columns.tolist()
        for col in cols:
            ori_series_list.append(ori_df[col])
            pred_series_list.append(pred_df[col])
        
        def bind_single_series(ori_s, pred_s):
            bind_df = pd.concat(list(map(pd.Series,[ori_s.values.tolist(), pred_s.values.tolist()])), axis = 1)
            assert bind_df.shape[0] == len(ori_s)
            bind_df.columns = ["y", "yhat"]
            if add_one:
                bind_df["y"] += 1
                bind_df["yhat"] += 1
            bind_df["ds"] = pd.date_range(max_date - pd.Timedelta("{}d".format(len(ori_s) - 1)), max_date)
            bind_df["cutoff"] = max_date - pd.Timedelta("{}d".format(len(ori_s)))
            return bind_df

        before_performance_list = list(map(lambda idx: ( ori_series_list[idx].name,bind_single_series(ori_series_list[idx], pred_series_list[idx])), range(len(ori_series_list))))
        different_part_dict = dict(map(lambda t2: (t2[0] ,performance_metrics(t2[-1], ["mape"])), before_performance_list))
        return dict(map(lambda t2: (t2[0], t2[1]["mape"].mean()) ,different_part_dict.items()))

    use_mape = True
    if use_mape:
        cutoffs_run_conclusions = list(map(lambda df_and_step:  (pd.Series(df_and_step[0].index.tolist()).max() ,single_fit_predict(df[["Date"] + list(hierarchy.keys()) + list(hierarchy.values())[0]] ,clf, df_and_step[0], hierarchy, df_and_step[1], ["total"], return_errors = False)), cutoffs_gen_list))
        dict_list = list(map(lambda t2: construct_df_cv_format(t2[-1][0], t2[-1][1], t2[0]), cutoffs_run_conclusions))
        from collections import defaultdict
        req = defaultdict(list)
        for dict_ in dict_list:
            for k, v in dict_.items():
                req[k].append(v)
        req_cp = dict()
        for k, v in req.items():
            req_cp[k] = pd.Series(v).mean()
        score = pd.Series(list(req_cp.values())).mean()
        #return score
    else:
        cutoffs_run_conclusions = list(map(lambda df_and_step:  (pd.Series(df_and_step[0].index.tolist()).max() ,single_fit_predict(df ,clf, df_and_step[0], hierarchy, df_and_step[1], ["total"], return_errors = True)), cutoffs_gen_list))
            
        cutoffs_run_conclusions_df = pd.DataFrame(cutoffs_run_conclusions)
        cutoffs_run_conclusions_df.columns = ["Date", "error"]
        data_unzipped = pd.concat(list(map(pd.Series ,cutoffs_run_conclusions_df["error"].map(lambda x: dict(x[0])).values.tolist())), axis = 1).T
        cutoffs_run_conclusions_df[data_unzipped.columns.tolist()] = data_unzipped
        cutoffs_run_conclusions_df = cutoffs_run_conclusions_df[["Date"] + data_unzipped.columns.tolist()]
        score = cutoffs_run_conclusions_df["total"].mean()
    
    
    import pickle as pkl
    import os
    retain_size = 100
    serlize_path = "/kaggle/working/serlize_m_dict.pkl"
    if os.path.exists(serlize_path):
        with open(serlize_path, "rb") as f:
            ori_serlize_m_dict = pkl.load(f)
        if len(ori_serlize_m_dict) > retain_size:
            ori_serlize_m_dict = dict(list(sorted(ori_serlize_m_dict.items(), key = lambda t2: t2[0]))[:retain_size])
    else:
        ori_serlize_m_dict = {}
    ori_serlize_m_dict = dict([(score, (kw, ))] + list(ori_serlize_m_dict.items()))
    
    ori_serlize_m_dict = dict(list(sorted(ori_serlize_m_dict.items(), key = lambda t2: t2[0]))[:retain_size])
    print("list length : {}".format(len(ori_serlize_m_dict)))
    
    with open(serlize_path, "wb") as f:
        pkl.dump(ori_serlize_m_dict, f)
    '''
    #print("time consum : {}".format(time() - start_time))
    
    #return score

# %%
best_clf = retrieve_clf(best_kw)

# %%
best_clf
# Out:
# HTSRegressor_Add_Verison(low_memory=False, model='prophet', n_jobs=4,
#                          revision_method=None, transform=None)

# %%
#cate_set
# Out:
# {'aa', 'ac', 'ca', 'cc', 'da', 'dc', 'total'}

# %%
model = best_clf.fit(df.head(len(df) - 6 * 7), hierarchy)
# Out:
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# will create leaf model - ca
# ----------
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (899, 1577) before shape (899, 2)
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# reg
# fit merge shape (899, 1577) before shape (899, 2)
# fit merge shape (899, 1577) before shape (899, 2)
# fit merge shape (899, 1577) before shape (899, 2)
# will create leaf model - cc
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:05<00:34,  5.70s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# will create leaf model - dc
# ----------
# Fitting models:  29%|██▊       | 2/7 [00:05<00:20,  4.05s/it]
# will create leaf model - da
# ----------
# Fitting models:  43%|████▎     | 3/7 [00:06<00:11,  2.87s/it]
# fit merge shape (899, 1577) before shape (899, 2)
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# Fitting models:  57%|█████▋    | 4/7 [00:06<00:06,  2.12s/it]
# fit merge shape (899, 1577) before shape (899, 2)
# fit merge shape (899, 1577) before shape (899, 2)
# Fitting models:  71%|███████▏  | 5/7 [00:07<00:03,  1.86s/it]
# Fitting models: 100%|██████████| 7/7 [00:08<00:00,  1.21s/it]

# %%
preds = model.predict(steps_ahead=6 * 7)
# Out:
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# pred merge shape (941, 1576) before shape (941, 1)
# pred merge shape (941, 1576) before shape (941, 1)
# pred merge shape (941, 1576) before shape (941, 1)
# pred merge shape (941, 1576) before shape (941, 1)
# Fitting models:  14%|█▍        | 1/7 [00:17<01:43, 17.29s/it]
# Fitting models:  29%|██▊       | 2/7 [00:17<01:00, 12.16s/it]
# pred merge shape (941, 1576) before shape (941, 1)
# pred merge shape (941, 1576) before shape (941, 1)
# Fitting models:  43%|████▎     | 3/7 [00:18<00:34,  8.70s/it]
# Fitting models:  57%|█████▋    | 4/7 [00:18<00:18,  6.12s/it]
# pred merge shape (941, 1576) before shape (941, 1)
# Fitting models:  71%|███████▏  | 5/7 [00:29<00:15,  7.82s/it]
# Fitting models:  86%|████████▌ | 6/7 [00:30<00:05,  5.51s/it]
# Fitting models: 100%|██████████| 7/7 [00:30<00:00,  4.34s/it]
# forecasts first key: aa

# %%
import seaborn as sns
dates = pd.Series(df.index.tolist())
ax = sns.lineplot(data = preds.reset_index()[["index", "total"]][preds.reset_index()["index"].isin(dates)][preds.reset_index()["index"] > "2015-01-01"], x = "index", y = "total")
ax.axes.set_ylim(0, 1.5 *int(1e7))
# Out:
# (0.0, 15000000.0)

# %%
ax = sns.lineplot(data = df.reset_index()[df.reset_index()["Date"] > "2015-01-01"], x = "Date", y = "total")
ax.axes.set_ylim(0, 1.5 *int(1e7))
# Out:
# (0.0, 15000000.0)

# %%
comp_df = pd.merge(preds[["total"]].tail(6 * 7), df[df.index.isin(preds["total"].index.tolist())][["total"]], left_index=True, right_index=True, how = "inner")

# %%
comp_df.columns = ["preds",  "ori"]

# %%
preds_df = comp_df[["preds"]].copy()
ori_df = comp_df[["ori"]].copy()
preds_df["cate"], ori_df["cate"] = "preds", "ori"
preds_df = preds_df.rename(columns={"preds": "val"})
ori_df = ori_df.rename(columns={"ori": "val"})
sns.lineplot(data = pd.concat([ori_df, preds_df], axis = 0).reset_index(), x = "index", y = "val", hue = "cate")

# %%
best_fit_score = object_func(best_kw)
# Out:
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# will create leaf model - ca
# ----------
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (871, 1577) before shape (871, 2)
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# seasonality yearly 365.25 40 1.737800828749377 added
# reg
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (871, 1577) before shape (871, 2)
# fit merge shape (871, 1577) before shape (871, 2)
# fit merge shape (871, 1577) before shape (871, 2)
# will create leaf model - cc
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:05<00:30,  5.05s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (871, 1577) before shape (871, 2)
# will create leaf model - dc
# ----------
# Fitting models:  29%|██▊       | 2/7 [00:05<00:18,  3.72s/it]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# Fitting models:  43%|████▎     | 3/7 [00:05<00:10,  2.66s/it]
# fit merge shape (871, 1577) before shape (871, 2)
# Fitting models:  57%|█████▋    | 4/7 [00:05<00:05,  1.90s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (871, 1577) before shape (871, 2)
# Fitting models:  71%|███████▏  | 5/7 [00:07<00:03,  1.69s/it]
# Fitting models: 100%|██████████| 7/7 [00:07<00:00,  1.07s/it]
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# pred merge shape (878, 1576) before shape (878, 1)
# pred merge shape (878, 1576) before shape (878, 1)
# pred merge shape (878, 1576) before shape (878, 1)
# pred merge shape (878, 1576) before shape (878, 1)
# Fitting models:  14%|█▍        | 1/7 [00:16<01:37, 16.31s/it]
# pred merge shape (878, 1576) before shape (878, 1)
# Fitting models:  29%|██▊       | 2/7 [00:16<00:57, 11.53s/it]
# pred merge shape (878, 1576) before shape (878, 1)
# Fitting models:  43%|████▎     | 3/7 [00:17<00:32,  8.21s/it]
# pred merge shape (878, 1576) before shape (878, 1)
# Fitting models:  57%|█████▋    | 4/7 [00:17<00:17,  5.96s/it]
# Fitting models:  71%|███████▏  | 5/7 [00:28<00:14,  7.42s/it]
# Fitting models:  86%|████████▌ | 6/7 [00:28<00:05,  5.27s/it]
# Fitting models: 100%|██████████| 7/7 [00:29<00:00,  4.16s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# will create leaf model - ca
# ----------
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# fit merge shape (878, 1577) before shape (878, 2)
# fit merge shape (878, 1577) before shape (878, 2)
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (878, 1577) before shape (878, 2)
# fit merge shape (878, 1577) before shape (878, 2)
# will create leaf model - cc
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:04<00:29,  4.98s/it]
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# Fitting models:  29%|██▊       | 2/7 [00:05<00:17,  3.56s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# will create leaf model - da
# ----------seasonality weekly 7 12 60.25595860743617 added
#
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# Fitting models:  43%|████▎     | 3/7 [00:05<00:10,  2.54s/it]
# fit merge shape (878, 1577) before shape (878, 2)
# seasonality yearly 365.25 40 1.737800828749377 added
# fit merge shape (878, 1577) before shape (878, 2)
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (878, 1577) before shape (878, 2)
# Fitting models:  57%|█████▋    | 4/7 [00:05<00:05,  1.89s/it]
# Fitting models:  71%|███████▏  | 5/7 [00:06<00:03,  1.59s/it]
# Fitting models: 100%|██████████| 7/7 [00:07<00:00,  1.03s/it]
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# pred merge shape (885, 1576) before shape (885, 1)
# pred merge shape (885, 1576) before shape (885, 1)
# pred merge shape (885, 1576) before shape (885, 1)
# pred merge shape (885, 1576) before shape (885, 1)
# Fitting models:  14%|█▍        | 1/7 [00:16<01:38, 16.42s/it]
# Fitting models:  29%|██▊       | 2/7 [00:16<00:57, 11.55s/it]
# pred merge shape (885, 1576) before shape (885, 1)
# pred merge shape (885, 1576) before shape (885, 1)
# Fitting models:  57%|█████▋    | 4/7 [00:16<00:24,  8.14s/it]
# pred merge shape (885, 1576) before shape (885, 1)
# Fitting models:  71%|███████▏  | 5/7 [00:28<00:18,  9.19s/it]
# Fitting models: 100%|██████████| 7/7 [00:28<00:00,  4.12s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# will create leaf model - ca
# ----------
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (885, 1577) before shape (885, 2)
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (885, 1577) before shape (885, 2)
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (885, 1577) before shape (885, 2)
# fit merge shape (885, 1577) before shape (885, 2)
# will create leaf model - cc
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:05<00:32,  5.45s/it]
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# Fitting models:  29%|██▊       | 2/7 [00:05<00:19,  3.86s/it]
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# reg
# fit merge shape (885, 1577) before shape (885, 2)
# will create leaf model - da
# ----------
# Fitting models:  43%|████▎     | 3/7 [00:05<00:11,  2.76s/it]
# fit merge shape (885, 1577) before shape (885, 2)
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (885, 1577) before shape (885, 2)
# Fitting models:  57%|█████▋    | 4/7 [00:06<00:06,  2.29s/it]
# Fitting models:  71%|███████▏  | 5/7 [00:07<00:03,  1.73s/it]
# Fitting models: 100%|██████████| 7/7 [00:07<00:00,  1.13s/it]
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# pred merge shape (892, 1576) before shape (892, 1)
# pred merge shape (892, 1576) before shape (892, 1)
# pred merge shape (892, 1576) before shape (892, 1)
# pred merge shape (892, 1576) before shape (892, 1)
# Fitting models:  14%|█▍        | 1/7 [00:16<01:36, 16.08s/it]
# pred merge shape (892, 1576) before shape (892, 1)
# Fitting models:  29%|██▊       | 2/7 [00:16<00:56, 11.37s/it]
# pred merge shape (892, 1576) before shape (892, 1)
# Fitting models:  43%|████▎     | 3/7 [00:17<00:32,  8.15s/it]
# pred merge shape (892, 1576) before shape (892, 1)
# Fitting models:  71%|███████▏  | 5/7 [00:28<00:14,  7.37s/it]
# Fitting models: 100%|██████████| 7/7 [00:28<00:00,  4.07s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# will create leaf model - ca
# ----------
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# fit merge shape (892, 1577) before shape (892, 2)
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# fit merge shape (892, 1577) before shape (892, 2)
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (892, 1577) before shape (892, 2)
# fit merge shape (892, 1577) before shape (892, 2)
# will create leaf model - cc
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:04<00:28,  4.78s/it]
# will create leaf model - dc
# ----------
# Fitting models:  29%|██▊       | 2/7 [00:04<00:16,  3.39s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (892, 1577) before shape (892, 2)
# fit merge shape (892, 1577) before shape (892, 2)
# will create leaf model - da
# ----------
# Fitting models:  43%|████▎     | 3/7 [00:05<00:10,  2.53s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (892, 1577) before shape (892, 2)
# Fitting models:  71%|███████▏  | 5/7 [00:06<00:03,  1.99s/it]
# Fitting models: 100%|██████████| 7/7 [00:07<00:00,  1.00s/it]
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# pred merge shape (899, 1576) before shape (899, 1)
# pred merge shape (899, 1576) before shape (899, 1)
# pred merge shape (899, 1576) before shape (899, 1)
# pred merge shape (899, 1576) before shape (899, 1)
# Fitting models:  14%|█▍        | 1/7 [00:15<01:35, 15.96s/it]
# pred merge shape (899, 1576) before shape (899, 1)
# Fitting models:  29%|██▊       | 2/7 [00:16<00:56, 11.38s/it]
# Fitting models:  43%|████▎     | 3/7 [00:16<00:32,  8.00s/it]
# pred merge shape (899, 1576) before shape (899, 1)
# pred merge shape (899, 1576) before shape (899, 1)
# Fitting models:  57%|█████▋    | 4/7 [00:16<00:16,  5.66s/it]
# Fitting models:  71%|███████▏  | 5/7 [00:28<00:14,  7.29s/it]
# Fitting models: 100%|██████████| 7/7 [00:28<00:00,  4.10s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# will create leaf model - ca
# ----------
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (899, 1577) before shape (899, 2)
# fit merge shape (899, 1577) before shape (899, 2)
# fit merge shape (899, 1577) before shape (899, 2)
# fit merge shape (899, 1577) before shape (899, 2)
# will create leaf model - cc
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:05<00:31,  5.31s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# will create leaf model - dc
# ----------
# Fitting models:  29%|██▊       | 2/7 [00:05<00:18,  3.76s/it]
# will create leaf model - da
# ----------
# Fitting models:  43%|████▎     | 3/7 [00:05<00:10,  2.66s/it]
# fit merge shape (899, 1577) before shape (899, 2)
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (899, 1577) before shape (899, 2)
# fit merge shape (899, 1577) before shape (899, 2)
# Fitting models:  71%|███████▏  | 5/7 [00:06<00:04,  2.06s/it]
# Fitting models: 100%|██████████| 7/7 [00:07<00:00,  1.09s/it]
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# pred merge shape (906, 1576) before shape (906, 1)
# pred merge shape (906, 1576) before shape (906, 1)
# pred merge shape (906, 1576) before shape (906, 1)
# pred merge shape (906, 1576) before shape (906, 1)
# Fitting models:  14%|█▍        | 1/7 [00:16<01:39, 16.61s/it]
# pred merge shape (906, 1576) before shape (906, 1)
# Fitting models:  29%|██▊       | 2/7 [00:17<00:58, 11.77s/it]
# Fitting models:  43%|████▎     | 3/7 [00:17<00:33,  8.27s/it]
# pred merge shape (906, 1576) before shape (906, 1)
# pred merge shape (906, 1576) before shape (906, 1)
# Fitting models:  71%|███████▏  | 5/7 [00:28<00:15,  7.54s/it]
# Fitting models: 100%|██████████| 7/7 [00:29<00:00,  4.17s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# will create leaf model - ca
# ----------
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (906, 1577) before shape (906, 2)
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (906, 1577) before shape (906, 2)
# fit merge shape (906, 1577) before shape (906, 2)
# fit merge shape (906, 1577) before shape (906, 2)
# will create leaf model - cc
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:04<00:27,  4.63s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (906, 1577) before shape (906, 2)
# will create leaf model - dc
# ----------
# Fitting models:  29%|██▊       | 2/7 [00:05<00:17,  3.46s/it]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# Fitting models:  43%|████▎     | 3/7 [00:05<00:09,  2.49s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# fit merge shape (906, 1577) before shape (906, 2)
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (906, 1577) before shape (906, 2)
# Fitting models:  57%|█████▋    | 4/7 [00:06<00:05,  1.95s/it]
# Fitting models:  71%|███████▏  | 5/7 [00:06<00:03,  1.54s/it]
# Fitting models:  86%|████████▌ | 6/7 [00:07<00:01,  1.19s/it]
# Fitting models: 100%|██████████| 7/7 [00:07<00:00,  1.06s/it]
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# pred merge shape (913, 1576) before shape (913, 1)
# pred merge shape (913, 1576) before shape (913, 1)
# pred merge shape (913, 1576) before shape (913, 1)
# pred merge shape (913, 1576) before shape (913, 1)
# Fitting models:  14%|█▍        | 1/7 [00:16<01:40, 16.82s/it]
# Fitting models:  29%|██▊       | 2/7 [00:16<00:59, 11.80s/it]
# pred merge shape (913, 1576) before shape (913, 1)
# pred merge shape (913, 1576) before shape (913, 1)
# Fitting models:  43%|████▎     | 3/7 [00:17<00:33,  8.49s/it]
# Fitting models:  57%|█████▋    | 4/7 [00:17<00:17,  5.99s/it]
# pred merge shape (913, 1576) before shape (913, 1)
# Fitting models:  71%|███████▏  | 5/7 [00:29<00:15,  7.60s/it]
# Fitting models: 100%|██████████| 7/7 [00:29<00:00,  4.22s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# will create leaf model - ca
# ----------
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# fit merge shape (913, 1577) before shape (913, 2)
# seasonality weekly 7 12 60.25595860743617 added
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality monthly 30.5 12 60.25595860743617 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality weekly 7 12 60.25595860743617 added
# reg
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (913, 1577) before shape (913, 2)
# fit merge shape (913, 1577) before shape (913, 2)
# fit merge shape (913, 1577) before shape (913, 2)
# will create leaf model - cc
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:05<00:32,  5.45s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (913, 1577) before shape (913, 2)
# will create leaf model - dc
# ----------
# Fitting models:  29%|██▊       | 2/7 [00:05<00:19,  3.88s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (913, 1577) before shape (913, 2)
# Fitting models:  43%|████▎     | 3/7 [00:06<00:11,  2.95s/it]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (913, 1577) before shape (913, 2)
# Fitting models:  57%|█████▋    | 4/7 [00:06<00:06,  2.20s/it]
# Fitting models:  71%|███████▏  | 5/7 [00:07<00:03,  1.66s/it]
# Fitting models:  86%|████████▌ | 6/7 [00:07<00:01,  1.28s/it]
# Fitting models: 100%|██████████| 7/7 [00:07<00:00,  1.13s/it]
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# pred merge shape (920, 1576) before shape (920, 1)
# pred merge shape (920, 1576) before shape (920, 1)
# pred merge shape (920, 1576) before shape (920, 1)
# pred merge shape (920, 1576) before shape (920, 1)
# Fitting models:  14%|█▍        | 1/7 [00:15<01:32, 15.45s/it]
# pred merge shape (920, 1576) before shape (920, 1)
# Fitting models:  29%|██▊       | 2/7 [00:16<00:54, 10.98s/it]
# Fitting models:  43%|████▎     | 3/7 [00:16<00:30,  7.73s/it]
# pred merge shape (920, 1576) before shape (920, 1)
# pred merge shape (920, 1576) before shape (920, 1)
# Fitting models:  71%|███████▏  | 5/7 [00:27<00:14,  7.16s/it]
# Fitting models: 100%|██████████| 7/7 [00:28<00:00,  4.00s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# will create leaf model - ca
# ----------
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# seasonality yearly 365.25 40 1.737800828749377 added
# reg
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (920, 1577) before shape (920, 2)
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (920, 1577) before shape (920, 2)
# fit merge shape (920, 1577) before shape (920, 2)
# fit merge shape (920, 1577) before shape (920, 2)
# will create leaf model - cc
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:05<00:30,  5.16s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
#
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# will create leaf model - dc
# ----------
# Fitting models:  29%|██▊       | 2/7 [00:05<00:18,  3.68s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# fit merge shape (920, 1577) before shape (920, 2)
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (920, 1577) before shape (920, 2)
# will create leaf model - da
# ----------
# Fitting models:  43%|████▎     | 3/7 [00:05<00:10,  2.74s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (920, 1577) before shape (920, 2)
# Fitting models:  57%|█████▋    | 4/7 [00:06<00:06,  2.05s/it]
# Fitting models:  71%|███████▏  | 5/7 [00:07<00:03,  1.67s/it]
# Fitting models: 100%|██████████| 7/7 [00:07<00:00,  1.05s/it]
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# pred merge shape (927, 1576) before shape (927, 1)
# pred merge shape (927, 1576) before shape (927, 1)
# pred merge shape (927, 1576) before shape (927, 1)
# pred merge shape (927, 1576) before shape (927, 1)
# Fitting models:  14%|█▍        | 1/7 [00:16<01:39, 16.52s/it]
# Fitting models:  29%|██▊       | 2/7 [00:16<00:58, 11.65s/it]
# pred merge shape (927, 1576) before shape (927, 1)
# Fitting models:  43%|████▎     | 3/7 [00:16<00:32,  8.20s/it]
# pred merge shape (927, 1576) before shape (927, 1)
# pred merge shape (927, 1576) before shape (927, 1)
# Fitting models:  57%|█████▋    | 4/7 [00:17<00:17,  5.81s/it]
# Fitting models:  71%|███████▏  | 5/7 [00:29<00:15,  7.66s/it]
# Fitting models: 100%|██████████| 7/7 [00:29<00:00,  4.20s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# will create leaf model - ca
# ----------
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# fit merge shape (927, 1577) before shape (927, 2)
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (927, 1577) before shape (927, 2)
# fit merge shape (927, 1577) before shape (927, 2)
# fit merge shape (927, 1577) before shape (927, 2)
# will create leaf model - cc
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:05<00:32,  5.42s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# will create leaf model - dc
# ----------reg
# Fitting models:  29%|██▊       | 2/7 [00:05<00:19,  3.85s/it]
# fit merge shape (927, 1577) before shape (927, 2)
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (927, 1577) before shape (927, 2)
# will create leaf model - da
# ----------
# Fitting models:  43%|████▎     | 3/7 [00:06<00:12,  3.05s/it]
# seasonality yearly 365.25 40 1.737800828749377 added
# seasonality weekly 7 12 60.25595860743617 added
# seasonality monthly 30.5 12 60.25595860743617 added
# reg
# fit merge shape (927, 1577) before shape (927, 2)
# Fitting models:  57%|█████▋    | 4/7 [00:07<00:07,  2.43s/it]
# Fitting models:  71%|███████▏  | 5/7 [00:08<00:03,  1.78s/it]
# Fitting models:  86%|████████▌ | 6/7 [00:08<00:01,  1.30s/it]
# Fitting models: 100%|██████████| 7/7 [00:09<00:00,  1.34s/it]
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# pred merge shape (934, 1576) before shape (934, 1)
# pred merge shape (934, 1576) before shape (934, 1)
# pred merge shape (934, 1576) before shape (934, 1)
# pred merge shape (934, 1576) before shape (934, 1)
# Fitting models:  14%|█▍        | 1/7 [00:18<01:52, 18.78s/it]
# pred merge shape (934, 1576) before shape (934, 1)
# Fitting models:  29%|██▊       | 2/7 [00:19<01:06, 13.28s/it]
# pred merge shape (934, 1576) before shape (934, 1)
# Fitting models:  43%|████▎     | 3/7 [00:19<00:38,  9.51s/it]
# pred merge shape (934, 1576) before shape (934, 1)
# Fitting models:  71%|███████▏  | 5/7 [00:31<00:16,  8.39s/it]
# Fitting models:  86%|████████▌ | 6/7 [00:31<00:05,  5.91s/it]
# Fitting models: 100%|██████████| 7/7 [00:31<00:00,  4.55s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# time consum : 337.3807063102722

# %%
best_fit_score
# Out:
# 0.06496026419008498
