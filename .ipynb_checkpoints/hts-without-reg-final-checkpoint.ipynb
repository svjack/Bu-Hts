# %%
get_ipython().system('pip3 install scikit-hts')
# Out:
# Collecting scikit-hts
#   Downloading https://files.pythonhosted.org/packages/5a/83/9f0865ad11ababc00f909cb29e64ad3030ff8ded701a0c36b2ecce8c94b0/scikit_hts-0.5.2-py2.py3-none-any.whl
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.6/dist-packages (from scikit-hts) (1.0.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.6/dist-packages (from scikit-hts) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.6/dist-packages (from scikit-hts) (1.18.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.6/dist-packages (from scikit-hts) (1.4.1)
# Collecting tqdm==4.43
#   Downloading https://files.pythonhosted.org/packages/47/55/fd9170ba08a1a64a18a7f8a18f088037316f2a41be04d2fe6ece5a653e8f/tqdm-4.43.0-py2.py3-none-any.whl (59kB)
#      |████████████████████████████████| 61kB 2.8MB/s
# Requirement already satisfied: statsmodels==0.10.2 in /usr/local/lib/python3.6/dist-packages (from scikit-hts) (0.10.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.25.3->scikit-hts) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.25.3->scikit-hts) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.21.3->scikit-hts) (0.16.0)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from statsmodels==0.10.2->scikit-hts) (0.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.25.3->scikit-hts) (1.15.0)
# Installing collected packages: tqdm, scikit-hts
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# Successfully installed scikit-hts-0.5.2 tqdm-4.43.0

# %%
get_ipython().system('pip3 install pmdarima')
# Out:
# Collecting pmdarima
#   Downloading https://files.pythonhosted.org/packages/4b/15/0dfc38deb2f5582b79baff6523b245d6a3dbe877e3fb96a1ee39ec63b626/pmdarima-1.6.1-cp36-cp36m-manylinux1_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 2.7MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (0.16.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.0.5)
# Collecting Cython<0.29.18,>=0.29
#   Downloading https://files.pythonhosted.org/packages/e7/d7/510ddef0248f3e1e91f9cc7e31c0f35f8954d0af92c5c3fd4c853e859ebe/Cython-0.29.17-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 30kB/s
# Collecting statsmodels>=0.11
#   Downloading https://files.pythonhosted.org/packages/cb/83/540fd83238a18abe6c2d280fa8e489ac5fcefa1f370f0ca1acd16ae1b860/statsmodels-0.11.1-cp36-cp36m-manylinux1_x86_64.whl (8.7MB)
#      |████████████████████████████████| 8.6MB 22.2MB/s eta 0:00:01     |████████████████████████████████| 8.7MB 22.2MB/s
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.18.5)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (0.22.2.post1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.6/dist-packages (from statsmodels>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.19->pmdarima) (1.15.0)
# ERROR: scikit-hts 0.5.2 has requirement statsmodels==0.10.2, but you'll have statsmodels 0.11.1 which is incompatible.
# Installing collected packages: Cython, statsmodels, pmdarima
#   Found existing installation: Cython 0.29.21
#     Uninstalling Cython-0.29.21:
#       Successfully uninstalled Cython-0.29.21
#   Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed Cython-0.29.17 pmdarima-1.6.1 statsmodels-0.11.1

# %%
import numpy as np
import pandas as pd
from fbprophet import Prophet
import os
import json

# %%
import inspect
def get_default_args(func):
    signature = inspect.signature(func)
    return{
        k: v.default
        for k, v in signature.parameters.items()
        if v.default is not inspect.Parameter.empty 
    }

prophet_defaults = get_default_args(Prophet)

# %%
'''
#df = pd.read_csv("/kaggle/input/sales-df/df.csv")
df = pd.read_csv("data/df.csv")
#with open("/kaggle/input/hier-json/hierarchy.json", "r") as f:
with open("data/hierarchy.json", "r") as f:
    hierarchy = json.load(f)  
if "Date" in df.columns.tolist():
    df.index = pd.to_datetime(df["Date"])
    del df["Date"]
df = df.asfreq("D")
'''
# Out:
# '\n#df = pd.read_csv("/kaggle/input/sales-df/df.csv")\ndf = pd.read_csv("data/df.csv")\n#with open("/kaggle/input/hier-json/hierarchy.json", "r") as f:\nwith open("data/hierarchy.json", "r") as f:\n    hierarchy = json.load(f)  \nif "Date" in df.columns.tolist():\n    df.index = pd.to_datetime(df["Date"])\n    del df["Date"]\ndf = df.asfreq("D")\n'

# %%
with open("data/hierarchy.json", "r") as f:
    hierarchy = json.load(f)
df_path = "df_add_lookup.csv"
df = pd.read_csv(df_path)
shift_cols = list(filter(lambda x: x.startswith("Customers") or x.startswith("Sales"),df.columns.tolist()))
for col in shift_cols:
    df[col] = df[col].shift(1)
#df = df.dropna()
df = df.fillna(0)
if "Date" in df.columns.tolist():
    df.index = pd.to_datetime(df["Date"])
    del df["Date"]
df = df.asfreq("D")

# %%
#df.head()

# %%
#first_df, second_df = pd.read_csv("data/df.csv"), pd.read_csv("df_add_lookup.csv")

# %%
#first_df.shape, second_df.shape

# %%
#(first_df.iloc[:, 1:] - second_df[first_df.iloc[:, 1:].columns.tolist()]).applymap(np.abs).mean()

# %%
#df.shape

# %%
#from hts.hierarchy import HierarchyTree
#ht = HierarchyTree.from_nodes(nodes = hierarchy, df = df)

# %%
#type(ht.children[0]), type(ht)
#ht.key, ht.children[0].key
#ht.item

# %%
#list(hierarchy.keys()) + list(hierarchy.values())[0]

# %%
head_set = set(filter(lambda x: "_" in x ,map(lambda col: col[:col.rfind("_")] ,df.columns.tolist())))
cate_set = set(filter(lambda x: "_" not in x ,map(lambda col: col[col.rfind("_") + 1:] ,df.columns.tolist())))

# %%
#head_set

# %%
#"Promo2SinceWeek_mean_total" in df.columns.tolist()

# %%
from hts.model import FBProphetModel
from hts.model.p import *
class FBProphetModel_Add_Version(FBProphetModel):
    def create_model(self, *args, **kwargs):
        self.lookup_df = None
        has_children = bool(self.node.children)
        is_children = not has_children
        print("will create {} model {}".format("leaf" if is_children else "branch", self.node) + "-" * 10)
        if "ext_args" not in kwargs:
            return super(FBProphetModel_Add_Version, self).create_model(*args, **kwargs)
        base_kwargs = dict()
        for k, v in kwargs.items():
            if k not in ["ext_args", "add_reg"]:
                base_kwargs[k] = v
        base_model = super(FBProphetModel_Add_Version, self).create_model(*args, **base_kwargs)
        #base_model = super().create_model(*args, **kwargs)
        ext_args_dict = kwargs["ext_args"]
        if "seasonality" in ext_args_dict:
            assert type(ext_args_dict["seasonality"]) == type([])
            for seasonality_dict in ext_args_dict["seasonality"]:
                name, period, fourier_order, prior_scale = seasonality_dict["name"], seasonality_dict["period"], seasonality_dict["fourier_order"], seasonality_dict["prior_scale"]
                base_model.add_seasonality(name = name, period = period, fourier_order = fourier_order, prior_scale =prior_scale)
                print("seasonality {} {} {} {} added".format(name, period, fourier_order, prior_scale))
        if "add_reg" in kwargs and "data" in kwargs["add_reg"] and kwargs["add_reg"]["data"] is not None:
            assert "reg" in ext_args_dict
            print("reg")
            reg_prior_dict = ext_args_dict["reg"]
            self.lookup_df = kwargs["add_reg"]["data"]
            cate = self.node.key
            assert cate in cate_set
            for col in map(lambda x: "{}_{}".format(x, cate), head_set):
                if "_mean_" in col:
                    prior_scale = reg_prior_dict["{}_prior".format(col)]
                    base_model.add_regressor(col, prior_scale = prior_scale)
                    #print("reg {} added".format(col))
        return base_model
    def fit(self, **fit_args) -> 'TimeSeriesModel':
        df = self._reformat(self.node.item)

        if self.lookup_df is not None:
            lookup_df = self.lookup_df
            before_shape = df.shape
            if "Date" not in lookup_df.columns.tolist():
                lookup_df = lookup_df.reset_index()
            ds_col = list(map(lambda tt2: tt2[0] ,filter(lambda t2: t2[-1] ,lookup_df.dtypes.map(str).map(lambda x: x == "datetime64[ns]").to_dict().items())))[0]
            lookup_df = lookup_df.rename(columns = {ds_col: "ds"})
            df = pd.merge(df, lookup_df, on = "ds", how = "inner")
            print("fit merge shape {} before shape {}".format(df.shape, before_shape))
            
        with suppress_stdout_stderr():
            self.model = self.model.fit(df)
            self.model.stan_backend = None
        return self

    def predict(self,
                node: HierarchyTree,
                freq: str = 'D',
                steps_ahead: int = 1):

        df = self._reformat(node.item)
        future = self.model.make_future_dataframe(periods=steps_ahead,
                                                  freq=freq,
                                                  include_history=True)
        if self.cap:
            future['cap'] = self.cap
        if self.floor:
            future['floor'] = self.floor
        
        if self.lookup_df is not None:
            lookup_df = self.lookup_df
            before_shape = future.shape
            if "Date" not in lookup_df.columns.tolist():
                lookup_df = lookup_df.reset_index()
            ds_col = list(map(lambda tt2: tt2[0] ,filter(lambda t2: t2[-1] ,lookup_df.dtypes.map(str).map(lambda x: x == "datetime64[ns]").to_dict().items())))[0]
            lookup_df = lookup_df.rename(columns = {ds_col: "ds"})
            future = pd.merge(future, lookup_df, on = "ds", how = "inner")
            print("pred merge shape {} before shape {}".format(future.shape, before_shape))
        
        self.forecast = self.model.predict(future)
        merged = pandas.merge(df, self.forecast, on='ds')
        self.residual = (merged['yhat'] - merged['y']).values
        self.mse = numpy.mean(numpy.array(self.residual) ** 2)
        if self.cap is not None:
            self.forecast.yhat = numpy.exp(self.forecast.yhat)
        if self.transform:
            self.forecast.yhat = self.transformer.inverse_transform(self.forecast.yhat)
            self.forecast.trend = self.transformer.inverse_transform(self.forecast.trend)
            for component in ["seasonal", "daily", "weekly", "yearly", "holidays"]:
                if component in self.forecast.columns.tolist():
                    inv_transf = self.transformer.inverse_transform(getattr(self.forecast, component))
                    setattr(self.forecast, component, inv_transf)
        return self

# %%
from hts.revision import *
class RevisionMethod_BU(RevisionMethod):
    def _y_hat_matrix(self, forecasts):
        print("forecasts first key: {}".format(list(forecasts.keys())[0]))
        n_cols = len(list(forecasts.keys())) + 1
        keys = range(n_cols - self.sum_mat.shape[1] - 1, n_cols - 1)
        #named_keys = list(map(lambda k_idx: list(forecasts.keys())[k_idx], keys))
        named_keys = list(set(forecasts.keys()).difference(set(["total"])))
        return y_hat_matrix(forecasts, keys=named_keys)

# %%
from hts.core.regressor import *
class HTSRegressor_Add_Verison(HTSRegressor):
    def _init_revision(self):
        self.revision_method = RevisionMethod_BU(sum_mat=self.sum_mat, transformer=self.transform, name=self.method)
    def _set_model_instance(self):
        from hts import model as hts_models
        from copy import deepcopy
        model_mapping = deepcopy(hts_models.MODEL_MAPPING)
        model_mapping["prophet"] = FBProphetModel_Add_Version
        try:
            self.model_instance = model_mapping[self.model]
        except KeyError:
            raise InvalidArgumentException(f'Model {self.model} not valid. Pick one of: {" ".join(Model.names())}')
            
    def _revise(self, steps_ahead=1):
        logger.info(f'Reconciling forecasts using {self.revision_method}')
        revised = self.revision_method.revise(
            forecasts=self.hts_result.forecasts,
            mse=self.hts_result.errors,
            nodes=self.nodes
        )

        revised_columns = list(make_iterable(self.nodes))
        revised_index = self._get_predict_index(steps_ahead=steps_ahead)
        return pandas.DataFrame(revised,
                                index=revised_index,
                                columns=revised_columns)

# %%
def object_func(kw):
    from copy import deepcopy
    from time import time
    from fbprophet.diagnostics import generate_cutoffs, performance_metrics
    start_time = time()
    assert type(kw) == type(dict())
    
    n_changepoints = int(kw["n_changepoints"])
    changepoint_range = kw["changepoint_range"]
    seasonality_prior_scale = kw["seasonality_prior_scale"]
    holidays_prior_scale = kw["holidays_prior_scale"]
    changepoint_prior_scale = kw["changepoint_prior_scale"]
    
    yearly_fourier_order = int(kw["yearly_fourier_order"])
    weekly_fourier_order = int(kw["weekly_fourier_order"])
    monthly_fourier_order = int(kw["monthly_fourier_order"])

    yearly_prior = kw["yearly_prior"]
    weekly_prior = kw["weekly_prior"]
    monthly_prior = kw["monthly_prior"]

    kwargs = dict()
    kwargs["yearly_seasonality"] = False
    kwargs["daily_seasonality"] = False
    kwargs["weekly_seasonality"] = False
    kwargs["ext_args"] = {
    "seasonality": [],
    "reg": {}
}

    kwargs["ext_args"]["seasonality"].append(
    {
        "name": "yearly",
        "period": 365.25,
        "fourier_order": yearly_fourier_order,
        "prior_scale": yearly_prior
    }
)
    kwargs["ext_args"]["seasonality"].append(
    {
        "name": "weekly",
        "period": 7,
        "fourier_order": weekly_fourier_order,
        "prior_scale": weekly_prior
    }
)
    kwargs["ext_args"]["seasonality"].append(
    {
        "name": "monthly",
        "period": 30.5,
        "fourier_order": monthly_fourier_order,
        "prior_scale": monthly_prior
    }
)
    
    kwargs["n_changepoints"] = n_changepoints
    kwargs["seasonality_prior_scale"] = seasonality_prior_scale
    kwargs["holidays_prior_scale"] = holidays_prior_scale
    kwargs["changepoint_prior_scale"] = changepoint_prior_scale
    
    kwargs["changepoint_range"] = changepoint_range
    kwargs["add_reg"] = {
        "data": None, 
    }
    
    horizon = "7 days"
    period = "7 days"
    initial = "870 days"
    
    horizon, period, initial = map(pd.Timedelta, [horizon, period, initial])
    #df = pd.read_csv("/kaggle/input/sales-df/df.csv")
    #df = pd.read_csv("data/df.csv")
    df = pd.read_csv(df_path)
    shift_cols = list(filter(lambda x: x.startswith("Customers") or x.startswith("Sales"),df.columns.tolist()))
    #shift_cols = []
    for col in shift_cols:
        df[col] = df[col].shift(1).copy()
    #df = df.dropna()
    df = df.fillna(0)
    df["Date"] = pd.to_datetime(df["Date"])
    
    kwargs["add_reg"]["data"] = df
    
    other_cols = list(filter(lambda col: col not in ["Date"] + list(hierarchy.keys()) + list(hierarchy.values())[0] ,df.columns.tolist()))
    for col in other_cols:
        #exec("reg_{}_prior=kw['{}_prior']".format(col, col))
        #kwargs["reg"]["{}_prior".format(col)] = kw["{}_prior".format(col)]
        kwargs["ext_args"]["reg"]["{}_prior".format(col)] = kw["{}_prior".format(col)]
    #df = df[["Date"] + list(hierarchy.keys()) + list(hierarchy.values())[0]].copy()

    cutoffs = generate_cutoffs(df = df.reset_index().rename(columns ={"Date": "ds", "total": "y"})[["ds", "y"]],horizon=horizon, period=period, initial=initial)

    cutoffs_list = list(cutoffs)

    def cutoff_forecast_gen(input_df, cutoffs_list):
        if "Date" not in input_df.columns.tolist() and "ds" not in input_df.columns.tolist():
            input_df = input_df.reset_index() 
            ds_col = "Date"
        else:
            ds_col = "Date" if "Date" in input_df.columns.tolist() else "ds"
        assert ds_col in input_df.columns.tolist()
        input_df[ds_col] = pd.to_datetime(input_df[ds_col])
        for i in range(len(sorted(cutoffs_list)[:-1])):
            time = sorted(cutoffs_list)[i]
            df_for_fit = input_df[input_df[ds_col] <= time].copy()
            pred_length = (sorted(cutoffs_list)[i + 1] - time).days
            df_for_fit.index = df_for_fit[ds_col]
            del df_for_fit[ds_col]
            yield (df_for_fit, pred_length)

    cutoffs_gen = cutoff_forecast_gen(df, cutoffs_list=cutoffs_list)

    cutoffs_gen_list = list(cutoffs_gen)

    def single_fit_predict(total_df ,clf_for_cp, df_for_fit, hierarchy, pred_length, measure_cols = "total", return_errors = True):
        assert type(measure_cols) in [type([]), type("")]
        measure_cols_list = measure_cols if type(measure_cols) == type([]) else [measure_cols]
        from copy import deepcopy
        clf = deepcopy(clf_for_cp)
        df_for_fit = df_for_fit.asfreq("D")
        model = clf.fit(df_for_fit, hierarchy)
        preds = model.predict(steps_ahead=pred_length)
        if "Date" not in total_df.columns.tolist():
            total_df = total_df.reset_index()
        if "Date" not in preds.columns.tolist():
            preds = preds.reset_index()
        
        total_ds_col = list(map(lambda tt2: tt2[0] ,filter(lambda t2: t2[-1] ,total_df.dtypes.map(str).map(lambda x: x == "datetime64[ns]").to_dict().items())))[0]
        preds_ds_col = list(map(lambda tt2: tt2[0] ,filter(lambda t2: t2[-1] ,preds.dtypes.map(str).map(lambda x: x == "datetime64[ns]").to_dict().items())))[0]
        preds_lookup_part = preds.sort_values(by = preds_ds_col, ascending = True).tail(pred_length).copy()
        total_lookup_part = total_df[total_df[total_ds_col].isin(preds_lookup_part[preds_ds_col])]
        print("total_part {} preds_part {}".format(total_lookup_part.shape, preds_lookup_part.shape))
        assert len(set(measure_cols_list).intersection(set(total_lookup_part.columns.tolist()))) == len(measure_cols_list)
        assert len(set(measure_cols_list).intersection(set(preds_lookup_part.columns.tolist()))) == len(measure_cols_list)
        preds_lookup_part = preds_lookup_part[preds_lookup_part[preds_ds_col].isin(total_lookup_part[total_ds_col])]
        total_lookup_part = total_lookup_part.sort_values(by = total_ds_col, ascending = True)
        preds_lookup_part = preds_lookup_part.sort_values(by = preds_ds_col, ascending = True)
        if not return_errors:
            return (total_lookup_part[measure_cols_list], preds_lookup_part[measure_cols_list])
        
        measure_cols_errors = (total_lookup_part[measure_cols_list] - preds_lookup_part[measure_cols_list]).applymap(abs).mean(axis = 0)
        mean_errors = measure_cols_errors.mean()
        return (measure_cols_errors, mean_errors)
    
    clf = HTSRegressor_Add_Verison(model='prophet', revision_method='BU', n_jobs=2, low_memory=False, **kwargs)
    
    def construct_df_cv_format(ori_df, pred_df, max_date, add_one = True):
        assert ori_df.columns.tolist() == pred_df.columns.tolist() and ori_df.shape == pred_df.shape
        ori_series_list = []
        pred_series_list = []
        cols = ori_df.columns.tolist()
        for col in cols:
            ori_series_list.append(ori_df[col])
            pred_series_list.append(pred_df[col])
        
        def bind_single_series(ori_s, pred_s):
            bind_df = pd.concat(list(map(pd.Series,[ori_s.values.tolist(), pred_s.values.tolist()])), axis = 1)
            assert bind_df.shape[0] == len(ori_s)
            bind_df.columns = ["y", "yhat"]
            if add_one:
                bind_df["y"] += 1
                bind_df["yhat"] += 1
            bind_df["ds"] = pd.date_range(max_date - pd.Timedelta("{}d".format(len(ori_s) - 1)), max_date)
            bind_df["cutoff"] = max_date - pd.Timedelta("{}d".format(len(ori_s)))
            return bind_df

        before_performance_list = list(map(lambda idx: ( ori_series_list[idx].name,bind_single_series(ori_series_list[idx], pred_series_list[idx])), range(len(ori_series_list))))
        different_part_dict = dict(map(lambda t2: (t2[0] ,performance_metrics(t2[-1], ["mape"])), before_performance_list))
        return dict(map(lambda t2: (t2[0], t2[1]["mape"].mean()) ,different_part_dict.items()))

    use_mape = True
    if use_mape:
        cutoffs_run_conclusions = list(map(lambda df_and_step:  (pd.Series(df_and_step[0].index.tolist()).max() ,single_fit_predict(df[["Date"] + list(hierarchy.keys()) + list(hierarchy.values())[0]] ,clf, df_and_step[0], hierarchy, df_and_step[1], ["total"], return_errors = False)), cutoffs_gen_list))
        dict_list = list(map(lambda t2: construct_df_cv_format(t2[-1][0], t2[-1][1], t2[0]), cutoffs_run_conclusions))
        from collections import defaultdict
        req = defaultdict(list)
        for dict_ in dict_list:
            for k, v in dict_.items():
                req[k].append(v)
        req_cp = dict()
        for k, v in req.items():
            req_cp[k] = pd.Series(v).mean()
        score = pd.Series(list(req_cp.values())).mean()
        #return score
    else:
        cutoffs_run_conclusions = list(map(lambda df_and_step:  (pd.Series(df_and_step[0].index.tolist()).max() ,single_fit_predict(df ,clf, df_and_step[0], hierarchy, df_and_step[1], ["total"], return_errors = True)), cutoffs_gen_list))
            
        cutoffs_run_conclusions_df = pd.DataFrame(cutoffs_run_conclusions)
        cutoffs_run_conclusions_df.columns = ["Date", "error"]
        data_unzipped = pd.concat(list(map(pd.Series ,cutoffs_run_conclusions_df["error"].map(lambda x: dict(x[0])).values.tolist())), axis = 1).T
        cutoffs_run_conclusions_df[data_unzipped.columns.tolist()] = data_unzipped
        cutoffs_run_conclusions_df = cutoffs_run_conclusions_df[["Date"] + data_unzipped.columns.tolist()]
        score = cutoffs_run_conclusions_df["total"].mean()
    
    import pickle as pkl
    import os
    retain_size = 100
    serlize_path = "serlize_m_dict.pkl"
    if os.path.exists(serlize_path):
        with open(serlize_path, "rb") as f:
            ori_serlize_m_dict = pkl.load(f)
        if len(ori_serlize_m_dict) > retain_size:
            ori_serlize_m_dict = dict(list(sorted(ori_serlize_m_dict.items(), key = lambda t2: t2[0]))[:retain_size])
    else:
        ori_serlize_m_dict = {}
    ori_serlize_m_dict = dict([(score, (kw, ))] + list(ori_serlize_m_dict.items()))
    
    ori_serlize_m_dict = dict(list(sorted(ori_serlize_m_dict.items(), key = lambda t2: t2[0]))[:retain_size])
    print("list length : {}".format(len(ori_serlize_m_dict)))
    
    with open(serlize_path, "wb") as f:
        pkl.dump(ori_serlize_m_dict, f)
    print("time consum : {}".format(time() - start_time))
    
    return score

# %%
req_keys = [
         'n_changepoints',
     'changepoint_range',
     'seasonality_prior_scale',
     'holidays_prior_scale',
     'changepoint_prior_scale',
        "yearly_fourier_order",
        "weekly_fourier_order",
        "monthly_fourier_order",

    "yearly_prior",
    "weekly_prior",
    "monthly_prior",
]


have_kv_dict = {
    "yearly_fourier_order": 1,
    "monthly_fourier_order": 2,

    "yearly_prior": 10,
    "monthly_prior": 10,
    "yearly_on_season_prior": 10, 

    "weekly_fourier_order": 5,
    "weekly_prior": 18,
    
}

other_cols = list(filter(lambda col: col not in ["Date"] + list(hierarchy.keys()) + list(hierarchy.values())[0] ,df.columns.tolist()))
req_keys.extend(list(map(lambda col: "{}_prior".format(col) ,other_cols)))

for col in other_cols:
    have_kv_dict["{}_prior".format(col)] = 10

from hyperopt import hp
from hyperopt import fmin, tpe


tiny_space = {
'n_changepoints': hp.choice("n_changepoints", list(range(5, 45))),
 'changepoint_range': hp.uniform("changepoint_range", 0.5, 1.0),
 'seasonality_prior_scale': hp.uniform("seasonality_prior_scale", 5.0, 50.0),
 'holidays_prior_scale': hp.uniform("holidays_prior_scale", 5.0, 60.0),
 'changepoint_prior_scale': hp.uniform("changepoint_prior_scale", 0.0001, 0.1),
 'yearly_fourier_order': hp.choice("yearly_fourier_order", list(range(1, 70))),
 'monthly_fourier_order': hp.choice("monthly_fourier_order", list(range(1, 35))),
    
  "yearly_prior": hp.choice("yearly_prior", np.logspace(1, 100, num = 100, base = 100 ** (1 / 100))),
    "monthly_prior":hp.choice("monthly_prior", np.logspace(1, 100, num = 100, base = 100 ** (1 / 100))),

"weekly_prior":hp.choice("weekly_prior", np.logspace(1, 100, num = 100, base = 100 ** (1 / 100))),
'weekly_fourier_order': hp.choice("weekly_fourier_order", list(range(1, 35))),
    
}

for col in other_cols:
    tiny_space["{}_prior".format(col)] = hp.choice("{}_prior".format(col), np.logspace(1, 100, num = 100, base = 100 ** (1 / 100)))

# %%
set_default_dict = dict(map(lambda k:(k, have_kv_dict[k]) if k in have_kv_dict else (k, prophet_defaults[k]), req_keys))

# %%
set_default_dict
# Out:
# {'n_changepoints': 25,
#  'changepoint_range': 0.8,
#  'seasonality_prior_scale': 10.0,
#  'holidays_prior_scale': 10.0,
#  'changepoint_prior_scale': 0.05,
#  'yearly_fourier_order': 1,
#  'weekly_fourier_order': 5,
#  'monthly_fourier_order': 2,
#  'yearly_prior': 10,
#  'weekly_prior': 18,
#  'monthly_prior': 10,
#  '25_max_da_prior': 10,
#  'CompetitionOpenSinceMonth_max_da_prior': 10,
#  'CompetitionDistance_max_da_prior': 10,
#  '9_max_da_prior': 10,
#  '12_max_da_prior': 10,
#  'SchoolHoliday_max_da_prior': 10,
#  'Promo2_max_da_prior': 10,
#  'PromoInterval_Mar_max_da_prior': 10,
#  'Promo2SinceYear_max_da_prior': 10,
#  '2_max_da_prior': 10,
#  '6_max_da_prior': 10,
#  '13_max_da_prior': 10,
#  '21_max_da_prior': 10,
#  '0_max_da_prior': 10,
#  '16_max_da_prior': 10,
#  '18_max_da_prior': 10,
#  'PromoInterval_Oct_max_da_prior': 10,
#  'Day_max_da_prior': 10,
#  '4_max_da_prior': 10,
#  '26_max_da_prior': 10,
#  '1_max_da_prior': 10,
#  'Sales_max_da_prior': 10,
#  '15_max_da_prior': 10,
#  'PromoInterval_Aug_max_da_prior': 10,
#  '7_max_da_prior': 10,
#  'PromoInterval_Apr_max_da_prior': 10,
#  'PromoInterval_Jul_max_da_prior': 10,
#  '5_max_da_prior': 10,
#  'PromoInterval_Nov_max_da_prior': 10,
#  'WeekOfYear_max_da_prior': 10,
#  '3_max_da_prior': 10,
#  'SalesPerCustomer_max_da_prior': 10,
#  '22_max_da_prior': 10,
#  '24_max_da_prior': 10,
#  'Month_max_da_prior': 10,
#  'PromoInterval_Feb_max_da_prior': 10,
#  'Promo2SinceWeek_max_da_prior': 10,
#  '11_max_da_prior': 10,
#  '20_max_da_prior': 10,
#  '10_max_da_prior': 10,
#  'PromoInterval_Dec_max_da_prior': 10,
#  'PromoInterval_Jan_max_da_prior': 10,
#  'Promo_max_da_prior': 10,
#  'PromoInterval_Sept_max_da_prior': 10,
#  'Customers_max_da_prior': 10,
#  'CompetitionOpenSinceYear_max_da_prior': 10,
#  'Date_max_da_prior': 10,
#  '8_max_da_prior': 10,
#  '17_max_da_prior': 10,
#  '23_max_da_prior': 10,
#  'PromoInterval_May_max_da_prior': 10,
#  '19_max_da_prior': 10,
#  'DayOfWeek_max_da_prior': 10,
#  'Year_max_da_prior': 10,
#  'PromoInterval_Jun_max_da_prior': 10,
#  '14_max_da_prior': 10,
#  '25_min_da_prior': 10,
#  'CompetitionOpenSinceMonth_min_da_prior': 10,
#  'CompetitionDistance_min_da_prior': 10,
#  '9_min_da_prior': 10,
#  '12_min_da_prior': 10,
#  'SchoolHoliday_min_da_prior': 10,
#  'Promo2_min_da_prior': 10,
#  'PromoInterval_Mar_min_da_prior': 10,
#  'Promo2SinceYear_min_da_prior': 10,
#  '2_min_da_prior': 10,
#  '6_min_da_prior': 10,
#  '13_min_da_prior': 10,
#  '21_min_da_prior': 10,
#  '0_min_da_prior': 10,
#  '16_min_da_prior': 10,
#  '18_min_da_prior': 10,
#  'PromoInterval_Oct_min_da_prior': 10,
#  'Day_min_da_prior': 10,
#  '4_min_da_prior': 10,
#  '26_min_da_prior': 10,
#  '1_min_da_prior': 10,
#  'Sales_min_da_prior': 10,
#  '15_min_da_prior': 10,
#  'PromoInterval_Aug_min_da_prior': 10,
#  '7_min_da_prior': 10,
#  'PromoInterval_Apr_min_da_prior': 10,
#  'PromoInterval_Jul_min_da_prior': 10,
#  '5_min_da_prior': 10,
#  'PromoInterval_Nov_min_da_prior': 10,
#  'WeekOfYear_min_da_prior': 10,
#  '3_min_da_prior': 10,
#  'SalesPerCustomer_min_da_prior': 10,
#  '22_min_da_prior': 10,
#  '24_min_da_prior': 10,
#  'Month_min_da_prior': 10,
#  'PromoInterval_Feb_min_da_prior': 10,
#  'Promo2SinceWeek_min_da_prior': 10,
#  '11_min_da_prior': 10,
#  '20_min_da_prior': 10,
#  '10_min_da_prior': 10,
#  'PromoInterval_Dec_min_da_prior': 10,
#  'PromoInterval_Jan_min_da_prior': 10,
#  'Promo_min_da_prior': 10,
#  'PromoInterval_Sept_min_da_prior': 10,
#  'Customers_min_da_prior': 10,
#  'CompetitionOpenSinceYear_min_da_prior': 10,
#  'Date_min_da_prior': 10,
#  '8_min_da_prior': 10,
#  '17_min_da_prior': 10,
#  '23_min_da_prior': 10,
#  'PromoInterval_May_min_da_prior': 10,
#  '19_min_da_prior': 10,
#  'DayOfWeek_min_da_prior': 10,
#  'Year_min_da_prior': 10,
#  'PromoInterval_Jun_min_da_prior': 10,
#  '14_min_da_prior': 10,
#  '25_count_da_prior': 10,
#  'CompetitionOpenSinceMonth_count_da_prior': 10,
#  'CompetitionDistance_count_da_prior': 10,
#  '9_count_da_prior': 10,
#  '12_count_da_prior': 10,
#  'SchoolHoliday_count_da_prior': 10,
#  'Promo2_count_da_prior': 10,
#  'PromoInterval_Mar_count_da_prior': 10,
#  'Promo2SinceYear_count_da_prior': 10,
#  '2_count_da_prior': 10,
#  '6_count_da_prior': 10,
#  '13_count_da_prior': 10,
#  '21_count_da_prior': 10,
#  '0_count_da_prior': 10,
#  '16_count_da_prior': 10,
#  '18_count_da_prior': 10,
#  'PromoInterval_Oct_count_da_prior': 10,
#  'Day_count_da_prior': 10,
#  '4_count_da_prior': 10,
#  '26_count_da_prior': 10,
#  '1_count_da_prior': 10,
#  'Sales_count_da_prior': 10,
#  '15_count_da_prior': 10,
#  'PromoInterval_Aug_count_da_prior': 10,
#  '7_count_da_prior': 10,
#  'PromoInterval_Apr_count_da_prior': 10,
#  'PromoInterval_Jul_count_da_prior': 10,
#  '5_count_da_prior': 10,
#  'PromoInterval_Nov_count_da_prior': 10,
#  'WeekOfYear_count_da_prior': 10,
#  '3_count_da_prior': 10,
#  'SalesPerCustomer_count_da_prior': 10,
#  '22_count_da_prior': 10,
#  '24_count_da_prior': 10,
#  'Month_count_da_prior': 10,
#  'PromoInterval_Feb_count_da_prior': 10,
#  'Promo2SinceWeek_count_da_prior': 10,
#  '11_count_da_prior': 10,
#  '20_count_da_prior': 10,
#  '10_count_da_prior': 10,
#  'PromoInterval_Dec_count_da_prior': 10,
#  'PromoInterval_Jan_count_da_prior': 10,
#  'Promo_count_da_prior': 10,
#  'PromoInterval_Sept_count_da_prior': 10,
#  'Customers_count_da_prior': 10,
#  'CompetitionOpenSinceYear_count_da_prior': 10,
#  'Date_count_da_prior': 10,
#  '8_count_da_prior': 10,
#  '17_count_da_prior': 10,
#  '23_count_da_prior': 10,
#  'PromoInterval_May_count_da_prior': 10,
#  '19_count_da_prior': 10,
#  'DayOfWeek_count_da_prior': 10,
#  'Year_count_da_prior': 10,
#  'PromoInterval_Jun_count_da_prior': 10,
#  '14_count_da_prior': 10,
#  '25_mean_da_prior': 10,
#  'CompetitionOpenSinceMonth_mean_da_prior': 10,
#  'CompetitionDistance_mean_da_prior': 10,
#  '9_mean_da_prior': 10,
#  '12_mean_da_prior': 10,
#  'SchoolHoliday_mean_da_prior': 10,
#  'Promo2_mean_da_prior': 10,
#  'PromoInterval_Mar_mean_da_prior': 10,
#  'Promo2SinceYear_mean_da_prior': 10,
#  '2_mean_da_prior': 10,
#  '6_mean_da_prior': 10,
#  '13_mean_da_prior': 10,
#  '21_mean_da_prior': 10,
#  '0_mean_da_prior': 10,
#  '16_mean_da_prior': 10,
#  '18_mean_da_prior': 10,
#  'PromoInterval_Oct_mean_da_prior': 10,
#  'Day_mean_da_prior': 10,
#  '4_mean_da_prior': 10,
#  '26_mean_da_prior': 10,
#  '1_mean_da_prior': 10,
#  'Sales_mean_da_prior': 10,
#  '15_mean_da_prior': 10,
#  'PromoInterval_Aug_mean_da_prior': 10,
#  '7_mean_da_prior': 10,
#  'PromoInterval_Apr_mean_da_prior': 10,
#  'PromoInterval_Jul_mean_da_prior': 10,
#  '5_mean_da_prior': 10,
#  'PromoInterval_Nov_mean_da_prior': 10,
#  'WeekOfYear_mean_da_prior': 10,
#  '3_mean_da_prior': 10,
#  'SalesPerCustomer_mean_da_prior': 10,
#  '22_mean_da_prior': 10,
#  '24_mean_da_prior': 10,
#  'Month_mean_da_prior': 10,
#  'PromoInterval_Feb_mean_da_prior': 10,
#  'Promo2SinceWeek_mean_da_prior': 10,
#  '11_mean_da_prior': 10,
#  '20_mean_da_prior': 10,
#  '10_mean_da_prior': 10,
#  'PromoInterval_Dec_mean_da_prior': 10,
#  'PromoInterval_Jan_mean_da_prior': 10,
#  'Promo_mean_da_prior': 10,
#  'PromoInterval_Sept_mean_da_prior': 10,
#  'Customers_mean_da_prior': 10,
#  'CompetitionOpenSinceYear_mean_da_prior': 10,
#  'Date_mean_da_prior': 10,
#  '8_mean_da_prior': 10,
#  '17_mean_da_prior': 10,
#  '23_mean_da_prior': 10,
#  'PromoInterval_May_mean_da_prior': 10,
#  '19_mean_da_prior': 10,
#  'DayOfWeek_mean_da_prior': 10,
#  'Year_mean_da_prior': 10,
#  'PromoInterval_Jun_mean_da_prior': 10,
#  '14_mean_da_prior': 10,
#  '25_max_cc_prior': 10,
#  'CompetitionOpenSinceMonth_max_cc_prior': 10,
#  'CompetitionDistance_max_cc_prior': 10,
#  '9_max_cc_prior': 10,
#  '12_max_cc_prior': 10,
#  'SchoolHoliday_max_cc_prior': 10,
#  'Promo2_max_cc_prior': 10,
#  'PromoInterval_Mar_max_cc_prior': 10,
#  'Promo2SinceYear_max_cc_prior': 10,
#  '2_max_cc_prior': 10,
#  '6_max_cc_prior': 10,
#  '13_max_cc_prior': 10,
#  '21_max_cc_prior': 10,
#  '0_max_cc_prior': 10,
#  '16_max_cc_prior': 10,
#  '18_max_cc_prior': 10,
#  'PromoInterval_Oct_max_cc_prior': 10,
#  'Day_max_cc_prior': 10,
#  '4_max_cc_prior': 10,
#  '26_max_cc_prior': 10,
#  '1_max_cc_prior': 10,
#  'Sales_max_cc_prior': 10,
#  '15_max_cc_prior': 10,
#  'PromoInterval_Aug_max_cc_prior': 10,
#  '7_max_cc_prior': 10,
#  'PromoInterval_Apr_max_cc_prior': 10,
#  'PromoInterval_Jul_max_cc_prior': 10,
#  '5_max_cc_prior': 10,
#  'PromoInterval_Nov_max_cc_prior': 10,
#  'WeekOfYear_max_cc_prior': 10,
#  '3_max_cc_prior': 10,
#  'SalesPerCustomer_max_cc_prior': 10,
#  '22_max_cc_prior': 10,
#  '24_max_cc_prior': 10,
#  'Month_max_cc_prior': 10,
#  'PromoInterval_Feb_max_cc_prior': 10,
#  'Promo2SinceWeek_max_cc_prior': 10,
#  '11_max_cc_prior': 10,
#  '20_max_cc_prior': 10,
#  '10_max_cc_prior': 10,
#  'PromoInterval_Dec_max_cc_prior': 10,
#  'PromoInterval_Jan_max_cc_prior': 10,
#  'Promo_max_cc_prior': 10,
#  'PromoInterval_Sept_max_cc_prior': 10,
#  'Customers_max_cc_prior': 10,
#  'CompetitionOpenSinceYear_max_cc_prior': 10,
#  'Date_max_cc_prior': 10,
#  '8_max_cc_prior': 10,
#  '17_max_cc_prior': 10,
#  '23_max_cc_prior': 10,
#  'PromoInterval_May_max_cc_prior': 10,
#  '19_max_cc_prior': 10,
#  'DayOfWeek_max_cc_prior': 10,
#  'Year_max_cc_prior': 10,
#  'PromoInterval_Jun_max_cc_prior': 10,
#  '14_max_cc_prior': 10,
#  '25_min_cc_prior': 10,
#  'CompetitionOpenSinceMonth_min_cc_prior': 10,
#  'CompetitionDistance_min_cc_prior': 10,
#  '9_min_cc_prior': 10,
#  '12_min_cc_prior': 10,
#  'SchoolHoliday_min_cc_prior': 10,
#  'Promo2_min_cc_prior': 10,
#  'PromoInterval_Mar_min_cc_prior': 10,
#  'Promo2SinceYear_min_cc_prior': 10,
#  '2_min_cc_prior': 10,
#  '6_min_cc_prior': 10,
#  '13_min_cc_prior': 10,
#  '21_min_cc_prior': 10,
#  '0_min_cc_prior': 10,
#  '16_min_cc_prior': 10,
#  '18_min_cc_prior': 10,
#  'PromoInterval_Oct_min_cc_prior': 10,
#  'Day_min_cc_prior': 10,
#  '4_min_cc_prior': 10,
#  '26_min_cc_prior': 10,
#  '1_min_cc_prior': 10,
#  'Sales_min_cc_prior': 10,
#  '15_min_cc_prior': 10,
#  'PromoInterval_Aug_min_cc_prior': 10,
#  '7_min_cc_prior': 10,
#  'PromoInterval_Apr_min_cc_prior': 10,
#  'PromoInterval_Jul_min_cc_prior': 10,
#  '5_min_cc_prior': 10,
#  'PromoInterval_Nov_min_cc_prior': 10,
#  'WeekOfYear_min_cc_prior': 10,
#  '3_min_cc_prior': 10,
#  'SalesPerCustomer_min_cc_prior': 10,
#  '22_min_cc_prior': 10,
#  '24_min_cc_prior': 10,
#  'Month_min_cc_prior': 10,
#  'PromoInterval_Feb_min_cc_prior': 10,
#  'Promo2SinceWeek_min_cc_prior': 10,
#  '11_min_cc_prior': 10,
#  '20_min_cc_prior': 10,
#  '10_min_cc_prior': 10,
#  'PromoInterval_Dec_min_cc_prior': 10,
#  'PromoInterval_Jan_min_cc_prior': 10,
#  'Promo_min_cc_prior': 10,
#  'PromoInterval_Sept_min_cc_prior': 10,
#  'Customers_min_cc_prior': 10,
#  'CompetitionOpenSinceYear_min_cc_prior': 10,
#  'Date_min_cc_prior': 10,
#  '8_min_cc_prior': 10,
#  '17_min_cc_prior': 10,
#  '23_min_cc_prior': 10,
#  'PromoInterval_May_min_cc_prior': 10,
#  '19_min_cc_prior': 10,
#  'DayOfWeek_min_cc_prior': 10,
#  'Year_min_cc_prior': 10,
#  'PromoInterval_Jun_min_cc_prior': 10,
#  '14_min_cc_prior': 10,
#  '25_count_cc_prior': 10,
#  'CompetitionOpenSinceMonth_count_cc_prior': 10,
#  'CompetitionDistance_count_cc_prior': 10,
#  '9_count_cc_prior': 10,
#  '12_count_cc_prior': 10,
#  'SchoolHoliday_count_cc_prior': 10,
#  'Promo2_count_cc_prior': 10,
#  'PromoInterval_Mar_count_cc_prior': 10,
#  'Promo2SinceYear_count_cc_prior': 10,
#  '2_count_cc_prior': 10,
#  '6_count_cc_prior': 10,
#  '13_count_cc_prior': 10,
#  '21_count_cc_prior': 10,
#  '0_count_cc_prior': 10,
#  '16_count_cc_prior': 10,
#  '18_count_cc_prior': 10,
#  'PromoInterval_Oct_count_cc_prior': 10,
#  'Day_count_cc_prior': 10,
#  '4_count_cc_prior': 10,
#  '26_count_cc_prior': 10,
#  '1_count_cc_prior': 10,
#  'Sales_count_cc_prior': 10,
#  '15_count_cc_prior': 10,
#  'PromoInterval_Aug_count_cc_prior': 10,
#  '7_count_cc_prior': 10,
#  'PromoInterval_Apr_count_cc_prior': 10,
#  'PromoInterval_Jul_count_cc_prior': 10,
#  '5_count_cc_prior': 10,
#  'PromoInterval_Nov_count_cc_prior': 10,
#  'WeekOfYear_count_cc_prior': 10,
#  '3_count_cc_prior': 10,
#  'SalesPerCustomer_count_cc_prior': 10,
#  '22_count_cc_prior': 10,
#  '24_count_cc_prior': 10,
#  'Month_count_cc_prior': 10,
#  'PromoInterval_Feb_count_cc_prior': 10,
#  'Promo2SinceWeek_count_cc_prior': 10,
#  '11_count_cc_prior': 10,
#  '20_count_cc_prior': 10,
#  '10_count_cc_prior': 10,
#  'PromoInterval_Dec_count_cc_prior': 10,
#  'PromoInterval_Jan_count_cc_prior': 10,
#  'Promo_count_cc_prior': 10,
#  'PromoInterval_Sept_count_cc_prior': 10,
#  'Customers_count_cc_prior': 10,
#  'CompetitionOpenSinceYear_count_cc_prior': 10,
#  'Date_count_cc_prior': 10,
#  '8_count_cc_prior': 10,
#  '17_count_cc_prior': 10,
#  '23_count_cc_prior': 10,
#  'PromoInterval_May_count_cc_prior': 10,
#  '19_count_cc_prior': 10,
#  'DayOfWeek_count_cc_prior': 10,
#  'Year_count_cc_prior': 10,
#  'PromoInterval_Jun_count_cc_prior': 10,
#  '14_count_cc_prior': 10,
#  '25_mean_cc_prior': 10,
#  'CompetitionOpenSinceMonth_mean_cc_prior': 10,
#  'CompetitionDistance_mean_cc_prior': 10,
#  '9_mean_cc_prior': 10,
#  '12_mean_cc_prior': 10,
#  'SchoolHoliday_mean_cc_prior': 10,
#  'Promo2_mean_cc_prior': 10,
#  'PromoInterval_Mar_mean_cc_prior': 10,
#  'Promo2SinceYear_mean_cc_prior': 10,
#  '2_mean_cc_prior': 10,
#  '6_mean_cc_prior': 10,
#  '13_mean_cc_prior': 10,
#  '21_mean_cc_prior': 10,
#  '0_mean_cc_prior': 10,
#  '16_mean_cc_prior': 10,
#  '18_mean_cc_prior': 10,
#  'PromoInterval_Oct_mean_cc_prior': 10,
#  'Day_mean_cc_prior': 10,
#  '4_mean_cc_prior': 10,
#  '26_mean_cc_prior': 10,
#  '1_mean_cc_prior': 10,
#  'Sales_mean_cc_prior': 10,
#  '15_mean_cc_prior': 10,
#  'PromoInterval_Aug_mean_cc_prior': 10,
#  '7_mean_cc_prior': 10,
#  'PromoInterval_Apr_mean_cc_prior': 10,
#  'PromoInterval_Jul_mean_cc_prior': 10,
#  '5_mean_cc_prior': 10,
#  'PromoInterval_Nov_mean_cc_prior': 10,
#  'WeekOfYear_mean_cc_prior': 10,
#  '3_mean_cc_prior': 10,
#  'SalesPerCustomer_mean_cc_prior': 10,
#  '22_mean_cc_prior': 10,
#  '24_mean_cc_prior': 10,
#  'Month_mean_cc_prior': 10,
#  'PromoInterval_Feb_mean_cc_prior': 10,
#  'Promo2SinceWeek_mean_cc_prior': 10,
#  '11_mean_cc_prior': 10,
#  '20_mean_cc_prior': 10,
#  '10_mean_cc_prior': 10,
#  'PromoInterval_Dec_mean_cc_prior': 10,
#  'PromoInterval_Jan_mean_cc_prior': 10,
#  'Promo_mean_cc_prior': 10,
#  'PromoInterval_Sept_mean_cc_prior': 10,
#  'Customers_mean_cc_prior': 10,
#  'CompetitionOpenSinceYear_mean_cc_prior': 10,
#  'Date_mean_cc_prior': 10,
#  '8_mean_cc_prior': 10,
#  '17_mean_cc_prior': 10,
#  '23_mean_cc_prior': 10,
#  'PromoInterval_May_mean_cc_prior': 10,
#  '19_mean_cc_prior': 10,
#  'DayOfWeek_mean_cc_prior': 10,
#  'Year_mean_cc_prior': 10,
#  'PromoInterval_Jun_mean_cc_prior': 10,
#  '14_mean_cc_prior': 10,
#  '25_max_aa_prior': 10,
#  'CompetitionOpenSinceMonth_max_aa_prior': 10,
#  'CompetitionDistance_max_aa_prior': 10,
#  '9_max_aa_prior': 10,
#  '12_max_aa_prior': 10,
#  'SchoolHoliday_max_aa_prior': 10,
#  'Promo2_max_aa_prior': 10,
#  'PromoInterval_Mar_max_aa_prior': 10,
#  'Promo2SinceYear_max_aa_prior': 10,
#  '2_max_aa_prior': 10,
#  '6_max_aa_prior': 10,
#  '13_max_aa_prior': 10,
#  '21_max_aa_prior': 10,
#  '0_max_aa_prior': 10,
#  '16_max_aa_prior': 10,
#  '18_max_aa_prior': 10,
#  'PromoInterval_Oct_max_aa_prior': 10,
#  'Day_max_aa_prior': 10,
#  '4_max_aa_prior': 10,
#  '26_max_aa_prior': 10,
#  '1_max_aa_prior': 10,
#  'Sales_max_aa_prior': 10,
#  '15_max_aa_prior': 10,
#  'PromoInterval_Aug_max_aa_prior': 10,
#  '7_max_aa_prior': 10,
#  'PromoInterval_Apr_max_aa_prior': 10,
#  'PromoInterval_Jul_max_aa_prior': 10,
#  '5_max_aa_prior': 10,
#  'PromoInterval_Nov_max_aa_prior': 10,
#  'WeekOfYear_max_aa_prior': 10,
#  '3_max_aa_prior': 10,
#  'SalesPerCustomer_max_aa_prior': 10,
#  '22_max_aa_prior': 10,
#  '24_max_aa_prior': 10,
#  'Month_max_aa_prior': 10,
#  'PromoInterval_Feb_max_aa_prior': 10,
#  'Promo2SinceWeek_max_aa_prior': 10,
#  '11_max_aa_prior': 10,
#  '20_max_aa_prior': 10,
#  '10_max_aa_prior': 10,
#  'PromoInterval_Dec_max_aa_prior': 10,
#  'PromoInterval_Jan_max_aa_prior': 10,
#  'Promo_max_aa_prior': 10,
#  'PromoInterval_Sept_max_aa_prior': 10,
#  'Customers_max_aa_prior': 10,
#  'CompetitionOpenSinceYear_max_aa_prior': 10,
#  'Date_max_aa_prior': 10,
#  '8_max_aa_prior': 10,
#  '17_max_aa_prior': 10,
#  '23_max_aa_prior': 10,
#  'PromoInterval_May_max_aa_prior': 10,
#  '19_max_aa_prior': 10,
#  'DayOfWeek_max_aa_prior': 10,
#  'Year_max_aa_prior': 10,
#  'PromoInterval_Jun_max_aa_prior': 10,
#  '14_max_aa_prior': 10,
#  '25_min_aa_prior': 10,
#  'CompetitionOpenSinceMonth_min_aa_prior': 10,
#  'CompetitionDistance_min_aa_prior': 10,
#  '9_min_aa_prior': 10,
#  '12_min_aa_prior': 10,
#  'SchoolHoliday_min_aa_prior': 10,
#  'Promo2_min_aa_prior': 10,
#  'PromoInterval_Mar_min_aa_prior': 10,
#  'Promo2SinceYear_min_aa_prior': 10,
#  '2_min_aa_prior': 10,
#  '6_min_aa_prior': 10,
#  '13_min_aa_prior': 10,
#  '21_min_aa_prior': 10,
#  '0_min_aa_prior': 10,
#  '16_min_aa_prior': 10,
#  '18_min_aa_prior': 10,
#  'PromoInterval_Oct_min_aa_prior': 10,
#  'Day_min_aa_prior': 10,
#  '4_min_aa_prior': 10,
#  '26_min_aa_prior': 10,
#  '1_min_aa_prior': 10,
#  'Sales_min_aa_prior': 10,
#  '15_min_aa_prior': 10,
#  'PromoInterval_Aug_min_aa_prior': 10,
#  '7_min_aa_prior': 10,
#  'PromoInterval_Apr_min_aa_prior': 10,
#  'PromoInterval_Jul_min_aa_prior': 10,
#  '5_min_aa_prior': 10,
#  'PromoInterval_Nov_min_aa_prior': 10,
#  'WeekOfYear_min_aa_prior': 10,
#  '3_min_aa_prior': 10,
#  'SalesPerCustomer_min_aa_prior': 10,
#  '22_min_aa_prior': 10,
#  '24_min_aa_prior': 10,
#  'Month_min_aa_prior': 10,
#  'PromoInterval_Feb_min_aa_prior': 10,
#  'Promo2SinceWeek_min_aa_prior': 10,
#  '11_min_aa_prior': 10,
#  '20_min_aa_prior': 10,
#  '10_min_aa_prior': 10,
#  'PromoInterval_Dec_min_aa_prior': 10,
#  'PromoInterval_Jan_min_aa_prior': 10,
#  'Promo_min_aa_prior': 10,
#  'PromoInterval_Sept_min_aa_prior': 10,
#  'Customers_min_aa_prior': 10,
#  'CompetitionOpenSinceYear_min_aa_prior': 10,
#  'Date_min_aa_prior': 10,
#  '8_min_aa_prior': 10,
#  '17_min_aa_prior': 10,
#  '23_min_aa_prior': 10,
#  'PromoInterval_May_min_aa_prior': 10,
#  '19_min_aa_prior': 10,
#  'DayOfWeek_min_aa_prior': 10,
#  'Year_min_aa_prior': 10,
#  'PromoInterval_Jun_min_aa_prior': 10,
#  '14_min_aa_prior': 10,
#  '25_count_aa_prior': 10,
#  'CompetitionOpenSinceMonth_count_aa_prior': 10,
#  'CompetitionDistance_count_aa_prior': 10,
#  '9_count_aa_prior': 10,
#  '12_count_aa_prior': 10,
#  'SchoolHoliday_count_aa_prior': 10,
#  'Promo2_count_aa_prior': 10,
#  'PromoInterval_Mar_count_aa_prior': 10,
#  'Promo2SinceYear_count_aa_prior': 10,
#  '2_count_aa_prior': 10,
#  '6_count_aa_prior': 10,
#  '13_count_aa_prior': 10,
#  '21_count_aa_prior': 10,
#  '0_count_aa_prior': 10,
#  '16_count_aa_prior': 10,
#  '18_count_aa_prior': 10,
#  'PromoInterval_Oct_count_aa_prior': 10,
#  'Day_count_aa_prior': 10,
#  '4_count_aa_prior': 10,
#  '26_count_aa_prior': 10,
#  '1_count_aa_prior': 10,
#  'Sales_count_aa_prior': 10,
#  '15_count_aa_prior': 10,
#  'PromoInterval_Aug_count_aa_prior': 10,
#  '7_count_aa_prior': 10,
#  'PromoInterval_Apr_count_aa_prior': 10,
#  'PromoInterval_Jul_count_aa_prior': 10,
#  '5_count_aa_prior': 10,
#  'PromoInterval_Nov_count_aa_prior': 10,
#  'WeekOfYear_count_aa_prior': 10,
#  '3_count_aa_prior': 10,
#  'SalesPerCustomer_count_aa_prior': 10,
#  '22_count_aa_prior': 10,
#  '24_count_aa_prior': 10,
#  'Month_count_aa_prior': 10,
#  'PromoInterval_Feb_count_aa_prior': 10,
#  'Promo2SinceWeek_count_aa_prior': 10,
#  '11_count_aa_prior': 10,
#  '20_count_aa_prior': 10,
#  '10_count_aa_prior': 10,
#  'PromoInterval_Dec_count_aa_prior': 10,
#  'PromoInterval_Jan_count_aa_prior': 10,
#  'Promo_count_aa_prior': 10,
#  'PromoInterval_Sept_count_aa_prior': 10,
#  'Customers_count_aa_prior': 10,
#  'CompetitionOpenSinceYear_count_aa_prior': 10,
#  'Date_count_aa_prior': 10,
#  '8_count_aa_prior': 10,
#  '17_count_aa_prior': 10,
#  '23_count_aa_prior': 10,
#  'PromoInterval_May_count_aa_prior': 10,
#  '19_count_aa_prior': 10,
#  'DayOfWeek_count_aa_prior': 10,
#  'Year_count_aa_prior': 10,
#  'PromoInterval_Jun_count_aa_prior': 10,
#  '14_count_aa_prior': 10,
#  '25_mean_aa_prior': 10,
#  'CompetitionOpenSinceMonth_mean_aa_prior': 10,
#  'CompetitionDistance_mean_aa_prior': 10,
#  '9_mean_aa_prior': 10,
#  '12_mean_aa_prior': 10,
#  'SchoolHoliday_mean_aa_prior': 10,
#  'Promo2_mean_aa_prior': 10,
#  'PromoInterval_Mar_mean_aa_prior': 10,
#  'Promo2SinceYear_mean_aa_prior': 10,
#  '2_mean_aa_prior': 10,
#  '6_mean_aa_prior': 10,
#  '13_mean_aa_prior': 10,
#  '21_mean_aa_prior': 10,
#  '0_mean_aa_prior': 10,
#  '16_mean_aa_prior': 10,
#  '18_mean_aa_prior': 10,
#  'PromoInterval_Oct_mean_aa_prior': 10,
#  'Day_mean_aa_prior': 10,
#  '4_mean_aa_prior': 10,
#  '26_mean_aa_prior': 10,
#  '1_mean_aa_prior': 10,
#  'Sales_mean_aa_prior': 10,
#  '15_mean_aa_prior': 10,
#  'PromoInterval_Aug_mean_aa_prior': 10,
#  '7_mean_aa_prior': 10,
#  'PromoInterval_Apr_mean_aa_prior': 10,
#  'PromoInterval_Jul_mean_aa_prior': 10,
#  '5_mean_aa_prior': 10,
#  'PromoInterval_Nov_mean_aa_prior': 10,
#  'WeekOfYear_mean_aa_prior': 10,
#  '3_mean_aa_prior': 10,
#  'SalesPerCustomer_mean_aa_prior': 10,
#  '22_mean_aa_prior': 10,
#  '24_mean_aa_prior': 10,
#  'Month_mean_aa_prior': 10,
#  'PromoInterval_Feb_mean_aa_prior': 10,
#  'Promo2SinceWeek_mean_aa_prior': 10,
#  '11_mean_aa_prior': 10,
#  '20_mean_aa_prior': 10,
#  '10_mean_aa_prior': 10,
#  'PromoInterval_Dec_mean_aa_prior': 10,
#  'PromoInterval_Jan_mean_aa_prior': 10,
#  'Promo_mean_aa_prior': 10,
#  'PromoInterval_Sept_mean_aa_prior': 10,
#  'Customers_mean_aa_prior': 10,
#  'CompetitionOpenSinceYear_mean_aa_prior': 10,
#  'Date_mean_aa_prior': 10,
#  '8_mean_aa_prior': 10,
#  '17_mean_aa_prior': 10,
#  '23_mean_aa_prior': 10,
#  'PromoInterval_May_mean_aa_prior': 10,
#  '19_mean_aa_prior': 10,
#  'DayOfWeek_mean_aa_prior': 10,
#  'Year_mean_aa_prior': 10,
#  'PromoInterval_Jun_mean_aa_prior': 10,
#  '14_mean_aa_prior': 10,
#  '25_max_ac_prior': 10,
#  'CompetitionOpenSinceMonth_max_ac_prior': 10,
#  'CompetitionDistance_max_ac_prior': 10,
#  '9_max_ac_prior': 10,
#  '12_max_ac_prior': 10,
#  'SchoolHoliday_max_ac_prior': 10,
#  'Promo2_max_ac_prior': 10,
#  'PromoInterval_Mar_max_ac_prior': 10,
#  'Promo2SinceYear_max_ac_prior': 10,
#  '2_max_ac_prior': 10,
#  '6_max_ac_prior': 10,
#  '13_max_ac_prior': 10,
#  '21_max_ac_prior': 10,
#  '0_max_ac_prior': 10,
#  '16_max_ac_prior': 10,
#  '18_max_ac_prior': 10,
#  'PromoInterval_Oct_max_ac_prior': 10,
#  'Day_max_ac_prior': 10,
#  '4_max_ac_prior': 10,
#  '26_max_ac_prior': 10,
#  '1_max_ac_prior': 10,
#  'Sales_max_ac_prior': 10,
#  '15_max_ac_prior': 10,
#  'PromoInterval_Aug_max_ac_prior': 10,
#  '7_max_ac_prior': 10,
#  'PromoInterval_Apr_max_ac_prior': 10,
#  'PromoInterval_Jul_max_ac_prior': 10,
#  '5_max_ac_prior': 10,
#  'PromoInterval_Nov_max_ac_prior': 10,
#  'WeekOfYear_max_ac_prior': 10,
#  '3_max_ac_prior': 10,
#  'SalesPerCustomer_max_ac_prior': 10,
#  '22_max_ac_prior': 10,
#  '24_max_ac_prior': 10,
#  'Month_max_ac_prior': 10,
#  'PromoInterval_Feb_max_ac_prior': 10,
#  'Promo2SinceWeek_max_ac_prior': 10,
#  '11_max_ac_prior': 10,
#  '20_max_ac_prior': 10,
#  '10_max_ac_prior': 10,
#  'PromoInterval_Dec_max_ac_prior': 10,
#  'PromoInterval_Jan_max_ac_prior': 10,
#  'Promo_max_ac_prior': 10,
#  'PromoInterval_Sept_max_ac_prior': 10,
#  'Customers_max_ac_prior': 10,
#  'CompetitionOpenSinceYear_max_ac_prior': 10,
#  'Date_max_ac_prior': 10,
#  '8_max_ac_prior': 10,
#  '17_max_ac_prior': 10,
#  '23_max_ac_prior': 10,
#  'PromoInterval_May_max_ac_prior': 10,
#  '19_max_ac_prior': 10,
#  'DayOfWeek_max_ac_prior': 10,
#  'Year_max_ac_prior': 10,
#  'PromoInterval_Jun_max_ac_prior': 10,
#  '14_max_ac_prior': 10,
#  '25_min_ac_prior': 10,
#  'CompetitionOpenSinceMonth_min_ac_prior': 10,
#  'CompetitionDistance_min_ac_prior': 10,
#  '9_min_ac_prior': 10,
#  '12_min_ac_prior': 10,
#  'SchoolHoliday_min_ac_prior': 10,
#  'Promo2_min_ac_prior': 10,
#  'PromoInterval_Mar_min_ac_prior': 10,
#  'Promo2SinceYear_min_ac_prior': 10,
#  '2_min_ac_prior': 10,
#  '6_min_ac_prior': 10,
#  '13_min_ac_prior': 10,
#  '21_min_ac_prior': 10,
#  '0_min_ac_prior': 10,
#  '16_min_ac_prior': 10,
#  '18_min_ac_prior': 10,
#  'PromoInterval_Oct_min_ac_prior': 10,
#  'Day_min_ac_prior': 10,
#  '4_min_ac_prior': 10,
#  '26_min_ac_prior': 10,
#  '1_min_ac_prior': 10,
#  'Sales_min_ac_prior': 10,
#  '15_min_ac_prior': 10,
#  'PromoInterval_Aug_min_ac_prior': 10,
#  '7_min_ac_prior': 10,
#  'PromoInterval_Apr_min_ac_prior': 10,
#  'PromoInterval_Jul_min_ac_prior': 10,
#  '5_min_ac_prior': 10,
#  'PromoInterval_Nov_min_ac_prior': 10,
#  'WeekOfYear_min_ac_prior': 10,
#  '3_min_ac_prior': 10,
#  'SalesPerCustomer_min_ac_prior': 10,
#  '22_min_ac_prior': 10,
#  '24_min_ac_prior': 10,
#  'Month_min_ac_prior': 10,
#  'PromoInterval_Feb_min_ac_prior': 10,
#  'Promo2SinceWeek_min_ac_prior': 10,
#  '11_min_ac_prior': 10,
#  '20_min_ac_prior': 10,
#  '10_min_ac_prior': 10,
#  'PromoInterval_Dec_min_ac_prior': 10,
#  'PromoInterval_Jan_min_ac_prior': 10,
#  'Promo_min_ac_prior': 10,
#  'PromoInterval_Sept_min_ac_prior': 10,
#  'Customers_min_ac_prior': 10,
#  'CompetitionOpenSinceYear_min_ac_prior': 10,
#  'Date_min_ac_prior': 10,
#  '8_min_ac_prior': 10,
#  '17_min_ac_prior': 10,
#  '23_min_ac_prior': 10,
#  'PromoInterval_May_min_ac_prior': 10,
#  '19_min_ac_prior': 10,
#  'DayOfWeek_min_ac_prior': 10,
#  'Year_min_ac_prior': 10,
#  'PromoInterval_Jun_min_ac_prior': 10,
#  '14_min_ac_prior': 10,
#  '25_count_ac_prior': 10,
#  'CompetitionOpenSinceMonth_count_ac_prior': 10,
#  'CompetitionDistance_count_ac_prior': 10,
#  '9_count_ac_prior': 10,
#  '12_count_ac_prior': 10,
#  'SchoolHoliday_count_ac_prior': 10,
#  'Promo2_count_ac_prior': 10,
#  'PromoInterval_Mar_count_ac_prior': 10,
#  'Promo2SinceYear_count_ac_prior': 10,
#  '2_count_ac_prior': 10,
#  '6_count_ac_prior': 10,
#  '13_count_ac_prior': 10,
#  '21_count_ac_prior': 10,
#  '0_count_ac_prior': 10,
#  '16_count_ac_prior': 10,
#  '18_count_ac_prior': 10,
#  'PromoInterval_Oct_count_ac_prior': 10,
#  'Day_count_ac_prior': 10,
#  '4_count_ac_prior': 10,
#  '26_count_ac_prior': 10,
#  '1_count_ac_prior': 10,
#  'Sales_count_ac_prior': 10,
#  '15_count_ac_prior': 10,
#  'PromoInterval_Aug_count_ac_prior': 10,
#  '7_count_ac_prior': 10,
#  'PromoInterval_Apr_count_ac_prior': 10,
#  'PromoInterval_Jul_count_ac_prior': 10,
#  '5_count_ac_prior': 10,
#  'PromoInterval_Nov_count_ac_prior': 10,
#  'WeekOfYear_count_ac_prior': 10,
#  '3_count_ac_prior': 10,
#  'SalesPerCustomer_count_ac_prior': 10,
#  '22_count_ac_prior': 10,
#  '24_count_ac_prior': 10,
#  'Month_count_ac_prior': 10,
#  'PromoInterval_Feb_count_ac_prior': 10,
#  'Promo2SinceWeek_count_ac_prior': 10,
#  '11_count_ac_prior': 10,
#  '20_count_ac_prior': 10,
#  '10_count_ac_prior': 10,
#  'PromoInterval_Dec_count_ac_prior': 10,
#  'PromoInterval_Jan_count_ac_prior': 10,
#  'Promo_count_ac_prior': 10,
#  'PromoInterval_Sept_count_ac_prior': 10,
#  'Customers_count_ac_prior': 10,
#  'CompetitionOpenSinceYear_count_ac_prior': 10,
#  'Date_count_ac_prior': 10,
#  '8_count_ac_prior': 10,
#  '17_count_ac_prior': 10,
#  '23_count_ac_prior': 10,
#  'PromoInterval_May_count_ac_prior': 10,
#  '19_count_ac_prior': 10,
#  'DayOfWeek_count_ac_prior': 10,
#  'Year_count_ac_prior': 10,
#  'PromoInterval_Jun_count_ac_prior': 10,
#  '14_count_ac_prior': 10,
#  '25_mean_ac_prior': 10,
#  'CompetitionOpenSinceMonth_mean_ac_prior': 10,
#  'CompetitionDistance_mean_ac_prior': 10,
#  '9_mean_ac_prior': 10,
#  '12_mean_ac_prior': 10,
#  'SchoolHoliday_mean_ac_prior': 10,
#  'Promo2_mean_ac_prior': 10,
#  'PromoInterval_Mar_mean_ac_prior': 10,
#  'Promo2SinceYear_mean_ac_prior': 10,
#  '2_mean_ac_prior': 10,
#  '6_mean_ac_prior': 10,
#  '13_mean_ac_prior': 10,
#  '21_mean_ac_prior': 10,
#  '0_mean_ac_prior': 10,
#  '16_mean_ac_prior': 10,
#  '18_mean_ac_prior': 10,
#  'PromoInterval_Oct_mean_ac_prior': 10,
#  'Day_mean_ac_prior': 10,
#  '4_mean_ac_prior': 10,
#  '26_mean_ac_prior': 10,
#  '1_mean_ac_prior': 10,
#  'Sales_mean_ac_prior': 10,
#  '15_mean_ac_prior': 10,
#  'PromoInterval_Aug_mean_ac_prior': 10,
#  '7_mean_ac_prior': 10,
#  'PromoInterval_Apr_mean_ac_prior': 10,
#  'PromoInterval_Jul_mean_ac_prior': 10,
#  '5_mean_ac_prior': 10,
#  'PromoInterval_Nov_mean_ac_prior': 10,
#  'WeekOfYear_mean_ac_prior': 10,
#  '3_mean_ac_prior': 10,
#  'SalesPerCustomer_mean_ac_prior': 10,
#  '22_mean_ac_prior': 10,
#  '24_mean_ac_prior': 10,
#  'Month_mean_ac_prior': 10,
#  'PromoInterval_Feb_mean_ac_prior': 10,
#  'Promo2SinceWeek_mean_ac_prior': 10,
#  '11_mean_ac_prior': 10,
#  '20_mean_ac_prior': 10,
#  '10_mean_ac_prior': 10,
#  'PromoInterval_Dec_mean_ac_prior': 10,
#  'PromoInterval_Jan_mean_ac_prior': 10,
#  'Promo_mean_ac_prior': 10,
#  'PromoInterval_Sept_mean_ac_prior': 10,
#  'Customers_mean_ac_prior': 10,
#  'CompetitionOpenSinceYear_mean_ac_prior': 10,
#  'Date_mean_ac_prior': 10,
#  '8_mean_ac_prior': 10,
#  '17_mean_ac_prior': 10,
#  '23_mean_ac_prior': 10,
#  'PromoInterval_May_mean_ac_prior': 10,
#  '19_mean_ac_prior': 10,
#  'DayOfWeek_mean_ac_prior': 10,
#  'Year_mean_ac_prior': 10,
#  'PromoInterval_Jun_mean_ac_prior': 10,
#  '14_mean_ac_prior': 10,
#  '25_max_ca_prior': 10,
#  'CompetitionOpenSinceMonth_max_ca_prior': 10,
#  'CompetitionDistance_max_ca_prior': 10,
#  '9_max_ca_prior': 10,
#  '12_max_ca_prior': 10,
#  'SchoolHoliday_max_ca_prior': 10,
#  'Promo2_max_ca_prior': 10,
#  'PromoInterval_Mar_max_ca_prior': 10,
#  'Promo2SinceYear_max_ca_prior': 10,
#  '2_max_ca_prior': 10,
#  '6_max_ca_prior': 10,
#  '13_max_ca_prior': 10,
#  '21_max_ca_prior': 10,
#  '0_max_ca_prior': 10,
#  '16_max_ca_prior': 10,
#  '18_max_ca_prior': 10,
#  'PromoInterval_Oct_max_ca_prior': 10,
#  'Day_max_ca_prior': 10,
#  '4_max_ca_prior': 10,
#  '26_max_ca_prior': 10,
#  '1_max_ca_prior': 10,
#  'Sales_max_ca_prior': 10,
#  '15_max_ca_prior': 10,
#  'PromoInterval_Aug_max_ca_prior': 10,
#  '7_max_ca_prior': 10,
#  'PromoInterval_Apr_max_ca_prior': 10,
#  'PromoInterval_Jul_max_ca_prior': 10,
#  '5_max_ca_prior': 10,
#  'PromoInterval_Nov_max_ca_prior': 10,
#  'WeekOfYear_max_ca_prior': 10,
#  '3_max_ca_prior': 10,
#  'SalesPerCustomer_max_ca_prior': 10,
#  '22_max_ca_prior': 10,
#  '24_max_ca_prior': 10,
#  'Month_max_ca_prior': 10,
#  'PromoInterval_Feb_max_ca_prior': 10,
#  'Promo2SinceWeek_max_ca_prior': 10,
#  '11_max_ca_prior': 10,
#  '20_max_ca_prior': 10,
#  '10_max_ca_prior': 10,
#  'PromoInterval_Dec_max_ca_prior': 10,
#  'PromoInterval_Jan_max_ca_prior': 10,
#  'Promo_max_ca_prior': 10,
#  'PromoInterval_Sept_max_ca_prior': 10,
#  'Customers_max_ca_prior': 10,
#  'CompetitionOpenSinceYear_max_ca_prior': 10,
#  'Date_max_ca_prior': 10,
#  '8_max_ca_prior': 10,
#  '17_max_ca_prior': 10,
#  '23_max_ca_prior': 10,
#  'PromoInterval_May_max_ca_prior': 10,
#  '19_max_ca_prior': 10,
#  'DayOfWeek_max_ca_prior': 10,
#  'Year_max_ca_prior': 10,
#  'PromoInterval_Jun_max_ca_prior': 10,
#  '14_max_ca_prior': 10,
#  '25_min_ca_prior': 10,
#  'CompetitionOpenSinceMonth_min_ca_prior': 10,
#  'CompetitionDistance_min_ca_prior': 10,
#  '9_min_ca_prior': 10,
#  '12_min_ca_prior': 10,
#  'SchoolHoliday_min_ca_prior': 10,
#  'Promo2_min_ca_prior': 10,
#  'PromoInterval_Mar_min_ca_prior': 10,
#  'Promo2SinceYear_min_ca_prior': 10,
#  '2_min_ca_prior': 10,
#  '6_min_ca_prior': 10,
#  '13_min_ca_prior': 10,
#  '21_min_ca_prior': 10,
#  '0_min_ca_prior': 10,
#  '16_min_ca_prior': 10,
#  '18_min_ca_prior': 10,
#  'PromoInterval_Oct_min_ca_prior': 10,
#  'Day_min_ca_prior': 10,
#  '4_min_ca_prior': 10,
#  '26_min_ca_prior': 10,
#  '1_min_ca_prior': 10,
#  'Sales_min_ca_prior': 10,
#  '15_min_ca_prior': 10,
#  'PromoInterval_Aug_min_ca_prior': 10,
#  '7_min_ca_prior': 10,
#  'PromoInterval_Apr_min_ca_prior': 10,
#  'PromoInterval_Jul_min_ca_prior': 10,
#  '5_min_ca_prior': 10,
#  'PromoInterval_Nov_min_ca_prior': 10,
#  'WeekOfYear_min_ca_prior': 10,
#  '3_min_ca_prior': 10,
#  'SalesPerCustomer_min_ca_prior': 10,
#  '22_min_ca_prior': 10,
#  '24_min_ca_prior': 10,
#  'Month_min_ca_prior': 10,
#  'PromoInterval_Feb_min_ca_prior': 10,
#  'Promo2SinceWeek_min_ca_prior': 10,
#  ...}

# %%
#score = object_func(set_default_dict)
# Out:
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  14%|█▍        | 1/7 [00:01<00:11,  1.85s/it]
# will create leaf model - ca
# ----------
# Fitting models:  29%|██▊       | 2/7 [00:01<00:06,  1.33s/it]
# will create leaf model - ac
# ----------seasonality yearly 365.25 1 10 added
#
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  43%|████▎     | 3/7 [00:02<00:04,  1.03s/it]
# will create leaf model - cc
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  57%|█████▋    | 4/7 [00:02<00:02,  1.32it/s]
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  71%|███████▏  | 5/7 [00:02<00:01,  1.67it/s]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  86%|████████▌ | 6/7 [00:02<00:00,  2.11it/s]
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|██████████| 7/7 [00:03<00:00,  2.31it/s]
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  14%|█▍        | 1/7 [00:08<00:48,  8.14s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  43%|████▎     | 3/7 [00:15<00:27,  6.82s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  71%|███████▏  | 5/7 [00:23<00:11,  5.89s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|██████████| 7/7 [00:26<00:00,  3.78s/it]
# forecasts first key: aa
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create leaf model - aa
# ----------
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# will create leaf model - ca
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:01<00:10,  1.77s/it]
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality yearly 365.25 1 10 added
# seasonality monthly 30.5 2 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  43%|████▎     | 3/7 [00:02<00:05,  1.30s/it]
# will create leaf model - cc
# ----------
# Fitting models:  57%|█████▋    | 4/7 [00:02<00:02,  1.05it/s]
# seasonality yearly 365.25 1 10 added
# will create leaf model - dc
# ----------
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  71%|███████▏  | 5/7 [00:02<00:01,  1.32it/s]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  86%|████████▌ | 6/7 [00:02<00:00,  1.78it/s]
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|██████████| 7/7 [00:02<00:00,  2.36it/s]
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  14%|█▍        | 1/7 [00:07<00:47,  7.88s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  43%|████▎     | 3/7 [00:14<00:26,  6.58s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  71%|███████▏  | 5/7 [00:21<00:11,  5.65s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  86%|████████▌ | 6/7 [00:22<00:04,  4.05s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|██████████| 7/7 [00:25<00:00,  3.64s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create leaf model - aa
# ----------will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
#
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  14%|█▍        | 1/7 [00:01<00:10,  1.70s/it]
# will create leaf model - ca
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  29%|██▊       | 2/7 [00:01<00:06,  1.24s/it]
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  43%|████▎     | 3/7 [00:02<00:03,  1.04it/s]
# will create leaf model - cc
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  57%|█████▋    | 4/7 [00:02<00:02,  1.37it/s]
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  71%|███████▏  | 5/7 [00:02<00:01,  1.72it/s]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  86%|████████▌ | 6/7 [00:02<00:00,  2.04it/s]
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|██████████| 7/7 [00:02<00:00,  2.34it/s]
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  14%|█▍        | 1/7 [00:07<00:45,  7.61s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  43%|████▎     | 3/7 [00:15<00:25,  6.46s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  71%|███████▏  | 5/7 [00:22<00:11,  5.64s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  86%|████████▌ | 6/7 [00:22<00:03,  3.99s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|██████████| 7/7 [00:26<00:00,  3.73s/it]
# forecasts first key: aa
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------will create leaf model - aa
# ----------
#
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# will create leaf model - ca
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:01<00:10,  1.68s/it]
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  43%|████▎     | 3/7 [00:02<00:04,  1.23s/it]
# will create leaf model - cc
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  57%|█████▋    | 4/7 [00:02<00:02,  1.06it/s]
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  71%|███████▏  | 5/7 [00:02<00:01,  1.41it/s]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  86%|████████▌ | 6/7 [00:02<00:00,  1.72it/s]
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|██████████| 7/7 [00:02<00:00,  2.36it/s]
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  14%|█▍        | 1/7 [00:07<00:43,  7.29s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [00:07<00:25,  5.16s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  43%|████▎     | 3/7 [00:14<00:23,  5.85s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  71%|███████▏  | 5/7 [00:22<00:10,  5.22s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|██████████| 7/7 [00:25<00:00,  3.69s/it]
# forecasts first key: aa
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  14%|█▍        | 1/7 [00:01<00:09,  1.66s/it]
# will create leaf model - ca
# ----------
# seasonality yearly 365.25 1 10 added
# will create leaf model - ac
# ----------
# Fitting models:  29%|██▊       | 2/7 [00:01<00:06,  1.20s/it]
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  43%|████▎     | 3/7 [00:02<00:03,  1.05it/s]
# will create leaf model - cc
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  71%|███████▏  | 5/7 [00:02<00:01,  1.38it/s]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  86%|████████▌ | 6/7 [00:02<00:00,  1.74it/s]
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|██████████| 7/7 [00:03<00:00,  2.32it/s]
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  14%|█▍        | 1/7 [00:07<00:47,  7.94s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  43%|████▎     | 3/7 [00:14<00:26,  6.59s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  57%|█████▋    | 4/7 [00:15<00:14,  4.83s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  71%|███████▏  | 5/7 [00:22<00:10,  5.35s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  86%|████████▌ | 6/7 [00:22<00:03,  3.92s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|██████████| 7/7 [00:25<00:00,  3.68s/it]
# forecasts first key: aa
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------will create leaf model - aa
# ----------
#
# seasonality yearly 365.25 1 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  14%|█▍        | 1/7 [00:01<00:10,  1.76s/it]
# will create leaf model - ca
# ----------
# will create leaf model - ac
# ----------
# Fitting models:  29%|██▊       | 2/7 [00:01<00:06,  1.27s/it]
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# will create leaf model - cc
# ----------
# Fitting models:  43%|████▎     | 3/7 [00:02<00:03,  1.04it/s]
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  57%|█████▋    | 4/7 [00:02<00:02,  1.32it/s]
# will create leaf model - dc
# ----------
# will create leaf model - da
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models: 100%|██████████| 7/7 [00:02<00:00,  2.44it/s]
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  14%|█▍        | 1/7 [00:07<00:47,  7.91s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  43%|████▎     | 3/7 [00:15<00:26,  6.69s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  57%|█████▋    | 4/7 [00:15<00:14,  4.73s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  71%|███████▏  | 5/7 [00:23<00:11,  5.61s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|██████████| 7/7 [00:27<00:00,  3.93s/it]
# forecasts first key: aa
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------will create leaf model - aa
# ----------
#
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  14%|█▍        | 1/7 [00:01<00:09,  1.65s/it]
# will create leaf model - ca
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  29%|██▊       | 2/7 [00:02<00:06,  1.27s/it]
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# will create leaf model - cc
# ----------
# Fitting models:  43%|████▎     | 3/7 [00:02<00:03,  1.06it/s]
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  57%|█████▋    | 4/7 [00:02<00:02,  1.31it/s]
# will create leaf model - dc
# ----------
# will create leaf model - da
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models: 100%|██████████| 7/7 [00:03<00:00,  2.21it/s]
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  14%|█▍        | 1/7 [00:07<00:45,  7.64s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [00:07<00:27,  5.41s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  43%|████▎     | 3/7 [00:14<00:23,  5.93s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  71%|███████▏  | 5/7 [00:22<00:10,  5.26s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  86%|████████▌ | 6/7 [00:22<00:03,  3.71s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|██████████| 7/7 [00:25<00:00,  3.69s/it]
# forecasts first key: aa
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create leaf model - aa
# ----------will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
#
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality yearly 365.25 1 10 added
# seasonality monthly 30.5 2 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  14%|█▍        | 1/7 [00:01<00:10,  1.74s/it]
# will create leaf model - ca
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# will create leaf model - ac
# ----------
# seasonality monthly 30.5 2 10 added
# Fitting models:  29%|██▊       | 2/7 [00:01<00:06,  1.27s/it]
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  43%|████▎     | 3/7 [00:02<00:04,  1.01s/it]
# will create leaf model - cc
# ----------
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  71%|███████▏  | 5/7 [00:02<00:01,  1.28it/s]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models: 100%|██████████| 7/7 [00:03<00:00,  2.17it/s]
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  14%|█▍        | 1/7 [00:07<00:44,  7.43s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  43%|████▎     | 3/7 [00:15<00:25,  6.36s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  57%|█████▋    | 4/7 [00:15<00:13,  4.48s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  71%|███████▏  | 5/7 [00:22<00:10,  5.34s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|██████████| 7/7 [00:26<00:00,  3.73s/it]
# forecasts first key: aa
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  14%|█▍        | 1/7 [00:01<00:09,  1.65s/it]
# will create leaf model - ca
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  29%|██▊       | 2/7 [00:01<00:06,  1.22s/it]
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  43%|████▎     | 3/7 [00:02<00:03,  1.10it/s]
# will create leaf model - cc
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models:  57%|█████▋    | 4/7 [00:02<00:02,  1.37it/s]
# will create leaf model - dc
# ----------
# will create leaf model - da
# ----------
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# seasonality yearly 365.25 1 10 added
# seasonality weekly 7 5 18 added
# seasonality monthly 30.5 2 10 added
# Fitting models: 100%|██████████| 7/7 [00:03<00:00,  2.31it/s]
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  14%|█▍        | 1/7 [00:07<00:47,  7.89s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  43%|████▎     | 3/7 [00:15<00:26,  6.62s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  57%|█████▋    | 4/7 [00:15<00:14,  4.70s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models:  71%|███████▏  | 5/7 [00:23<00:11,  5.57s/it]
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|██████████| 7/7 [00:26<00:00,  3.78s/it]
# forecasts first key: aa
# total_part (7, 8) preds_part (7, 8)
# time consum : 267.44685912132263

# %%
#score
#### with reg score 0.08
# Out:
# 0.08084819651717301

# %%
#score
#### without reg score 0.15

# %%
from multiprocessing import Process, Pipe
import sys
import time

import hyperopt
import numpy as np

PY2 = sys.version_info[0] == 2
int_types = (int, long) if PY2 else (int,)


def is_integer(obj):
    return isinstance(obj, int_types + (np.integer,))


def is_number(obj, check_complex=False):
    types = ((float, complex, np.number) if check_complex else
             (float, np.floating))
    return is_integer(obj) or isinstance(obj, types)

def get_vals(trial):
    """Determine hyperparameter values given a ``Trial`` object"""
    # based on hyperopt/base.py:Trials:argmin
    return dict((k, v[0]) for k, v in trial['misc']['vals'].items() if v)


def wrap_cost(cost_fn, timeout=None, iters=1, verbose=0):
    """Wrap cost function to execute trials safely on a separate process.

    Parameters
    ----------
    cost_fn : callable
        The cost function (aka. objective function) to wrap. It follows the
        same specifications as normal Hyperopt cost functions.
    timeout : int
        Time to wait for process to complete, in seconds. If this time is
        reached, the process is re-tried if there are remaining iterations,
        otherwise marked as a failure. If ``None``, wait indefinitely.
    iters : int
        Number of times to allow the trial to timeout before marking it as
        a failure due to timeout.
    verbose : int
        How verbose this function should be. 0 is not verbose, 1 is verbose.

    Example
    -------
    def objective(args):
        case, val = args
        return val**2 if case else val

    space = [hp.choice('case', [False, True]), hp.uniform('val', -1, 1)]
    safe_objective = wrap_cost(objective, timeout=2, iters=2, verbose=1)
    best = hyperopt.fmin(safe_objective, space, max_evals=100)

    Notes
    -----
    Based on code from https://github.com/hyperopt/hyperopt-sklearn
    """
    def _cost_fn(*args, **kwargs):
        _conn = kwargs.pop('_conn')
        try:
            t_start = time.time()
            rval = cost_fn(*args, **kwargs)
            t_done = time.time()

            if not isinstance(rval, dict):
                rval = dict(loss=rval)
            assert 'loss' in rval, "Returned dictionary must include loss"
            loss = rval['loss']
            assert is_number(loss), "Returned loss must be a number type"
            rval.setdefault('status', hyperopt.STATUS_OK if np.isfinite(loss)
                            else hyperopt.STATUS_FAIL)
            rval.setdefault('duration', t_done - t_start)
            rtype = 'return'

        except Exception as exc:
            rval = exc
            rtype = 'raise'

        # -- return the result to calling process
        _conn.send((rtype, rval))

    def wrapper(*args, **kwargs):
        for k in range(iters):
            conn1, conn2 = Pipe()
            kwargs['_conn'] = conn2
            th = Process(target=_cost_fn, args=args, kwargs=kwargs)
            th.start()
            if conn1.poll(timeout):
                fn_rval = conn1.recv()
                th.join()
            else:
                if verbose >= 1:
                    print("TRIAL TIMED OUT (%d/%d)" % (k+1, iters))
                th.terminate()
                th.join()
                continue

            assert fn_rval[0] in ('raise', 'return')
            if fn_rval[0] == 'raise':
                raise fn_rval[1]
            else:
                return fn_rval[1]

        return {'status': hyperopt.STATUS_FAIL,
                'failure': 'timeout'}

    return wrapper

#### try two times
safe_objective = wrap_cost(object_func, timeout=500, iters=1, verbose=1)

# %%
from hyperopt import Trials
trials = Trials()

#### with calculate
def run_trials():
    import pickle
    trials_step = 1  # how many additional trials to do after loading saved trials. 1 = save after iteration
    max_trials = 1  # initial max_trials. put something small to not have to wait
    trials_path = "trials_mean_1_peak_100_prior.pkl"
    try:  # try to load an already saved trials object, and increase the max
        #trials = pickle.load(open("my_model.hyperopt", "rb"))x
        trials = pickle.load(open(trials_path, "rb"))
        print("Found saved Trials! Loading...")
        max_trials = len(trials.trials) + trials_step
        print("Rerunning from {} trials to {} (+{}) trials".format(len(trials.trials), max_trials, trials_step))
    except:  # create a new trials object and start searching
        trials = Trials()

    #best = fmin(fn=mymodel, space=model_space, algo=tpe.suggest, max_evals=max_trials, trials=trials)
    try:
        best_without_init = fmin(safe_objective, tiny_space, algo = tpe.suggest, max_evals = max_trials,  points_to_evaluate=[set_default_dict], 
                         trials = trials)
    except:
        print("Time Out !!!!")
        return
    print("Best:", best_without_init)
    
    # save the trials object
    with open(trials_path, "wb") as f:
        pickle.dump(trials, f)
        
    print("length : {}".format(len(trials)) + "!" * 100)

# loop indefinitely and stop whenever you like
times = 0
while True:
    run_trials()
    times += 1 
    if times >= 3:
        break
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:09:45<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:07:13<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:03:45<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:47:01<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:09:47<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:12:54<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:19:54<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:16:24<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [57:59<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:11:05<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [3:09:45<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:07:13<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:03:45<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:47:01<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:09:48<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:12:54<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:19:54<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:16:25<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [57:59<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:11:05<?, ?it/s]
#                   will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:19<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   will create leaf model - aa
# ----------
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:19<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality yearly 365.25 23 5.24807460249774 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality weekly 7 12 36.30780547701034 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality monthly 30.5 25 83.17637711026768 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality yearly 365.25 23 5.24807460249774 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality weekly 7 12 36.30780547701034 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality monthly 30.5 25 83.17637711026768 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceWeek_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jul_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 5_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 20_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Apr_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Dec_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceWeek_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jul_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 5_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 20_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Apr_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Dec_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceYear_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 12_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceYear_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 21_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg WeekOfYear_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 7_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 14_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 17_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceYear_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 12_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceYear_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Month_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 15_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionDistance_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:21<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 2_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Aug_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 22_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 11_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Sept_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Sales_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 19_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Feb_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 0_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceMonth_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_May_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jun_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 21_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg WeekOfYear_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 26_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 7_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 14_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 17_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Month_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 15_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionDistance_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 2_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 24_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Aug_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 22_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 11_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 18_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Sept_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 3_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg DayOfWeek_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Sales_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 19_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Feb_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 0_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceMonth_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_May_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jun_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 26_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 24_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 18_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 3_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 4_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 6_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 10_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Oct_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 13_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jan_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 8_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg DayOfWeek_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 4_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 6_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 10_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 9_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Oct_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 16_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Date_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg SalesPerCustomer_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:22<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 13_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jan_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 8_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 9_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 16_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Date_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Nov_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg SalesPerCustomer_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Day_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 23_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Nov_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Day_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 23_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Customers_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 1_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg SchoolHoliday_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Mar_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Year_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 25_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Customers_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 1_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg SchoolHoliday_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Mar_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   fit merge shape (871, 1577) before shape (871, 2)
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Year_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 25_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   fit merge shape (871, 1577) before shape (871, 2)
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:23<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   will create leaf model - ca
# ----------
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:25<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:  14%|#4        | 1/7 [00:06<00:37,  6.33s/it]
#
#
# Fitting models:   0%|          | 0/7 [3:09:51<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:07:20<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:03:52<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:47:08<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:09:54<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:13:01<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:20:01<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:16:31<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [58:06<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:11:12<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [3:09:52<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:07:20<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:03:52<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:47:08<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:09:55<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:13:01<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:20:01<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:16:32<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [58:06<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:11:12<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:  29%|##8       | 2/7 [00:07<00:23,  4.66s/it]
#
#
# Fitting models:   0%|          | 0/7 [3:09:52<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:07:20<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:03:53<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:47:09<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:09:55<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:13:02<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:20:01<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:16:32<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [58:06<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:11:12<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [3:09:52<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:07:20<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:03:53<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:47:09<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:09:55<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:13:02<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:20:02<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:16:32<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [58:06<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:11:12<?, ?it/s]
#                   will create leaf model - ac
# ----------
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:26<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality yearly 365.25 23 5.24807460249774 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality weekly 7 12 36.30780547701034 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality yearly 365.25 23 5.24807460249774 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality weekly 7 12 36.30780547701034 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality monthly 30.5 25 83.17637711026768 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceWeek_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality monthly 30.5 25 83.17637711026768 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceWeek_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jul_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jul_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 5_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 5_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 20_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Apr_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Dec_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceYear_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 20_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Apr_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Dec_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceYear_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 12_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceYear_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 21_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg WeekOfYear_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 7_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 14_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 12_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceYear_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 21_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg WeekOfYear_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 7_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 17_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 14_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 17_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Month_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Month_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 15_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 15_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionDistance_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 2_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionDistance_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Aug_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 2_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Aug_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 22_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 22_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 11_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Sept_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 11_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Sept_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Sales_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Sales_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 19_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:27<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Feb_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 0_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceMonth_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_May_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jun_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 19_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Feb_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 0_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 26_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 24_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 18_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 3_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceMonth_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_May_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jun_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 26_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg DayOfWeek_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 4_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 6_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 10_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Oct_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 13_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jan_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 8_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 9_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 16_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Date_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg SalesPerCustomer_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Nov_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Day_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 23_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 24_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
# reg 18_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 3_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg DayOfWeek_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 4_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 6_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 10_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Oct_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 13_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jan_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 8_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 9_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 16_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Date_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg SalesPerCustomer_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Nov_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Day_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 23_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Customers_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 1_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg SchoolHoliday_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Mar_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Year_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 25_mean_ac added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Customers_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 1_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg SchoolHoliday_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Mar_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Year_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:28<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 25_mean_ca added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:29<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   fit merge shape (871, 1577) before shape (871, 2)
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:29<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   fit merge shape (871, 1577) before shape (871, 2)
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:29<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   will create leaf model - cc
# ----------
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:31<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality yearly 365.25 23 5.24807460249774 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:32<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality weekly 7 12 36.30780547701034 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:32<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality monthly 30.5 25 83.17637711026768 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:32<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceWeek_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:32<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jul_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:32<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 5_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:32<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 20_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:32<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Apr_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:32<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   will create leaf model - dc
# ----------
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:32<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:  43%|####2     | 3/7 [00:12<00:19,  4.91s/it]
#
#
# Fitting models:   0%|          | 0/7 [3:09:58<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:07:26<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:03:58<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:47:14<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:10:00<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:13:07<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:20:07<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:16:38<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [58:12<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:11:18<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [3:09:58<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:07:26<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:03:59<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:47:15<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:10:01<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:13:07<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:20:07<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:16:38<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [58:12<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:11:18<?, ?it/s]
#                   reg PromoInterval_Dec_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:32<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceYear_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:32<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:  57%|#####7    | 4/7 [00:13<00:10,  3.60s/it]
#
#
# Fitting models:   0%|          | 0/7 [3:09:58<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:07:26<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:03:59<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:47:15<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:10:01<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:13:08<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:20:07<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:16:38<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [58:12<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:11:18<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [3:09:58<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:07:27<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:03:59<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:47:15<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:10:01<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:13:08<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:20:08<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:16:38<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [58:12<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:11:18<?, ?it/s]
#                   seasonality yearly 365.25 23 5.24807460249774 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 12_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceYear_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 21_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg WeekOfYear_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 7_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 14_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 17_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Month_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 15_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionDistance_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 2_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Aug_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 22_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality weekly 7 12 36.30780547701034 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 11_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Sept_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Sales_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 19_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality monthly 30.5 25 83.17637711026768 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Feb_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceWeek_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 0_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jul_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceMonth_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_May_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 5_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 20_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jun_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Apr_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Dec_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 26_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceYear_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 24_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 18_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 3_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg DayOfWeek_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 12_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceYear_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 21_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg WeekOfYear_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 7_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 14_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 17_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
# reg Month_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 4_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 6_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 10_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Oct_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 13_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jan_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 8_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 9_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 15_mean_dc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 16_mean_cc added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:33<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|##########| 7/7 [00:30<00:00,  4.24s/it]
#
#
# Fitting models:   0%|          | 0/7 [3:16:15<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:13:44<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:10:16<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:53:32<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:16:18<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:19:25<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:26:25<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:22:55<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:04:29<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:17:36<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [3:16:16<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:13:44<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:10:16<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:53:32<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:16:18<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:19:25<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:26:25<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:22:55<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:04:30<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:17:36<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models: 100%|##########| 7/7 [00:31<00:00,  4.46s/it]
#
#
# Fitting models:   0%|          | 0/7 [3:16:16<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:13:44<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:10:16<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:53:32<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:16:18<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:19:25<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:26:25<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:22:56<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:04:30<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:17:36<?, ?it/s]
#                   forecasts first key: total
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:50<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   total_part (7, 8) preds_part (7, 8)
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:50<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:16:16<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:13:45<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:10:17<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:53:33<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:16:19<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:19:26<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:26:26<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:22:56<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:04:30<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:17:36<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [3:16:16<?, ?it/s]
#
#
# Fitting models:   0%|          | 0/7 [3:13:45<?, ?it/s]
#
#
#
# Fitting models:   0%|          | 0/7 [2:10:17<?, ?it/s]
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:53:33<?, ?it/s]
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:16:19<?, ?it/s]
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:19:26<?, ?it/s]
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:26:26<?, ?it/s]
#
#
#
#
#
#
# Fitting models:  29%|██▊       | 2/7 [1:22:56<00:55, 11.09s/it]
#
#
#
#
#
#
#
#
#
# Fitting models:   0%|          | 0/7 [1:04:30<?, ?it/s]
# Fitting models:   0%|          | 0/7 [3:17:37<?, ?it/s]
#                   will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:51<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   will create leaf model - aa
# ----------
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:51<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality yearly 365.25 23 5.24807460249774 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality weekly 7 12 36.30780547701034 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality monthly 30.5 25 83.17637711026768 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceWeek_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jul_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 5_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 20_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality yearly 365.25 23 5.24807460249774 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Apr_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality weekly 7 12 36.30780547701034 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   seasonality monthly 30.5 25 83.17637711026768 added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceWeek_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jul_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Dec_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceYear_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 12_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 5_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 20_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Apr_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Dec_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo2SinceYear_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceYear_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 21_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:52<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg WeekOfYear_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 7_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 14_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 17_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Month_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 15_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionDistance_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 2_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Aug_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 22_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 11_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Sept_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Sales_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 19_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Feb_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 0_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceMonth_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_May_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jun_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 26_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 24_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 18_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 3_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg DayOfWeek_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 4_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 6_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 12_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceYear_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 21_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg WeekOfYear_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 7_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 14_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 17_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Month_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 15_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionDistance_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 10_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Oct_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 13_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jan_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 2_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Aug_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 22_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Promo_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 8_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 9_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 11_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Sept_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Sales_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 19_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Feb_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 0_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg CompetitionOpenSinceMonth_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_May_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Jun_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 26_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 24_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 16_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg 18_mean_aa added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg Date_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg SalesPerCustomer_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]
#
#
#
#
#
#
#
#
#
#
#                   reg PromoInterval_Nov_mean_total added
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [06:53<?, ?it/s, best loss: ?]

# %%
os.path.exists("serlize_m_dict.pkl")
# Out:
# True

# %%
os.path.exists("trials_mean_1_peak_100_prior.pkl")
# Out:
# True

# %%
"Done !!!"

# %%
import pickle as pkl
if os.path.exists("serlize_m_dict_hts_bu.pkl"):
    with open("serlize_m_dict_hts_bu.pkl", "rb") as f:
        ori_serlize_m_dict = pkl.load(f)

# %%
ori_serlize_m_dict
# Out:
# {777511.5594971064: ({'changepoint_prior_scale': 0.03544445370013562,
#    'changepoint_range': 0.919881741595199,
#    'holidays_prior_scale': 22.057393646144526,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 26.302679918953956,
#    'n_changepoints': 36,
#    'seasonality_prior_scale': 7.114445399086622,
#    'weekly_fourier_order': 4,
#    'weekly_prior': 1.5848931924611147,
#    'yearly_fourier_order': 37,
#    'yearly_prior': 1.659586907437562},),
#  784725.6066324047: ({'changepoint_prior_scale': 0.035311427725431034,
#    'changepoint_range': 0.8047188542674242,
#    'holidays_prior_scale': 9.625691765752727,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 39.81071705534996,
#    'n_changepoints': 39,
#    'seasonality_prior_scale': 16.754281950627252,
#    'weekly_fourier_order': 7,
#    'weekly_prior': 16.59586907437568,
#    'yearly_fourier_order': 40,
#    'yearly_prior': 14.454397707459336},),
#  788709.6710249592: ({'changepoint_prior_scale': 0.046451031448288924,
#    'changepoint_range': 0.8582537186088166,
#    'holidays_prior_scale': 59.85641823892037,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 34.67368504525336,
#    'n_changepoints': 16,
#    'seasonality_prior_scale': 45.78754554871645,
#    'weekly_fourier_order': 34,
#    'weekly_prior': 6.309573444801951,
#    'yearly_fourier_order': 51,
#    'yearly_prior': 15.135612484362147},),
#  790919.8908430493: ({'changepoint_prior_scale': 0.03342946969256098,
#    'changepoint_range': 0.808383566328412,
#    'holidays_prior_scale': 13.111024406736496,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 57.543993733716064,
#    'n_changepoints': 44,
#    'seasonality_prior_scale': 27.688627464353484,
#    'weekly_fourier_order': 33,
#    'weekly_prior': 38.01893963205634,
#    'yearly_fourier_order': 51,
#    'yearly_prior': 1.659586907437562},),
#  791832.6074152124: ({'changepoint_prior_scale': 0.03807050068067732,
#    'changepoint_range': 0.9798639735006427,
#    'holidays_prior_scale': 25.168712672475785,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 39.81071705534996,
#    'n_changepoints': 11,
#    'seasonality_prior_scale': 9.940035824471742,
#    'weekly_fourier_order': 4,
#    'weekly_prior': 5.24807460249774,
#    'yearly_fourier_order': 51,
#    'yearly_prior': 79.43282347242871},),
#  792835.5570807415: ({'changepoint_prior_scale': 0.08807300998629945,
#    'changepoint_range': 0.7867300222205658,
#    'holidays_prior_scale': 17.78948023436567,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 3.4673685045253233,
#    'n_changepoints': 20,
#    'seasonality_prior_scale': 19.806637557063784,
#    'weekly_fourier_order': 17,
#    'weekly_prior': 4.1686938347033635,
#    'yearly_fourier_order': 48,
#    'yearly_prior': 1.8197008586099852},),
#  796922.3558554905: ({'changepoint_prior_scale': 0.0518728018107152,
#    'changepoint_range': 0.6563866926668498,
#    'holidays_prior_scale': 10.392354461091923,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 39.81071705534996,
#    'n_changepoints': 39,
#    'seasonality_prior_scale': 14.552852896148824,
#    'weekly_fourier_order': 17,
#    'weekly_prior': 16.59586907437568,
#    'yearly_fourier_order': 48,
#    'yearly_prior': 39.81071705534996},),
#  797926.1745362376: ({'changepoint_prior_scale': 0.0470242917436164,
#    'changepoint_range': 0.6657470202775582,
#    'holidays_prior_scale': 10.3553941501913,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 19.95262314968889,
#    'n_changepoints': 11,
#    'seasonality_prior_scale': 14.80681294356491,
#    'weekly_fourier_order': 9,
#    'weekly_prior': 16.59586907437568,
#    'yearly_fourier_order': 48,
#    'yearly_prior': 7.244359600749924},),
#  799972.8564394698: ({'changepoint_prior_scale': 0.02620000665998142,
#    'changepoint_range': 0.9049646736064897,
#    'holidays_prior_scale': 15.830506749503272,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 30.199517204020324,
#    'n_changepoints': 24,
#    'seasonality_prior_scale': 12.589659251256581,
#    'weekly_fourier_order': 4,
#    'weekly_prior': 1.659586907437562,
#    'yearly_fourier_order': 52,
#    'yearly_prior': 43.65158322401686},),
#  800182.9298739426: ({'changepoint_prior_scale': 0.02731506276764972,
#    'changepoint_range': 0.9046380315181108,
#    'holidays_prior_scale': 27.905530306876823,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 1.2589254117941677,
#    'n_changepoints': 24,
#    'seasonality_prior_scale': 11.917375850406248,
#    'weekly_fourier_order': 4,
#    'weekly_prior': 4.7863009232263956,
#    'yearly_fourier_order': 52,
#    'yearly_prior': 43.65158322401686},),
#  802419.9598617961: ({'changepoint_prior_scale': 0.02549777084973662,
#    'changepoint_range': 0.9064552207828858,
#    'holidays_prior_scale': 28.566725459987307,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 1.737800828749377,
#    'n_changepoints': 24,
#    'seasonality_prior_scale': 10.894324324114805,
#    'weekly_fourier_order': 4,
#    'weekly_prior': 10.000000000000037,
#    'yearly_fourier_order': 52,
#    'yearly_prior': 30.199517204020324},),
#  803911.1647246142: ({'changepoint_prior_scale': 0.026122237811733805,
#    'changepoint_range': 0.8300312424401164,
#    'holidays_prior_scale': 43.911369074835804,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 30.199517204020324,
#    'n_changepoints': 20,
#    'seasonality_prior_scale': 25.52267206534889,
#    'weekly_fourier_order': 20,
#    'weekly_prior': 19.95262314968889,
#    'yearly_fourier_order': 52,
#    'yearly_prior': 1.0471285480508996},),
#  805401.541218316: ({'changepoint_prior_scale': 0.02228194781869189,
#    'changepoint_range': 0.9075807173051117,
#    'holidays_prior_scale': 5.1618529671771505,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 1.148153621496883,
#    'n_changepoints': 24,
#    'seasonality_prior_scale': 5.700824337841907,
#    'weekly_fourier_order': 4,
#    'weekly_prior': 1.9054607179632492,
#    'yearly_fourier_order': 52,
#    'yearly_prior': 43.65158322401686},),
#  811689.6211725865: ({'changepoint_prior_scale': 0.03642330127378815,
#    'changepoint_range': 0.6463491034646159,
#    'holidays_prior_scale': 17.738412504635107,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 39.81071705534996,
#    'n_changepoints': 39,
#    'seasonality_prior_scale': 10.326168655422101,
#    'weekly_fourier_order': 17,
#    'weekly_prior': 52.48074602497759,
#    'yearly_fourier_order': 48,
#    'yearly_prior': 45.70881896148778},),
#  817034.7778470196: ({'changepoint_prior_scale': 0.051195483172291445,
#    'changepoint_range': 0.5737252565910477,
#    'holidays_prior_scale': 6.962269496390025,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 20.892961308540496,
#    'n_changepoints': 39,
#    'seasonality_prior_scale': 18.099741555511653,
#    'weekly_fourier_order': 17,
#    'weekly_prior': 16.59586907437568,
#    'yearly_fourier_order': 34,
#    'yearly_prior': 15.848931924611204},),
#  818361.912150077: ({'changepoint_prior_scale': 0.02310960905335651,
#    'changepoint_range': 0.8884895541226605,
#    'holidays_prior_scale': 5.26911268891193,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 45.70881896148778,
#    'n_changepoints': 21,
#    'seasonality_prior_scale': 9.866203671442477,
#    'weekly_fourier_order': 5,
#    'weekly_prior': 43.65158322401686,
#    'yearly_fourier_order': 45,
#    'yearly_prior': 5.24807460249774},),
#  824887.1597740845: ({'changepoint_prior_scale': 0.08645502570185126,
#    'changepoint_range': 0.7683145306938779,
#    'holidays_prior_scale': 50.94321080650556,
#    'monthly_fourier_order': 9,
#    'monthly_prior': 60.25595860743617,
#    'n_changepoints': 14,
#    'seasonality_prior_scale': 49.30605337606675,
#    'weekly_fourier_order': 15,
#    'weekly_prior': 3.4673685045253233,
#    'yearly_fourier_order': 25,
#    'yearly_prior': 31.622776601683967},),
#  833442.8719407992: ({'changepoint_prior_scale': 0.039253758823933255,
#    'changepoint_range': 0.7589242083970832,
#    'holidays_prior_scale': 49.96949971784984,
#    'monthly_fourier_order': 19,
#    'monthly_prior': 2.630267991895386,
#    'n_changepoints': 15,
#    'seasonality_prior_scale': 49.73705771196133,
#    'weekly_fourier_order': 14,
#    'weekly_prior': 41.68693834703379,
#    'yearly_fourier_order': 25,
#    'yearly_prior': 19.95262314968889},),
#  835503.0623180685: ({'changepoint_prior_scale': 0.05516650650774079,
#    'changepoint_range': 0.9904360608657866,
#    'holidays_prior_scale': 23.9658600869862,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 26.302679918953956,
#    'n_changepoints': 21,
#    'seasonality_prior_scale': 9.785863256898073,
#    'weekly_fourier_order': 4,
#    'weekly_prior': 7.9432823472428415,
#    'yearly_fourier_order': 62,
#    'yearly_prior': 5.49540873857626},),
#  838112.0779171906: ({'changepoint_prior_scale': 0.017348162635383073,
#    'changepoint_range': 0.8599245771293647,
#    'holidays_prior_scale': 13.125084176694541,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 8.709635899560837,
#    'n_changepoints': 42,
#    'seasonality_prior_scale': 30.02384687774589,
#    'weekly_fourier_order': 33,
#    'weekly_prior': 6.918309709189386,
#    'yearly_fourier_order': 56,
#    'yearly_prior': 3.6307805477010207},),
#  840364.6732912627: ({'changepoint_prior_scale': 0.0327683955000644,
#    'changepoint_range': 0.8316533697667763,
#    'holidays_prior_scale': 40.87344837648819,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 3.1622776601683853,
#    'n_changepoints': 18,
#    'seasonality_prior_scale': 11.1125672319729,
#    'weekly_fourier_order': 26,
#    'weekly_prior': 3.0199517204020214,
#    'yearly_fourier_order': 66,
#    'yearly_prior': 1.2589254117941677},),
#  840512.7037155102: ({'changepoint_prior_scale': 0.02146714967731265,
#    'changepoint_range': 0.6765546380595943,
#    'holidays_prior_scale': 16.785843062282808,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 100.00000000000074,
#    'n_changepoints': 20,
#    'seasonality_prior_scale': 10.597837264133528,
#    'weekly_fourier_order': 21,
#    'weekly_prior': 2.187761623949555,
#    'yearly_fourier_order': 44,
#    'yearly_prior': 12.589254117941723},),
#  850485.359185069: ({'changepoint_prior_scale': 0.02399694923952761,
#    'changepoint_range': 0.9308634512370795,
#    'holidays_prior_scale': 9.909255492192063,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 6.025595860743595,
#    'n_changepoints': 27,
#    'seasonality_prior_scale': 23.941599172881073,
#    'weekly_fourier_order': 24,
#    'weekly_prior': 66.06934480076004,
#    'yearly_fourier_order': 62,
#    'yearly_prior': 33.11311214825929},),
#  857024.2997195144: ({'changepoint_prior_scale': 0.030761209022887856,
#    'changepoint_range': 0.8107554230672881,
#    'holidays_prior_scale': 46.11335703458969,
#    'monthly_fourier_order': 24,
#    'monthly_prior': 9.12010839355913,
#    'n_changepoints': 15,
#    'seasonality_prior_scale': 49.0874281794059,
#    'weekly_fourier_order': 8,
#    'weekly_prior': 41.68693834703379,
#    'yearly_fourier_order': 25,
#    'yearly_prior': 54.954087385762804},),
#  867714.8500212547: ({'changepoint_prior_scale': 0.049100282467029986,
#    'changepoint_range': 0.7666703804108227,
#    'holidays_prior_scale': 5.432151603525451,
#    'monthly_fourier_order': 3,
#    'monthly_prior': 34.67368504525336,
#    'n_changepoints': 16,
#    'seasonality_prior_scale': 47.83828049094856,
#    'weekly_fourier_order': 34,
#    'weekly_prior': 9.12010839355913,
#    'yearly_fourier_order': 26,
#    'yearly_prior': 4.36515832240167},),
#  870186.9604917616: ({'changepoint_prior_scale': 0.08674601138233887,
#    'changepoint_range': 0.7731408426428598,
#    'holidays_prior_scale': 55.22960202515975,
#    'monthly_fourier_order': 21,
#    'monthly_prior': 3.1622776601683853,
#    'n_changepoints': 14,
#    'seasonality_prior_scale': 33.78472586143229,
#    'weekly_fourier_order': 9,
#    'weekly_prior': 27.54228703338181,
#    'yearly_fourier_order': 26,
#    'yearly_prior': 1.9054607179632492},),
#  874149.2276953137: ({'changepoint_prior_scale': 0.01452366366727681,
#    'changepoint_range': 0.778156571777744,
#    'holidays_prior_scale': 9.207357199914046,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 10.471285480509035,
#    'n_changepoints': 36,
#    'seasonality_prior_scale': 26.70192070883548,
#    'weekly_fourier_order': 4,
#    'weekly_prior': 36.30780547701034,
#    'yearly_fourier_order': 64,
#    'yearly_prior': 1.148153621496883},),
#  874993.7547225194: ({'changepoint_prior_scale': 0.0031928328017443858,
#    'changepoint_range': 0.9812126219772218,
#    'holidays_prior_scale': 20.21640410466422,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 43.65158322401686,
#    'n_changepoints': 19,
#    'seasonality_prior_scale': 33.609374570277716,
#    'weekly_fourier_order': 8,
#    'weekly_prior': 57.543993733716064,
#    'yearly_fourier_order': 53,
#    'yearly_prior': 33.11311214825929},),
#  879932.9569719615: ({'changepoint_prior_scale': 0.029823647226248605,
#    'changepoint_range': 0.9137252220298085,
#    'holidays_prior_scale': 42.30168824296578,
#    'monthly_fourier_order': 19,
#    'monthly_prior': 63.09573444801974,
#    'n_changepoints': 40,
#    'seasonality_prior_scale': 10.34668749908189,
#    'weekly_fourier_order': 28,
#    'weekly_prior': 28.840315031266215,
#    'yearly_fourier_order': 26,
#    'yearly_prior': 6.60693448007598},),
#  888136.6003224519: ({'changepoint_prior_scale': 0.03597102237258802,
#    'changepoint_range': 0.8299061597231331,
#    'holidays_prior_scale': 22.84216818560195,
#    'monthly_fourier_order': 7,
#    'monthly_prior': 6.309573444801951,
#    'n_changepoints': 25,
#    'seasonality_prior_scale': 6.646118287470045,
#    'weekly_fourier_order': 28,
#    'weekly_prior': 69.18309709189411,
#    'yearly_fourier_order': 24,
#    'yearly_prior': 69.18309709189411},),
#  892903.0655083326: ({'changepoint_prior_scale': 0.062328931613728183,
#    'changepoint_range': 0.9949493751703462,
#    'holidays_prior_scale': 40.855566030223244,
#    'monthly_fourier_order': 31,
#    'monthly_prior': 4.570881896148761,
#    'n_changepoints': 31,
#    'seasonality_prior_scale': 40.97013073810726,
#    'weekly_fourier_order': 24,
#    'weekly_prior': 3.0199517204020214,
#    'yearly_fourier_order': 25,
#    'yearly_prior': 15.848931924611204},),
#  892954.4735315046: ({'changepoint_prior_scale': 0.03479990170112778,
#    'changepoint_range': 0.8032036472323947,
#    'holidays_prior_scale': 47.47658896861299,
#    'monthly_fourier_order': 13,
#    'monthly_prior': 75.8577575029189,
#    'n_changepoints': 43,
#    'seasonality_prior_scale': 27.218433336819793,
#    'weekly_fourier_order': 7,
#    'weekly_prior': 2.398832919019494,
#    'yearly_fourier_order': 24,
#    'yearly_prior': 27.54228703338181},),
#  898438.6000200422: ({'changepoint_prior_scale': 0.09197931095536518,
#    'changepoint_range': 0.863785832414184,
#    'holidays_prior_scale': 57.12744710987137,
#    'monthly_fourier_order': 30,
#    'monthly_prior': 34.67368504525336,
#    'n_changepoints': 36,
#    'seasonality_prior_scale': 42.68632928729168,
#    'weekly_fourier_order': 15,
#    'weekly_prior': 6.309573444801951,
#    'yearly_fourier_order': 25,
#    'yearly_prior': 1.737800828749377},),
#  904350.6077987663: ({'changepoint_prior_scale': 0.035956254938654356,
#    'changepoint_range': 0.9235660147666106,
#    'holidays_prior_scale': 23.248983499195077,
#    'monthly_fourier_order': 20,
#    'monthly_prior': 57.543993733716064,
#    'n_changepoints': 21,
#    'seasonality_prior_scale': 27.60419653261256,
#    'weekly_fourier_order': 33,
#    'weekly_prior': 87.09635899560868,
#    'yearly_fourier_order': 28,
#    'yearly_prior': 2.2908676527677763},),
#  905342.0592195559: ({'changepoint_prior_scale': 0.03390822851205384,
#    'changepoint_range': 0.9315118659561309,
#    'holidays_prior_scale': 19.86552228856132,
#    'monthly_fourier_order': 9,
#    'monthly_prior': 8.709635899560837,
#    'n_changepoints': 13,
#    'seasonality_prior_scale': 6.064880970387158,
#    'weekly_fourier_order': 20,
#    'weekly_prior': 6.025595860743595,
#    'yearly_fourier_order': 28,
#    'yearly_prior': 2.884031503126611},),
#  906877.9774879825: ({'changepoint_prior_scale': 0.03285280275362255,
#    'changepoint_range': 0.8057592826919229,
#    'holidays_prior_scale': 45.881729076916805,
#    'monthly_fourier_order': 12,
#    'monthly_prior': 14.454397707459336,
#    'n_changepoints': 15,
#    'seasonality_prior_scale': 49.95460876368223,
#    'weekly_fourier_order': 5,
#    'weekly_prior': 3.1622776601683853,
#    'yearly_fourier_order': 28,
#    'yearly_prior': 54.954087385762804},),
#  910368.5213048158: ({'changepoint_prior_scale': 0.03779108168389786,
#    'changepoint_range': 0.8479816436106927,
#    'holidays_prior_scale': 31.045024183121523,
#    'monthly_fourier_order': 28,
#    'monthly_prior': 23.988329190195024,
#    'n_changepoints': 19,
#    'seasonality_prior_scale': 35.61019947755983,
#    'weekly_fourier_order': 28,
#    'weekly_prior': 3.4673685045253233,
#    'yearly_fourier_order': 33,
#    'yearly_prior': 6.918309709189386},),
#  913522.6764469852: ({'changepoint_prior_scale': 0.011105843225906582,
#    'changepoint_range': 0.934690784728863,
#    'holidays_prior_scale': 44.08049280455993,
#    'monthly_fourier_order': 1,
#    'monthly_prior': 47.863009232264126,
#    'n_changepoints': 20,
#    'seasonality_prior_scale': 20.859094847983634,
#    'weekly_fourier_order': 20,
#    'weekly_prior': 1.0471285480508996,
#    'yearly_fourier_order': 62,
#    'yearly_prior': 11.481536214968871},),
#  916291.2768572737: ({'changepoint_prior_scale': 0.002677391848896602,
#    'changepoint_range': 0.5173889148416342,
#    'holidays_prior_scale': 55.04797307362793,
#    'monthly_fourier_order': 12,
#    'monthly_prior': 14.454397707459336,
#    'n_changepoints': 29,
#    'seasonality_prior_scale': 44.11308581413863,
#    'weekly_fourier_order': 26,
#    'weekly_prior': 16.59586907437568,
#    'yearly_fourier_order': 28,
#    'yearly_prior': 1.3803842646028854},),
#  921116.8559612161: ({'changepoint_prior_scale': 0.06070862494499875,
#    'changepoint_range': 0.8585754258429235,
#    'holidays_prior_scale': 54.0373919447084,
#    'monthly_fourier_order': 10,
#    'monthly_prior': 3.981071705534981,
#    'n_changepoints': 7,
#    'seasonality_prior_scale': 45.79106129921948,
#    'weekly_fourier_order': 34,
#    'weekly_prior': 3.80189396320562,
#    'yearly_fourier_order': 29,
#    'yearly_prior': 1.659586907437562},),
#  922370.0481549911: ({'changepoint_prior_scale': 0.0643953514524034,
#    'changepoint_range': 0.9218019829691171,
#    'holidays_prior_scale': 59.72644932646986,
#    'monthly_fourier_order': 16,
#    'monthly_prior': 20.892961308540496,
#    'n_changepoints': 32,
#    'seasonality_prior_scale': 31.58942924519672,
#    'weekly_fourier_order': 19,
#    'weekly_prior': 52.48074602497759,
#    'yearly_fourier_order': 29,
#    'yearly_prior': 2.7542287033381707},),
#  925726.012529877: ({'changepoint_prior_scale': 0.07088899819866382,
#    'changepoint_range': 0.846115870092379,
#    'holidays_prior_scale': 24.114975668818108,
#    'monthly_fourier_order': 5,
#    'monthly_prior': 39.81071705534996,
#    'n_changepoints': 12,
#    'seasonality_prior_scale': 6.6387299352925915,
#    'weekly_fourier_order': 31,
#    'weekly_prior': 2.7542287033381707,
#    'yearly_fourier_order': 32,
#    'yearly_prior': 15.135612484362147},),
#  928436.7091892143: ({'changepoint_prior_scale': 0.0015734084191744366,
#    'changepoint_range': 0.9388512324003596,
#    'holidays_prior_scale': 31.710483288475558,
#    'monthly_fourier_order': 25,
#    'monthly_prior': 14.454397707459336,
#    'n_changepoints': 22,
#    'seasonality_prior_scale': 37.63631803527106,
#    'weekly_fourier_order': 4,
#    'weekly_prior': 3.3113112148259174,
#    'yearly_fourier_order': 31,
#    'yearly_prior': 4.570881896148761},),
#  928529.9945052261: ({'changepoint_prior_scale': 0.09563954425516938,
#    'changepoint_range': 0.759445122675298,
#    'holidays_prior_scale': 55.568115899441935,
#    'monthly_fourier_order': 3,
#    'monthly_prior': 1.5848931924611147,
#    'n_changepoints': 44,
#    'seasonality_prior_scale': 46.29414494928784,
#    'weekly_fourier_order': 23,
#    'weekly_prior': 3.3113112148259174,
#    'yearly_fourier_order': 30,
#    'yearly_prior': 31.622776601683967},),
#  928781.2054589803: ({'changepoint_prior_scale': 0.026475228587589453,
#    'changepoint_range': 0.9871358235005777,
#    'holidays_prior_scale': 6.196358623930232,
#    'monthly_fourier_order': 20,
#    'monthly_prior': 21.877616239495634,
#    'n_changepoints': 23,
#    'seasonality_prior_scale': 17.93696348658719,
#    'weekly_fourier_order': 34,
#    'weekly_prior': 5.49540873857626,
#    'yearly_fourier_order': 33,
#    'yearly_prior': 38.01893963205634},),
#  930403.8181175882: ({'changepoint_prior_scale': 0.07344410438850328,
#    'changepoint_range': 0.8960226149417504,
#    'holidays_prior_scale': 25.13935407557425,
#    'monthly_fourier_order': 21,
#    'monthly_prior': 13.803842646028906,
#    'n_changepoints': 35,
#    'seasonality_prior_scale': 28.93808559392055,
#    'weekly_fourier_order': 23,
#    'weekly_prior': 2.5118864315095837,
#    'yearly_fourier_order': 30,
#    'yearly_prior': 10.964781961431893},),
#  932508.5754062585: ({'changepoint_prior_scale': 0.04809977915709506,
#    'changepoint_range': 0.7338528036099854,
#    'holidays_prior_scale': 50.060467272527475,
#    'monthly_fourier_order': 6,
#    'monthly_prior': 5.24807460249774,
#    'n_changepoints': 13,
#    'seasonality_prior_scale': 35.71391205987726,
#    'weekly_fourier_order': 17,
#    'weekly_prior': 100.00000000000074,
#    'yearly_fourier_order': 33,
#    'yearly_prior': 16.59586907437568},),
#  932879.7024920979: ({'changepoint_prior_scale': 0.046471181641761936,
#    'changepoint_range': 0.8247967756369885,
#    'holidays_prior_scale': 53.76324784521032,
#    'monthly_fourier_order': 12,
#    'monthly_prior': 18.19700858609992,
#    'n_changepoints': 16,
#    'seasonality_prior_scale': 45.055119423402445,
#    'weekly_fourier_order': 34,
#    'weekly_prior': 3.981071705534981,
#    'yearly_fourier_order': 30,
#    'yearly_prior': 22.908676527677844},),
#  932939.7848986071: ({'changepoint_prior_scale': 0.010630128916105114,
#    'changepoint_range': 0.8464110868067551,
#    'holidays_prior_scale': 47.343487600300655,
#    'monthly_fourier_order': 19,
#    'monthly_prior': 9.12010839355913,
#    'n_changepoints': 33,
#    'seasonality_prior_scale': 34.24022897194052,
#    'weekly_fourier_order': 8,
#    'weekly_prior': 41.68693834703379,
#    'yearly_fourier_order': 25,
#    'yearly_prior': 27.54228703338181},),
#  936507.7144179179: ({'changepoint_prior_scale': 0.03993337958292351,
#    'changepoint_range': 0.7310116562642452,
#    'holidays_prior_scale': 45.627685845040475,
#    'monthly_fourier_order': 18,
#    'monthly_prior': 1.2589254117941677,
#    'n_changepoints': 35,
#    'seasonality_prior_scale': 31.090231436934477,
#    'weekly_fourier_order': 5,
#    'weekly_prior': 57.543993733716064,
#    'yearly_fourier_order': 31,
#    'yearly_prior': 13.182567385564125},),
#  937067.0284114685: ({'changepoint_prior_scale': 0.027649138789121782,
#    'changepoint_range': 0.9580024330398665,
#    'holidays_prior_scale': 19.216586960794093,
#    'monthly_fourier_order': 14,
#    'monthly_prior': 5.24807460249774,
#    'n_changepoints': 8,
#    'seasonality_prior_scale': 21.16090287603202,
#    'weekly_fourier_order': 9,
#    'weekly_prior': 34.67368504525336,
#    'yearly_fourier_order': 35,
#    'yearly_prior': 20.892961308540496},),
#  937828.8478365429: ({'changepoint_prior_scale': 0.04478570536213614,
#    'changepoint_range': 0.776114103815074,
#    'holidays_prior_scale': 44.96320793902683,
#    'monthly_fourier_order': 7,
#    'monthly_prior': 5.7543993733715855,
#    'n_changepoints': 26,
#    'seasonality_prior_scale': 18.73135497968905,
#    'weekly_fourier_order': 2,
#    'weekly_prior': 60.25595860743617,
#    'yearly_fourier_order': 36,
#    'yearly_prior': 79.43282347242871},),
#  939445.8923874764: ({'changepoint_prior_scale': 0.03978695337952786,
#    'changepoint_range': 0.9541275184518768,
#    'holidays_prior_scale': 37.778948425379276,
#    'monthly_fourier_order': 26,
#    'monthly_prior': 12.022644346174177,
#    'n_changepoints': 16,
#    'seasonality_prior_scale': 42.70755718664071,
#    'weekly_fourier_order': 13,
#    'weekly_prior': 50.11872336272754,
#    'yearly_fourier_order': 35,
#    'yearly_prior': 8.317637711026737},),
#  940505.4680859183: ({'changepoint_prior_scale': 0.04101052530625246,
#    'changepoint_range': 0.8416275329905375,
#    'holidays_prior_scale': 59.93892409889849,
#    'monthly_fourier_order': 16,
#    'monthly_prior': 2.630267991895386,
#    'n_changepoints': 41,
#    'seasonality_prior_scale': 41.780334373925186,
#    'weekly_fourier_order': 16,
#    'weekly_prior': 2.7542287033381707,
#    'yearly_fourier_order': 35,
#    'yearly_prior': 9.12010839355913},),
#  942274.0165590652: ({'changepoint_prior_scale': 0.0646551822735846,
#    'changepoint_range': 0.6240469832896693,
#    'holidays_prior_scale': 35.60196961479839,
#    'monthly_fourier_order': 27,
#    'monthly_prior': 2.187761623949555,
#    'n_changepoints': 24,
#    'seasonality_prior_scale': 8.057385219861606,
#    'weekly_fourier_order': 30,
#    'weekly_prior': 4.570881896148761,
#    'yearly_fourier_order': 29,
#    'yearly_prior': 60.25595860743617},),
#  948498.3804073458: ({'changepoint_prior_scale': 0.01646516635082753,
#    'changepoint_range': 0.865627358903656,
#    'holidays_prior_scale': 14.21200133536353,
#    'monthly_fourier_order': 18,
#    'monthly_prior': 52.48074602497759,
#    'n_changepoints': 29,
#    'seasonality_prior_scale': 10.99275433315395,
#    'weekly_fourier_order': 17,
#    'weekly_prior': 1.3803842646028854,
#    'yearly_fourier_order': 31,
#    'yearly_prior': 5.011872336272735},),
#  950823.9833536767: ({'changepoint_prior_scale': 0.051725013289140864,
#    'changepoint_range': 0.9574133033371458,
#    'holidays_prior_scale': 31.562303335353757,
#    'monthly_fourier_order': 28,
#    'monthly_prior': 57.543993733716064,
#    'n_changepoints': 23,
#    'seasonality_prior_scale': 5.0451986201573185,
#    'weekly_fourier_order': 33,
#    'weekly_prior': 47.863009232264126,
#    'yearly_fourier_order': 40,
#    'yearly_prior': 52.48074602497759},),
#  953202.8836019025: ({'changepoint_prior_scale': 0.0448409451073014,
#    'changepoint_range': 0.9795411153198884,
#    'holidays_prior_scale': 17.29599952261992,
#    'monthly_fourier_order': 3,
#    'monthly_prior': 11.481536214968871,
#    'n_changepoints': 10,
#    'seasonality_prior_scale': 21.855804916157336,
#    'weekly_fourier_order': 10,
#    'weekly_prior': 1.659586907437562,
#    'yearly_fourier_order': 36,
#    'yearly_prior': 79.43282347242871},),
#  953710.7019115982: ({'changepoint_prior_scale': 0.03231513758949455,
#    'changepoint_range': 0.9470122051716608,
#    'holidays_prior_scale': 17.95041755885073,
#    'monthly_fourier_order': 32,
#    'monthly_prior': 3.3113112148259174,
#    'n_changepoints': 9,
#    'seasonality_prior_scale': 16.5850784754512,
#    'weekly_fourier_order': 12,
#    'weekly_prior': 91.20108393559163,
#    'yearly_fourier_order': 34,
#    'yearly_prior': 6.309573444801951},),
#  957187.3898136144: ({'changepoint_prior_scale': 0.0475624569286371,
#    'changepoint_range': 0.7581237471574573,
#    'holidays_prior_scale': 28.676174027491328,
#    'monthly_fourier_order': 7,
#    'monthly_prior': 17.378008287493834,
#    'n_changepoints': 25,
#    'seasonality_prior_scale': 16.429463077099083,
#    'weekly_fourier_order': 15,
#    'weekly_prior': 83.17637711026768,
#    'yearly_fourier_order': 37,
#    'yearly_prior': 75.8577575029189},),
#  957241.5831760243: ({'changepoint_prior_scale': 0.03019659739276136,
#    'changepoint_range': 0.5897571445574088,
#    'holidays_prior_scale': 6.253563180172441,
#    'monthly_fourier_order': 4,
#    'monthly_prior': 9.12010839355913,
#    'n_changepoints': 34,
#    'seasonality_prior_scale': 6.620952492361019,
#    'weekly_fourier_order': 30,
#    'weekly_prior': 20.892961308540496,
#    'yearly_fourier_order': 32,
#    'yearly_prior': 41.68693834703379},),
#  963211.8868843107: ({'changepoint_prior_scale': 0.047988336106694444,
#    'changepoint_range': 0.785034096966436,
#    'holidays_prior_scale': 18.945089262232525,
#    'monthly_fourier_order': 2,
#    'monthly_prior': 2.884031503126611,
#    'n_changepoints': 36,
#    'seasonality_prior_scale': 43.33387908550552,
#    'weekly_fourier_order': 29,
#    'weekly_prior': 2.884031503126611,
#    'yearly_fourier_order': 50,
#    'yearly_prior': 8.709635899560837},),
#  966101.6566411145: ({'changepoint_prior_scale': 0.06472159964241951,
#    'changepoint_range': 0.8334277220133427,
#    'holidays_prior_scale': 15.88328007552919,
#    'monthly_fourier_order': 29,
#    'monthly_prior': 28.840315031266215,
#    'n_changepoints': 13,
#    'seasonality_prior_scale': 27.806028421276572,
#    'weekly_fourier_order': 12,
#    'weekly_prior': 5.49540873857626,
#    'yearly_fourier_order': 37,
#    'yearly_prior': 6.309573444801951},),
#  967528.419149634: ({'changepoint_prior_scale': 0.029137631833037414,
#    'changepoint_range': 0.6375056211358929,
#    'holidays_prior_scale': 33.272051381528385,
#    'monthly_fourier_order': 28,
#    'monthly_prior': 1.9054607179632492,
#    'n_changepoints': 7,
#    'seasonality_prior_scale': 7.555037860024566,
#    'weekly_fourier_order': 3,
#    'weekly_prior': 11.481536214968871,
#    'yearly_fourier_order': 37,
#    'yearly_prior': 2.630267991895386},),
#  970563.4811940773: ({'changepoint_prior_scale': 0.06159758384950199,
#    'changepoint_range': 0.6944163408394814,
#    'holidays_prior_scale': 12.358558975653661,
#    'monthly_fourier_order': 6,
#    'monthly_prior': 95.4992586021443,
#    'n_changepoints': 19,
#    'seasonality_prior_scale': 19.086749190373464,
#    'weekly_fourier_order': 7,
#    'weekly_prior': 1.5848931924611147,
#    'yearly_fourier_order': 40,
#    'yearly_prior': 1.3182567385564077},),
#  970809.3258592827: ({'changepoint_prior_scale': 0.059103229424462514,
#    'changepoint_range': 0.9886937131055163,
#    'holidays_prior_scale': 20.51258018600961,
#    'monthly_fourier_order': 10,
#    'monthly_prior': 25.11886431509593,
#    'n_changepoints': 36,
#    'seasonality_prior_scale': 8.407924769048664,
#    'weekly_fourier_order': 4,
#    'weekly_prior': 79.43282347242871,
#    'yearly_fourier_order': 37,
#    'yearly_prior': 5.7543993733715855},),
#  972181.5653134007: ({'changepoint_prior_scale': 0.028211934066105795,
#    'changepoint_range': 0.7128831434414021,
#    'holidays_prior_scale': 12.327939222881819,
#    'monthly_fourier_order': 11,
#    'monthly_prior': 15.135612484362147,
#    'n_changepoints': 15,
#    'seasonality_prior_scale': 12.797372392364867,
#    'weekly_fourier_order': 31,
#    'weekly_prior': 19.95262314968889,
#    'yearly_fourier_order': 40,
#    'yearly_prior': 11.481536214968871},),
#  972496.5396899597: ({'changepoint_prior_scale': 0.03589651903937932,
#    'changepoint_range': 0.9791929996145904,
#    'holidays_prior_scale': 10.236488620151997,
#    'monthly_fourier_order': 25,
#    'monthly_prior': 27.54228703338181,
#    'n_changepoints': 40,
#    'seasonality_prior_scale': 7.1129005151400735,
#    'weekly_fourier_order': 11,
#    'weekly_prior': 38.01893963205634,
#    'yearly_fourier_order': 37,
#    'yearly_prior': 10.471285480509035},),
#  976517.1801911936: ({'changepoint_prior_scale': 0.05351099049810838,
#    'changepoint_range': 0.8165339683519991,
#    'holidays_prior_scale': 11.272031697456594,
#    'monthly_fourier_order': 14,
#    'monthly_prior': 43.65158322401686,
#    'n_changepoints': 44,
#    'seasonality_prior_scale': 31.404020994812,
#    'weekly_fourier_order': 13,
#    'weekly_prior': 5.011872336272735,
#    'yearly_fourier_order': 39,
#    'yearly_prior': 2.5118864315095837},),
#  977485.7155464614: ({'changepoint_prior_scale': 0.037195236804883944,
#    'changepoint_range': 0.9730023691786602,
#    'holidays_prior_scale': 11.565406021201488,
#    'monthly_fourier_order': 4,
#    'monthly_prior': 41.68693834703379,
#    'n_changepoints': 6,
#    'seasonality_prior_scale': 17.491564121175003,
#    'weekly_fourier_order': 4,
#    'weekly_prior': 100.00000000000074,
#    'yearly_fourier_order': 42,
#    'yearly_prior': 16.59586907437568},),
#  977800.2034558002: ({'changepoint_prior_scale': 0.09581974211059263,
#    'changepoint_range': 0.7702859003873307,
#    'holidays_prior_scale': 18.353641691782695,
#    'monthly_fourier_order': 33,
#    'monthly_prior': 3.4673685045253233,
#    'n_changepoints': 20,
#    'seasonality_prior_scale': 26.34531956988519,
#    'weekly_fourier_order': 8,
#    'weekly_prior': 54.954087385762804,
#    'yearly_fourier_order': 37,
#    'yearly_prior': 83.17637711026768},),
#  979501.6320213912: ({'changepoint_prior_scale': 0.018048856422895457,
#    'changepoint_range': 0.7010911609145373,
#    'holidays_prior_scale': 29.96787161692835,
#    'monthly_fourier_order': 17,
#    'monthly_prior': 4.36515832240167,
#    'n_changepoints': 39,
#    'seasonality_prior_scale': 21.156921322466264,
#    'weekly_fourier_order': 14,
#    'weekly_prior': 3.1622776601683853,
#    'yearly_fourier_order': 38,
#    'yearly_prior': 14.454397707459336},),
#  980838.4387983715: ({'changepoint_prior_scale': 0.002591732637377358,
#    'changepoint_range': 0.5739879759227121,
#    'holidays_prior_scale': 37.34606416832595,
#    'monthly_fourier_order': 7,
#    'monthly_prior': 1.513561248436209,
#    'n_changepoints': 34,
#    'seasonality_prior_scale': 44.855555838634075,
#    'weekly_fourier_order': 28,
#    'weekly_prior': 3.6307805477010207,
#    'yearly_fourier_order': 39,
#    'yearly_prior': 14.454397707459336},),
#  985504.5129751568: ({'changepoint_prior_scale': 0.08363581005647192,
#    'changepoint_range': 0.7702031691908602,
#    'holidays_prior_scale': 49.69251146995886,
#    'monthly_fourier_order': 14,
#    'monthly_prior': 2.398832919019494,
#    'n_changepoints': 39,
#    'seasonality_prior_scale': 49.48162790928542,
#    'weekly_fourier_order': 25,
#    'weekly_prior': 19.054607179632562,
#    'yearly_fourier_order': 42,
#    'yearly_prior': 4.7863009232263956},),
#  985777.762035777: ({'changepoint_prior_scale': 0.06943694713603787,
#    'changepoint_range': 0.7333218090532932,
#    'holidays_prior_scale': 13.432334493943785,
#    'monthly_fourier_order': 34,
#    'monthly_prior': 39.81071705534996,
#    'n_changepoints': 39,
#    'seasonality_prior_scale': 16.89774232235249,
#    'weekly_fourier_order': 7,
#    'weekly_prior': 3.6307805477010207,
#    'yearly_fourier_order': 40,
#    'yearly_prior': 3.3113112148259174},),
#  986815.4764269334: ({'changepoint_prior_scale': 0.07779166965657372,
#    'changepoint_range': 0.876629230670801,
#    'holidays_prior_scale': 32.00192553226042,
#    'monthly_fourier_order': 11,
#    'monthly_prior': 19.95262314968889,
#    'n_changepoints': 7,
#    'seasonality_prior_scale': 23.418212505556706,
#    'weekly_fourier_order': 12,
#    'weekly_prior': 20.892961308540496,
#    'yearly_fourier_order': 41,
#    'yearly_prior': 23.988329190195024},),
#  988489.1173058964: ({'changepoint_prior_scale': 0.0821439791193366,
#    'changepoint_range': 0.8521463673892643,
#    'holidays_prior_scale': 22.647138237170438,
#    'monthly_fourier_order': 26,
#    'monthly_prior': 3.6307805477010207,
#    'n_changepoints': 15,
#    'seasonality_prior_scale': 12.922598408073998,
#    'weekly_fourier_order': 25,
#    'weekly_prior': 1.148153621496883,
#    'yearly_fourier_order': 39,
#    'yearly_prior': 72.4435960074995},),
#  988789.7991260965: ({'changepoint_prior_scale': 0.03823126692633335,
#    'changepoint_range': 0.9159786586834414,
#    'holidays_prior_scale': 44.59001367737847,
#    'monthly_fourier_order': 11,
#    'monthly_prior': 5.011872336272735,
#    'n_changepoints': 29,
#    'seasonality_prior_scale': 35.47070527617738,
#    'weekly_fourier_order': 32,
#    'weekly_prior': 43.65158322401686,
#    'yearly_fourier_order': 44,
#    'yearly_prior': 10.964781961431893},),
#  989156.2581231943: ({'changepoint_prior_scale': 0.05338119072543278,
#    'changepoint_range': 0.7940843299249112,
#    'holidays_prior_scale': 16.02920777388774,
#    'monthly_fourier_order': 13,
#    'monthly_prior': 50.11872336272754,
#    'n_changepoints': 7,
#    'seasonality_prior_scale': 21.959073833433376,
#    'weekly_fourier_order': 33,
#    'weekly_prior': 2.089296130854042,
#    'yearly_fourier_order': 43,
#    'yearly_prior': 79.43282347242871},),
#  989161.9531963865: ({'changepoint_prior_scale': 0.04565424267231292,
#    'changepoint_range': 0.8702046040229419,
#    'holidays_prior_scale': 12.81847073341741,
#    'monthly_fourier_order': 29,
#    'monthly_prior': 36.30780547701034,
#    'n_changepoints': 38,
#    'seasonality_prior_scale': 13.124307451652786,
#    'weekly_fourier_order': 29,
#    'weekly_prior': 66.06934480076004,
#    'yearly_fourier_order': 47,
#    'yearly_prior': 7.585775750291862},),
#  989756.9563614976: ({'changepoint_prior_scale': 0.054466111728971325,
#    'changepoint_range': 0.8478507455520029,
#    'holidays_prior_scale': 56.488527931326495,
#    'monthly_fourier_order': 15,
#    'monthly_prior': 6.918309709189386,
#    'n_changepoints': 12,
#    'seasonality_prior_scale': 39.48528009129039,
#    'weekly_fourier_order': 32,
#    'weekly_prior': 72.4435960074995,
#    'yearly_fourier_order': 44,
#    'yearly_prior': 2.630267991895386},),
#  991882.0737084233: ({'changepoint_prior_scale': 0.042029835639416716,
#    'changepoint_range': 0.9260371849646903,
#    'holidays_prior_scale': 14.272863560424689,
#    'monthly_fourier_order': 24,
#    'monthly_prior': 1.0471285480508996,
#    'n_changepoints': 28,
#    'seasonality_prior_scale': 5.002937622445711,
#    'weekly_fourier_order': 24,
#    'weekly_prior': 1.4454397707459283,
#    'yearly_fourier_order': 41,
#    'yearly_prior': 1.4454397707459283},),
#  992635.8266848268: ({'changepoint_prior_scale': 0.049787705534639085,
#    'changepoint_range': 0.9485427757814752,
#    'holidays_prior_scale': 26.011400165424035,
#    'monthly_fourier_order': 8,
#    'monthly_prior': 69.18309709189411,
#    'n_changepoints': 11,
#    'seasonality_prior_scale': 7.036839747607596,
#    'weekly_fourier_order': 23,
#    'weekly_prior': 45.70881896148778,
#    'yearly_fourier_order': 51,
#    'yearly_prior': 66.06934480076004},),
#  993055.2234597376: ({'changepoint_prior_scale': 0.031068372145811103,
#    'changepoint_range': 0.8273719052135148,
#    'holidays_prior_scale': 12.337643014968016,
#    'monthly_fourier_order': 4,
#    'monthly_prior': 36.30780547701034,
#    'n_changepoints': 16,
#    'seasonality_prior_scale': 40.87556531676011,
#    'weekly_fourier_order': 19,
#    'weekly_prior': 15.135612484362147,
#    'yearly_fourier_order': 27,
#    'yearly_prior': 3.981071705534981},),
#  993337.6333223057: ({'changepoint_prior_scale': 0.059337275340823045,
#    'changepoint_range': 0.8771670557452584,
#    'holidays_prior_scale': 58.52174072856622,
#    'monthly_fourier_order': 8,
#    'monthly_prior': 75.8577575029189,
#    'n_changepoints': 23,
#    'seasonality_prior_scale': 7.976647133846087,
#    'weekly_fourier_order': 7,
#    'weekly_prior': 7.9432823472428415,
#    'yearly_fourier_order': 46,
#    'yearly_prior': 50.11872336272754},),
#  993482.4954755969: ({'changepoint_prior_scale': 0.07979931283462594,
#    'changepoint_range': 0.9408552950995491,
#    'holidays_prior_scale': 29.928320878112228,
#    'monthly_fourier_order': 5,
#    'monthly_prior': 3.6307805477010207,
#    'n_changepoints': 17,
#    'seasonality_prior_scale': 24.268511341456772,
#    'weekly_fourier_order': 26,
#    'weekly_prior': 12.589254117941723,
#    'yearly_fourier_order': 47,
#    'yearly_prior': 95.4992586021443},),
#  996832.922927435: ({'changepoint_prior_scale': 0.039572134240874524,
#    'changepoint_range': 0.8995408722667109,
#    'holidays_prior_scale': 23.217772225959628,
#    'monthly_fourier_order': 12,
#    'monthly_prior': 12.022644346174177,
#    'n_changepoints': 17,
#    'seasonality_prior_scale': 20.2152676971492,
#    'weekly_fourier_order': 34,
#    'weekly_prior': 19.054607179632562,
#    'yearly_fourier_order': 51,
#    'yearly_prior': 36.30780547701034},),
#  997004.4440743623: ({'changepoint_prior_scale': 0.0407005732156777,
#    'changepoint_range': 0.9387630371812645,
#    'holidays_prior_scale': 20.931051935170007,
#    'monthly_fourier_order': 14,
#    'monthly_prior': 18.19700858609992,
#    'n_changepoints': 11,
#    'seasonality_prior_scale': 29.10096242446654,
#    'weekly_fourier_order': 13,
#    'weekly_prior': 9.12010839355913,
#    'yearly_fourier_order': 51,
#    'yearly_prior': 1.513561248436209},),
#  997569.8902685959: ({'changepoint_prior_scale': 0.051010642393513286,
#    'changepoint_range': 0.8739247872168258,
#    'holidays_prior_scale': 27.19176761149207,
#    'monthly_fourier_order': 10,
#    'monthly_prior': 2.884031503126611,
#    'n_changepoints': 10,
#    'seasonality_prior_scale': 23.545763783647764,
#    'weekly_fourier_order': 4,
#    'weekly_prior': 8.317637711026737,
#    'yearly_fourier_order': 51,
#    'yearly_prior': 6.025595860743595},),
#  999202.3196830683: ({'changepoint_prior_scale': 0.014200333941646177,
#    'changepoint_range': 0.9318973106154106,
#    'holidays_prior_scale': 30.38608471883405,
#    'monthly_fourier_order': 20,
#    'monthly_prior': 5.49540873857626,
#    'n_changepoints': 13,
#    'seasonality_prior_scale': 8.32709044224691,
#    'weekly_fourier_order': 26,
#    'weekly_prior': 75.8577575029189,
#    'yearly_fourier_order': 38,
#    'yearly_prior': 6.918309709189386},),
#  999317.649907188: ({'changepoint_prior_scale': 0.07778970219098558,
#    'changepoint_range': 0.6921322202565402,
#    'holidays_prior_scale': 33.916609090888656,
#    'monthly_fourier_order': 9,
#    'monthly_prior': 4.36515832240167,
#    'n_changepoints': 38,
#    'seasonality_prior_scale': 37.57419763006542,
#    'weekly_fourier_order': 15,
#    'weekly_prior': 12.022644346174177,
#    'yearly_fourier_order': 27,
#    'yearly_prior': 39.81071705534996},),
#  999618.9853428307: ({'changepoint_prior_scale': 0.048129743304283386,
#    'changepoint_range': 0.9793394655783783,
#    'holidays_prior_scale': 15.062269378227235,
#    'monthly_fourier_order': 32,
#    'monthly_prior': 9.549925860214394,
#    'n_changepoints': 28,
#    'seasonality_prior_scale': 15.893176678236546,
#    'weekly_fourier_order': 24,
#    'weekly_prior': 26.302679918953956,
#    'yearly_fourier_order': 47,
#    'yearly_prior': 34.67368504525336},),
#  1000002.9086981871: ({'changepoint_prior_scale': 0.03315196977517007,
#    'changepoint_range': 0.8937866999370461,
#    'holidays_prior_scale': 51.21799420200204,
#    'monthly_fourier_order': 27,
#    'monthly_prior': 45.70881896148778,
#    'n_changepoints': 26,
#    'seasonality_prior_scale': 46.35783230127538,
#    'weekly_fourier_order': 20,
#    'weekly_prior': 15.848931924611204,
#    'yearly_fourier_order': 40,
#    'yearly_prior': 2.398832919019494},),
#  1000025.4666702321: ({'changepoint_prior_scale': 0.02695182219788339,
#    'changepoint_range': 0.8382215369905219,
#    'holidays_prior_scale': 29.10374425381316,
#    'monthly_fourier_order': 13,
#    'monthly_prior': 57.543993733716064,
#    'n_changepoints': 44,
#    'seasonality_prior_scale': 32.07842568600087,
#    'weekly_fourier_order': 4,
#    'weekly_prior': 18.19700858609992,
#    'yearly_fourier_order': 51,
#    'yearly_prior': 1.659586907437562},),
#  1000208.4687580216: ({'changepoint_prior_scale': 0.035388582547490055,
#    'changepoint_range': 0.7479694891461006,
#    'holidays_prior_scale': 7.1080193999412264,
#    'monthly_fourier_order': 15,
#    'monthly_prior': 10.000000000000037,
#    'n_changepoints': 18,
#    'seasonality_prior_scale': 38.74164076311403,
#    'weekly_fourier_order': 10,
#    'weekly_prior': 6.60693448007598,
#    'yearly_fourier_order': 51,
#    'yearly_prior': 100.00000000000074},),
#  1003734.9286466887: ({'changepoint_prior_scale': 0.03881433947395159,
#    'changepoint_range': 0.7437009943303988,
#    'holidays_prior_scale': 57.909374726010775,
#    'monthly_fourier_order': 32,
#    'monthly_prior': 2.5118864315095837,
#    'n_changepoints': 41,
#    'seasonality_prior_scale': 44.04541298714329,
#    'weekly_fourier_order': 31,
#    'weekly_prior': 22.908676527677844,
#    'yearly_fourier_order': 49,
#    'yearly_prior': 41.68693834703379},),
#  1005078.6305757434: ({'changepoint_prior_scale': 0.050445938463605115,
#    'changepoint_range': 0.7759971318809784,
#    'holidays_prior_scale': 9.3931100332561,
#    'monthly_fourier_order': 32,
#    'monthly_prior': 2.089296130854042,
#    'n_changepoints': 17,
#    'seasonality_prior_scale': 36.54874288754366,
#    'weekly_fourier_order': 30,
#    'weekly_prior': 30.199517204020324,
#    'yearly_fourier_order': 49,
#    'yearly_prior': 3.1622776601683853},),
#  1005669.7291160007: ({'changepoint_prior_scale': 0.058556555830844334,
#    'changepoint_range': 0.671371358625663,
#    'holidays_prior_scale': 5.320771233732948,
#    'monthly_fourier_order': 20,
#    'monthly_prior': 7.9432823472428415,
#    'n_changepoints': 31,
#    'seasonality_prior_scale': 8.72965309615917,
#    'weekly_fourier_order': 6,
#    'weekly_prior': 16.59586907437568,
#    'yearly_fourier_order': 50,
#    'yearly_prior': 9.549925860214394},),
#  1006012.9068924641: ({'changepoint_prior_scale': 0.02996338776866849,
#    'changepoint_range': 0.820204887977185,
#    'holidays_prior_scale': 27.34092762022094,
#    'monthly_fourier_order': 22,
#    'monthly_prior': 26.302679918953956,
#    'n_changepoints': 27,
#    'seasonality_prior_scale': 25.50720503158353,
#    'weekly_fourier_order': 34,
#    'weekly_prior': 18.19700858609992,
#    'yearly_fourier_order': 48,
#    'yearly_prior': 1.659586907437562},),
#  1006084.2771076113: ({'changepoint_prior_scale': 0.0395430544804534,
#    'changepoint_range': 0.9637834228741216,
#    'holidays_prior_scale': 26.694693015363338,
#    'monthly_fourier_order': 24,
#    'monthly_prior': 11.481536214968871,
#    'n_changepoints': 33,
#    'seasonality_prior_scale': 10.99515020247872,
#    'weekly_fourier_order': 18,
#    'weekly_prior': 69.18309709189411,
#    'yearly_fourier_order': 46,
#    'yearly_prior': 30.199517204020324},)}

# %%
best_kw = list(map(lambda tt2: tt2[-1][-1] ,sorted(ori_serlize_m_dict.items(), key = lambda t2: t2[0])))[0]

# %%
best_kw
# Out:
# {'changepoint_prior_scale': 0.03544445370013562,
#  'changepoint_range': 0.919881741595199,
#  'holidays_prior_scale': 22.057393646144526,
#  'monthly_fourier_order': 1,
#  'monthly_prior': 26.302679918953956,
#  'n_changepoints': 36,
#  'seasonality_prior_scale': 7.114445399086622,
#  'weekly_fourier_order': 4,
#  'weekly_prior': 1.5848931924611147,
#  'yearly_fourier_order': 37,
#  'yearly_prior': 1.659586907437562}

# %%
best_fit_score = object_func(best_kw)
# Out:
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create leaf model - aa
# ----------will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
#
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - ca
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:00<00:05,  1.04it/s]
# Fitting models:  29%|██▊       | 2/7 [00:01<00:03,  1.42it/s]
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  43%|████▎     | 3/7 [00:01<00:02,  1.40it/s]
# will create leaf model - cc
# ----------
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  71%|███████▏  | 5/7 [00:02<00:01,  1.69it/s]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models: 100%|██████████| 7/7 [00:02<00:00,  2.45it/s]
# Fitting models: 100%|██████████| 7/7 [00:31<00:00,  4.56s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - ca
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:00<00:04,  1.24it/s]
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - ac
# ----------
# Fitting models:  29%|██▊       | 2/7 [00:01<00:03,  1.39it/s]
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - cc
# ----------
# Fitting models:  43%|████▎     | 3/7 [00:01<00:02,  1.67it/s]
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  57%|█████▋    | 4/7 [00:01<00:01,  1.97it/s]
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - da
# ----------
# Fitting models:  71%|███████▏  | 5/7 [00:02<00:01,  1.80it/s]
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models: 100%|██████████| 7/7 [00:03<00:00,  2.32it/s]
# Fitting models: 100%|██████████| 7/7 [00:31<00:00,  4.54s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------will create leaf model - aa
# ----------
#
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  14%|█▍        | 1/7 [00:00<00:03,  1.67it/s]
# will create leaf model - ca
# ----------
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  43%|████▎     | 3/7 [00:01<00:02,  1.97it/s]
# will create leaf model - cc
# ----------
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  71%|███████▏  | 5/7 [00:01<00:00,  2.14it/s]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models: 100%|██████████| 7/7 [00:02<00:00,  2.78it/s]
# Fitting models: 100%|██████████| 7/7 [00:32<00:00,  4.66s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create leaf model - aa
# ----------
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  14%|█▍        | 1/7 [00:00<00:03,  1.55it/s]
# will create leaf model - ca
# ----------
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - cc
# ----------
# Fitting models:  43%|████▎     | 3/7 [00:01<00:02,  1.90it/s]
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  57%|█████▋    | 4/7 [00:01<00:01,  2.41it/s]
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  71%|███████▏  | 5/7 [00:01<00:00,  2.42it/s]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models: 100%|██████████| 7/7 [00:02<00:00,  3.01it/s]
# Fitting models: 100%|██████████| 7/7 [00:32<00:00,  4.69s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------will create leaf model - aa
# ----------
#
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - ca
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:00<00:03,  1.72it/s]
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  29%|██▊       | 2/7 [00:00<00:02,  2.07it/s]
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - cc
# ----------
# Fitting models:  43%|████▎     | 3/7 [00:01<00:01,  2.18it/s]
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - dc
# ----------
# Fitting models:  57%|█████▋    | 4/7 [00:01<00:01,  2.59it/s]
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  71%|███████▏  | 5/7 [00:02<00:00,  2.19it/s]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models: 100%|██████████| 7/7 [00:02<00:00,  2.78it/s]
# Fitting models: 100%|██████████| 7/7 [00:31<00:00,  4.52s/it]
# forecasts first key: aa
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  14%|█▍        | 1/7 [00:00<00:03,  1.53it/s]
# will create leaf model - ca
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  29%|██▊       | 2/7 [00:00<00:02,  1.85it/s]
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - cc
# ----------
# Fitting models:  43%|████▎     | 3/7 [00:01<00:01,  2.08it/s]
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  57%|█████▋    | 4/7 [00:01<00:01,  2.33it/s]
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  71%|███████▏  | 5/7 [00:01<00:00,  2.65it/s]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models: 100%|██████████| 7/7 [00:02<00:00,  2.82it/s]
# Fitting models: 100%|██████████| 7/7 [00:32<00:00,  4.63s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------will create leaf model - aa
# ----------
#
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - ca
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:00<00:05,  1.16it/s]
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  29%|██▊       | 2/7 [00:01<00:03,  1.32it/s]
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  43%|████▎     | 3/7 [00:01<00:02,  1.66it/s]
# will create leaf model - cc
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  57%|█████▋    | 4/7 [00:01<00:01,  1.99it/s]
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  71%|███████▏  | 5/7 [00:02<00:00,  2.01it/s]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models: 100%|██████████| 7/7 [00:03<00:00,  2.31it/s]
# Fitting models: 100%|██████████| 7/7 [00:32<00:00,  4.70s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------will create leaf model - aa
# ----------
#
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - ca
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:00<00:05,  1.07it/s]
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - cc
# ----------
# Fitting models:  43%|████▎     | 3/7 [00:01<00:02,  1.37it/s]
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  57%|█████▋    | 4/7 [00:01<00:01,  1.76it/s]
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - da
# ----------
# Fitting models:  71%|███████▏  | 5/7 [00:02<00:01,  1.83it/s]
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models: 100%|██████████| 7/7 [00:02<00:00,  2.68it/s]
# Fitting models: 100%|██████████| 7/7 [00:33<00:00,  4.82s/it]
# forecasts first key: aa
# total_part (7, 8) preds_part (7, 8)
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------will create leaf model - aa
# ----------
#
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - ca
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:00<00:05,  1.20it/s]
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - cc
# ----------
# Fitting models:  43%|████▎     | 3/7 [00:01<00:02,  1.49it/s]
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  71%|███████▏  | 5/7 [00:02<00:01,  1.77it/s]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models: 100%|██████████| 7/7 [00:02<00:00,  2.87it/s]
# Fitting models: 100%|██████████| 7/7 [00:32<00:00,  4.64s/it]
# forecasts first key: total
# total_part (7, 8) preds_part (7, 8)

# %%
best_fit_score
# Out:
# 0.11715400256873237

# %%
best_fit_score
# Out:
# 777511.5594971064

# %%
import seaborn as sns
sns.distplot(list(ori_serlize_m_dict.keys()))

# %%
import pickle as pkl
with open("serlize_m_dict_total.pkl", "rb") as f:
    total_serize_m_dict = pkl.load(f)

# %%
pd.Series(list(total_serize_m_dict.keys())).min()
# Out:
# 0.1397960218580981

# %%
def retrieve_clf(kw):
    from copy import deepcopy
    from time import time
    from fbprophet.diagnostics import generate_cutoffs, performance_metrics
    start_time = time()
    assert type(kw) == type(dict())
    
    n_changepoints = int(kw["n_changepoints"])
    changepoint_range = kw["changepoint_range"]
    seasonality_prior_scale = kw["seasonality_prior_scale"]
    holidays_prior_scale = kw["holidays_prior_scale"]
    changepoint_prior_scale = kw["changepoint_prior_scale"]
    
    yearly_fourier_order = int(kw["yearly_fourier_order"])
    weekly_fourier_order = int(kw["weekly_fourier_order"])
    monthly_fourier_order = int(kw["monthly_fourier_order"])

    yearly_prior = kw["yearly_prior"]
    weekly_prior = kw["weekly_prior"]
    monthly_prior = kw["monthly_prior"]

    kwargs = dict()
    kwargs["yearly_seasonality"] = False
    kwargs["daily_seasonality"] = False
    kwargs["weekly_seasonality"] = False
    kwargs["ext_args"] = {
    "seasonality": []
}

    kwargs["ext_args"]["seasonality"].append(
    {
        "name": "yearly",
        "period": 365.25,
        "fourier_order": yearly_fourier_order,
        "prior_scale": yearly_prior
    }
)
    kwargs["ext_args"]["seasonality"].append(
    {
        "name": "weekly",
        "period": 7,
        "fourier_order": weekly_fourier_order,
        "prior_scale": weekly_prior
    }
)
    kwargs["ext_args"]["seasonality"].append(
    {
        "name": "monthly",
        "period": 30.5,
        "fourier_order": monthly_fourier_order,
        "prior_scale": monthly_prior
    }
)
    
    kwargs["n_changepoints"] = n_changepoints
    kwargs["seasonality_prior_scale"] = seasonality_prior_scale
    kwargs["holidays_prior_scale"] = holidays_prior_scale
    kwargs["changepoint_prior_scale"] = changepoint_prior_scale
    
    kwargs["changepoint_range"] = changepoint_range
    
    clf = HTSRegressor_Add_Verison(model='prophet', revision_method='BU', n_jobs=2, low_memory=False, **kwargs)
    return clf

# %%
best_clf = retrieve_clf(best_kw)

# %%
import pandas as pd
import numpy as np
import os
import json

df = pd.read_csv("data/df.csv")
with open("data/hierarchy.json", "r") as f:
    hierarchy = json.load(f)  
if "Date" in df.columns.tolist():
    df.index = pd.to_datetime(df["Date"])
    del df["Date"]
df = df.asfreq("D")

# %%
model = best_clf.fit(df.head(len(df) - 6 * 7), hierarchy)
# Out:
# Fitting models:   0%|          | 0/7 [00:00<?, ?it/s]
# will create branch model - total
#    |- aa
#    |- ca
#    |- ac
#    |- cc
#    |- dc
#    - da
# ----------
# will create leaf model - aa
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# will create leaf model - ca
# ----------
# Fitting models:  14%|█▍        | 1/7 [00:00<00:04,  1.29it/s]
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  29%|██▊       | 2/7 [00:01<00:03,  1.63it/s]
# will create leaf model - ac
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  43%|████▎     | 3/7 [00:01<00:02,  1.75it/s]
# will create leaf model - cc
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  57%|█████▋    | 4/7 [00:01<00:01,  2.23it/s]
# will create leaf model - dc
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models:  71%|███████▏  | 5/7 [00:02<00:01,  1.93it/s]
# will create leaf model - da
# ----------
# seasonality yearly 365.25 37 1.659586907437562 added
# seasonality weekly 7 4 1.5848931924611147 added
# seasonality monthly 30.5 1 26.302679918953956 added
# Fitting models: 100%|██████████| 7/7 [00:02<00:00,  2.56it/s]

# %%
preds = model.predict(steps_ahead=6 * 7)
# Out:
# Fitting models: 100%|██████████| 7/7 [00:33<00:00,  4.85s/it]
# forecasts first key: total

# %%
import seaborn as sns
dates = pd.Series(df.index.tolist())
ax = sns.lineplot(data = preds.reset_index()[["index", "total"]][preds.reset_index()["index"].isin(dates)][preds.reset_index()["index"] > "2015-01-01"], x = "index", y = "total")
ax.axes.set_ylim(0, 1.5 *int(1e7))
# Out:
# (0.0, 15000000.0)

# %%
ax = sns.lineplot(data = df.reset_index()[df.reset_index()["Date"] > "2015-01-01"], x = "Date", y = "total")
ax.axes.set_ylim(0, 1.5 *int(1e7))
# Out:
# (0.0, 15000000.0)

# %%
comp_df = pd.merge(preds[["total"]].tail(6 * 7), df[df.index.isin(preds["total"].index.tolist())][["total"]], left_index=True, right_index=True, how = "inner")

# %%
comp_df.columns = ["preds",  "ori"]

# %%
preds_df = comp_df[["preds"]].copy()
ori_df = comp_df[["ori"]].copy()
preds_df["cate"], ori_df["cate"] = "preds", "ori"
preds_df = preds_df.rename(columns={"preds": "val"})
ori_df = ori_df.rename(columns={"ori": "val"})
sns.lineplot(data = pd.concat([ori_df, preds_df], axis = 0).reset_index(), x = "index", y = "val", hue = "cate")
